# %%
'''
Date: 2019-01-02
Contributor: Matthew Barlowe
Twitter: @matt_barlowe
Email: matt@barloweanalytics.com

This file contains the main functions to scrape and compile the NBA api and
return a CSV file of the pbp for the provided game
'''
import json
import requests
import bs4
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
# have to pass this to the requests function or the api will return a 403 code
user_agent = {'User-agent': 'Mozilla/5.0'}

#this will catalog the shot types recorded in the NBA play by play
#not sure how accurate this is it seems to change for the same shots
shot_type_dict = {58: 'turnaround hook shot', 5: 'layup', 6: 'driving layup',
                  96: 'turnaround bank hook shot', 108: 'cutting dunk shot',
                  79: 'pullup jump shot', 72: 'putback layup', 1: 'jump shot',
                  57: 'driving hook shot', 75: 'driving finger roll layup',
                  76: 'running finger roll layup', 79: '3pt shot', 80: '3pt shot',
                  2: '3pt shot', 3: 'hook shot', 98: 'cutting layup', 67: 'hook bank shot',
                  101: 'driving floating jump shot', 102: 'driving floating bank shot jump shot',
                  73: 'driving reverse layup', 63: 'fadeaway jump shot', 47: 'turnaround jump shot',
                  52: 'alley oop dunk', 97: 'tip layup', 66: 'jump bank shot',
                  50: 'running dunk shot', 41: 'running layup', 93: 'driving bank hook shot',
                  87: 'putback dunk shot', 99:'cutting finger roll layup',
                  86: 'turnaround fadeaway', 78: 'floating jump shot', 9: 'driving dunk',
                  74: 'running reverse layup', 44: 'reverse layup',
                  71: 'finger roll layup'
                  }

#this dictionary will categorize the event types that happen in the NBA
#play by play
event_type_dict = {1: 'shot', 2: 'missed_shot', 4: 'rebound', 5: 'turnover',
                   20: 'stoppage: out-of-bounds', 6: 'foul', 3: 'free-throw',
                   8: 'substitution', 12: 'period-start', 10: 'jump-ball',
                   9: 'team-timeout', 18: 'instant-replay', 13: 'period-end',
                   7: 'goal-tending', 0: 'game-end'
                  }

# %%
#create column whether shot was succesful or not
def made_shot(row):
    '''
    function to determine whether shot was made or missed

    Input:
    row - pandas row

    Output:
    shot_made - binary variable
    '''

    if row['event_type_de'] == 'shot':
        return 1
    elif row['event_type_de'] == 'missed_shot':
        return 0
    elif (row['event_type_de'] == 'free-throw') & ('Missed' in row['de']):
        return 0
    elif (row['event_type_de'] == 'free-throw') & ('Missed' not in row['de']):
        return 1
    else:
        return np.nan

# %%
#parse mtype column to get all the shot types being taken
def parse_shot_types(row):
    '''
    function to parse what type of shot is being taken

    Inputs:
    row - pandas row of play by play dataframe

    Outputs:
    shot_type - returns a shot type of the values hook, jump, layup, dunk, tip
    '''
    if pd.isnull(row['shot_made']) == 0:
        if 'Layup' in row['de']:
            return 'layup'
        elif 'Hook' in row['de']:
            return 'hook'
        elif 'Dunk' in row['de']:
            return 'dunk'
        elif 'Free' in row['de']:
            return 'free'
        else:
            return 'jump'
    else:
        return np.nan

# %%
#Clean time to get a seconds elapsed column

def create_seconds_elapsed(row):
    '''
    this function parses the string time column and converts it into game
    seconds elapsed

    Inputs:
    row - row of play by play dataframe

    Outputs:
    time_in_seconds - the elapsed game time expressed in seconds
    '''

    time = row['pctimestring'].strip()
    time_list = time.split(':')
    max_time = 720
    ot_max_time = 300

    if row['period'] in [1,2,3,4]:
        time_in_seconds = (max_time - (int(time_list[0]) * 60 + int(time_list[1]))) + (720 * (int(row['period']) - 1))
    elif row['period'] > 4:
        time_in_seconds = (ot_max_time - (int(time_list[0]) * 60 + int(time_list[1]))) + (300 * (int(row['period']) - 5)) + 2880

    return time_in_seconds

# %%
def calc_points_made(row):
    '''
    function to calculate the points earned by a team with each shot made

    Inputs:
    row - row of pbp dataframe

    Outputs - value of shot made
    '''

    if row['is_three'] == 1 and row['shot_made'] == 1:
        return 3
    elif row['is_three'] == 0 and row['shot_made'] == 1 and row['shot_type'] != 'free':
        return 2
    elif row['shot_type'] == 'free':
        return 1
    else:
        return 0

# %%
#determine what type of fouls are being commited

def parse_foul(row):
    '''
    function to determine what type of foul is being commited by the player

    Input:
    row - row of nba play by play

    Output:
    foul_type - the foul type of the fould commited by the player
    '''

    if 'Shooting' in row['de']:
        return 'shooting'
    if 'Personal' in row['de']:
        return 'personal'
    if 'Loose Ball' in row['de']:
        return 'loose_ball'
    if 'Technical' in row['de']:
        return 'technical'
    if 'Charge' in row['de']:
        return 'charge'
    if 'Defense 3 Second' in row['de']:
        return '3 second'
    if 'Flagrant' in row['de']:
        return 'flagrant'
    if 'Flagrant 2' in row['de']:
        return 'flagrant 2'
    else:
        return np.nan

# %%
def get_lineups(dataframe):
    '''
    This function gets the lineups for the game and creates columns 
    for each player on the court for each event of the play by play
    
    Inputs:
    dataframe  - the nba dataframe that's been computed up to this point
    
    Outputs:
    lineup_df  - the dataframe with lineups computed 
    '''
    #this pulls out the starting lineups from the play by play if every player
#on the court has done something that is recorded by the play by play
#if not then I will need to check the players against the lineups returned
#from the api and weed out which one doesn't fit. This needs to be repeated
#for every period

    periods = []
    for period in range(1, dataframe['period'].max()+1):
        #subsets main dataframe by period and subsets into a home and away subs
        period_df = dataframe[dataframe['period'] == period].reset_index()
        subs_df = period_df[(period_df.event_type_de == 'substitution')]
        away_subs = subs_df[pd.isnull(subs_df['visitordescription']) == 0]
        home_subs = subs_df[pd.isnull(subs_df['homedescription']) == 0]

        #getting player ids of the players subbed into the game to check against later
        #to determine starting lineups
        away_subbed_players = list(away_subs['player2_id'].unique())
        home_subbed_players = list(home_subs['player2_id'].unique())
        #gets the index of the first sub for home and away to get the players who started
        #the period by subsetting the dataframe to all actions before the first sub for
        #each team
        away_indexes = list(away_subs.index)
        home_indexes = list(home_subs.index)
        #create variables for the lineup API in case just looking at
        game_date = str(period_df.game_date.unique()[0])[:10]
        away_team_id = period_df.away_team_id.unique()[0]
        home_team_id = period_df.home_team_id.unique()[0]
        api_season = f'{period_df.season.unique()[0]-1}-{str(period_df.season.unique()[0])[2:]}'
        home_lineup_api = ('https://stats.nba.com/stats/leaguedashlineups?Conference=&'
                           f'DateFrom={game_date}&DateTo={game_date}&Division=&'
                           'GameSegment=&GroupQuantity=5&LastNGames=0&LeagueID=&Location=&'
                           f'MeasureType=Base&Month=0&OpponentTeamID={away_team_id}&Outcome=&PORound=&'
                           f'PaceAdjust=N&PerMode=Totals&Period={period}&PlusMinus=N&Rank=N&'
                           f'Season={api_season}&SeasonSegment=&SeasonType=Regular+'
                           'Season&ShotClockRange=&TeamID=&VsConference=&VsDivision=')

        away_lineup_api = ('https://stats.nba.com/stats/leaguedashlineups?Conference=&'
                           f'DateFrom={game_date}&DateTo={game_date}&Division=&'
                           'GameSegment=&GroupQuantity=5&LastNGames=0&LeagueID=&Location=&'
                           f'MeasureType=Base&Month=0&OpponentTeamID={home_team_id}&Outcome=&PORound=&'
                           f'PaceAdjust=N&PerMode=Totals&Period={period}&PlusMinus=N&Rank=N&'
                           f'Season={api_season}&SeasonSegment=&SeasonType=Regular+'
                           'Season&ShotClockRange=&TeamID=&VsConference=&VsDivision=')


        home_lineup_req = requests.get(home_lineup_api, headers=user_agent)

        home_lineup_dict = home_lineup_req.json()

        #extract the player ids of each lineup
        home_lineups = []
        for lineup in home_lineup_dict['resultSets'][0]['rowSet']:
            home_lineups.append([lineup[1]])

        #clean the id strings into a list of ids for each lineup and convert them to ints
        for x in range(len(home_lineups)):
            home_lineups[x] = list(map(int,list(filter(None,home_lineups[x][0].split('-')))))

        away_lineup_req = requests.get(away_lineup_api, headers=user_agent)
        away_lineup_dict = away_lineup_req.json()

        #extract the player ids of each lineup
        away_lineups = []
        for lineup in away_lineup_dict['resultSets'][0]['rowSet']:
            away_lineups.append([lineup[1]])

        #clean the id strings into a list of ids for each lineup and convert them to ints
        for x in range(len(away_lineups)):
            away_lineups[x] = list(map(int,list(filter(None,away_lineups[x][0].split('-')))))
        #looking at the people before the first sub and if
        #it doesn't equal five then continue till next sub excluding the id of the first
        #subbed player and etc. until a list of five players is achieved if five is never
        #achieved by end of period then goto lineup api



        away_starting_line = list(period_df[(period_df.event_team == test['away_team_abbrev'].unique()[0])
                                       & (~pd.isnull(period_df['player1_name']))
                                       & (period_df['player1_team_abbreviation'] == test['away_team_abbrev'].unique()[0])
                                       & (period_df.is_block == 0)
                                       & (period_df.is_steal == 0)]
                                        .loc[:away_indexes[0], :]['player1_id'].unique())

        home_starting_line = list(period_df[(period_df.event_team == test['home_team_abbrev'].unique()[0])
                                       & (~pd.isnull(period_df['player1_name']))
                                       & (period_df['player1_team_abbreviation'] == test['home_team_abbrev'].unique()[0])
                                       & (period_df.is_block == 0)
                                       & (period_df.is_steal == 0)]
                                        .loc[:home_indexes[0], :]['player1_id'].unique())
        
#theres a large possibility that my catching of posssible lines might return
#two possible lines that fit the criteria in extreme edge cases may have to
#resort to brute forcing it if that happens often
        
        if len(away_starting_line) < 5:
            possible_away_lines = []
            possible_home_lines = []
            for x in away_lineups:
                if set(away_starting_line).issubset(x):
                    possible_away_lines.append(x)
            if len(possible_away_lines) > 1:
                index = 0
                for line in possible_away_lines:
                    for player in line:
                        if player in away_subs and player not in away_starting_line:
                            index = possible_home_lines.index(line)
                    possible_home_lines.pop(index)
            away_ids_names = [(x, period_df[period_df['player1_id'] == x]['player1_name'].unique()[0]) for x in possible_away_lines[0]]
        else:
            away_ids_names = [(x, period_df[period_df['player1_id'] == x]['player1_name'].unique()[0]) for x in away_starting_line]
        #repeating the process for home players
        if len(home_starting_line) < 5:
            possible_home_lines = []
            for x in home_lineups:
                if set(home_starting_line).issubset(x):
                    possible_home_lines.append(x)
            if len(possible_home_lines) > 1:
                index = 0
                for line in possible_home_lines:
                    for player in line:
                        if player in home_subs and player not in home_starting_line:
                            index = possible_home_lines.index(line)
                    possible_home_lines.pop(index)
            home_ids_names = [(x, period_df[period_df['player1_id'] == x]['player1_name'].unique()[0]) for x in possible_home_lines[0]]
        else:
            home_ids_names = [(x, period_df[period_df['player1_id'] == x]['player1_name'].unique()[0]) for x in home_starting_line]
        


        period_df['home_player_1'] = ''
        period_df['home_player_1_id'] = ''
        period_df['home_player_2'] = ''
        period_df['home_player_2_id'] = ''
        period_df['home_player_3'] = ''
        period_df['home_player_3_id'] = ''
        period_df['home_player_4'] = ''
        period_df['home_player_4_id'] = ''
        period_df['home_player_5'] = ''
        period_df['home_player_5_id'] = ''
        period_df['away_player_1'] = ''
        period_df['away_player_1_id'] = ''
        period_df['away_player_2'] = ''
        period_df['away_player_2_id'] = ''
        period_df['away_player_3'] = ''
        period_df['away_player_3_id'] = ''
        period_df['away_player_4'] = ''
        period_df['away_player_4_id'] = ''
        period_df['away_player_5'] = ''
        period_df['away_player_5_id'] = ''
        for x in range(period_df.shape[0]):
            if period_df.iloc[x, :]['event_type_de'] == 'substitution' and pd.isnull(period_df.iloc[x, :]['visitordescription']) == 1:
                home_ids_names = [ids for ids in home_ids_names if ids[0] != period_df.iloc[x, :]['player1_id']]
                home_ids_names.append((period_df.iloc[x, 21], period_df.iloc[x,22]))
                period_df.iloc[x, 63] = home_ids_names[0][0]
                period_df.iloc[x, 62] = home_ids_names[0][1]
                period_df.iloc[x, 65] = home_ids_names[1][0]
                period_df.iloc[x, 64] = home_ids_names[1][1]
                period_df.iloc[x, 67] = home_ids_names[2][0]
                period_df.iloc[x, 66] = home_ids_names[2][1]
                period_df.iloc[x, 69] = home_ids_names[3][0]
                period_df.iloc[x, 68] = home_ids_names[3][1]
                period_df.iloc[x, 71] = home_ids_names[4][0]
                period_df.iloc[x, 70] = home_ids_names[4][1]
                period_df.iloc[x, 73] = away_ids_names[0][0]
                period_df.iloc[x, 72] = away_ids_names[0][1]
                period_df.iloc[x, 75] = away_ids_names[1][0]
                period_df.iloc[x, 74] = away_ids_names[1][1]
                period_df.iloc[x, 77] = away_ids_names[2][0]
                period_df.iloc[x, 76] = away_ids_names[2][1]
                period_df.iloc[x, 79] = away_ids_names[3][0]
                period_df.iloc[x, 78] = away_ids_names[3][1]
                period_df.iloc[x, 81] = away_ids_names[4][0]
                period_df.iloc[x, 80] = away_ids_names[4][1]
            elif period_df.iloc[x, :]['event_type_de'] == 'substitution' and pd.isnull(period_df.iloc[x, :]['homedescription']) == 1:
                away_ids_names = [ids for ids in away_ids_names if ids[0] != period_df.iloc[x, :]['player1_id']]
                away_ids_names.append((period_df.iloc[x,21], period_df.iloc[x,22]))
                period_df.iloc[x, 63] = home_ids_names[0][0]
                period_df.iloc[x, 62] = home_ids_names[0][1]
                period_df.iloc[x, 65] = home_ids_names[1][0]
                period_df.iloc[x, 64] = home_ids_names[1][1]
                period_df.iloc[x, 67] = home_ids_names[2][0]
                period_df.iloc[x, 66] = home_ids_names[2][1]
                period_df.iloc[x, 69] = home_ids_names[3][0]
                period_df.iloc[x, 68] = home_ids_names[3][1]
                period_df.iloc[x, 71] = home_ids_names[4][0]
                period_df.iloc[x, 70] = home_ids_names[4][1]
                period_df.iloc[x, 73] = away_ids_names[0][0]
                period_df.iloc[x, 72] = away_ids_names[0][1]
                period_df.iloc[x, 75] = away_ids_names[1][0]
                period_df.iloc[x, 74] = away_ids_names[1][1]
                period_df.iloc[x, 77] = away_ids_names[2][0]
                period_df.iloc[x, 76] = away_ids_names[2][1]
                period_df.iloc[x, 79] = away_ids_names[3][0]
                period_df.iloc[x, 78] = away_ids_names[3][1]
                period_df.iloc[x, 81] = away_ids_names[4][0]
                period_df.iloc[x, 80] = away_ids_names[4][1]
            else:
                period_df.iloc[x, 63] = home_ids_names[0][0]
                period_df.iloc[x, 62] = home_ids_names[0][1]
                period_df.iloc[x, 65] = home_ids_names[1][0]
                period_df.iloc[x, 64] = home_ids_names[1][1]
                period_df.iloc[x, 67] = home_ids_names[2][0]
                period_df.iloc[x, 66] = home_ids_names[2][1]
                period_df.iloc[x, 69] = home_ids_names[3][0]
                period_df.iloc[x, 68] = home_ids_names[3][1]
                period_df.iloc[x, 71] = home_ids_names[4][0]
                period_df.iloc[x, 70] = home_ids_names[4][1]
                period_df.iloc[x, 73] = away_ids_names[0][0]
                period_df.iloc[x, 72] = away_ids_names[0][1]
                period_df.iloc[x, 75] = away_ids_names[1][0]
                period_df.iloc[x, 74] = away_ids_names[1][1]
                period_df.iloc[x, 77] = away_ids_names[2][0]
                period_df.iloc[x, 76] = away_ids_names[2][1]
                period_df.iloc[x, 79] = away_ids_names[3][0]
                period_df.iloc[x, 78] = away_ids_names[3][1]
                period_df.iloc[x, 81] = away_ids_names[4][0]
                period_df.iloc[x, 80] = away_ids_names[4][1]
        periods.append(period_df)

    lineup_df = pd.concat(periods).reset_index()
    return lineup_df

# %%
def scrape_pbp(game_id, user_agent=user_agent):
    '''
    This function scrapes both of the pbp urls and returns a joined/cleaned
    pbp dataframe

    Inputs:
    game_id - integer id of the nba game you want to scrape in question
    user_agent - this is the user agent to pass to the requests function

    Outputs:
    clean_df - final cleaned dataframe
    '''

#hard coding these in for testing purposes
    v2_api_url = 'https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800549&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk'
    pbp_api_url = 'https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800549_full_pbp.json'

# this will be the main url used for the v2 api url once testing is done
#v2 api will contain all the player info for each play in the game while the
#pbp_api_url will contain xy coords for each event
#   v2_api_url = 'https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID={game_id}&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk'
#   pbp_api_url = 'https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/{game_id}_full_pbp.json'
# have to pass this to the requests function or the api will return a 403 code
    v2_rep = requests.get(v2_api_url, headers=user_agent, verify=False) # remove this when package is finalized
    v2_dict = v2_rep.json()

#this pulls the v2 stats.nba play by play api
    pbp_v2_headers = v2_dict['resultSets'][0]['headers']
    pbp_v2_data = v2_dict['resultSets'][0]['rowSet']
    pbp_v2_df = pd.DataFrame(pbp_v2_data, columns=pbp_v2_headers)
    pbp_v2_df.columns = list(map(str.lower, pbp_v2_df.columns))
    print(pbp_v2_df.columns)

#this pulls the data.nba api end play by play
    pbp_rep = requests.get(pbp_api_url, headers=user_agent, verify=False)
    pbp_dict = pbp_rep.json()

#this will be used to concat each quarter from the play by play
    pbp_df_list = []

    for qtr in range(len(pbp_dict['g']['pd'])):
        pbp_df_list.append(pd.DataFrame(pbp_dict['g']['pd'][qtr]['pla']))

#pulling the home and away team abbreviations and the game date
    gcode = pbp_dict['g']['gcode'].split('/')
    date = gcode[0]
    teams = gcode[1]
    home_team_abbrev = teams[3:]
    away_team_abbrev = teams[:3]
    pbp_df = pd.concat(pbp_df_list)

#joining the two dataframes together and only pulling in relavent columns
    clean_df = pbp_v2_df.merge(pbp_df[['evt', 'locX', 'locY', 'hs', 'vs', 'de']],
                               left_on = 'eventnum', right_on='evt')

#add date and team abbrev columns to dataframe
    clean_df.loc[:, 'home_team_abbrev'] = home_team_abbrev
    clean_df.loc[:, 'away_team_abbrev'] = away_team_abbrev
    clean_df.loc[:, 'game_date'] = date
    clean_df.loc[:, 'game_date'] = clean_df.loc[:, 'game_date'].astype('datetime64')
    clean_df.loc[:, ('season')] = np.where(clean_df.game_date.dt.month.isin([10, 11, 12]),
                                           clean_df.game_date.dt.year + 1,
                                           clean_df.game_date.dt.year)
    #code to properly get the team ids as the scientific notation cuts off some digits
    home_team_id = clean_df[clean_df['player1_team_abbreviation'] == home_team_abbrev]['player1_team_id'].astype(int).unique()
    away_team_id = clean_df[clean_df['player1_team_abbreviation'] == away_team_abbrev]['player1_team_id'].astype(int).unique()
    clean_df.loc[:, 'home_team_id'] = home_team_id
    clean_df.loc[:, 'away_team_id'] = away_team_id

#create an event team colum
    clean_df['event_team'] = np.where(clean_df['homedescription'].isnull(),
                                    clean_df['home_team_abbrev'], clean_df['away_team_abbrev'])

#create and event type description column
    clean_df['event_type_de'] = clean_df[['eventmsgtype']].replace({'eventmsgtype': event_type_dict})

#create and shot type description column
    clean_df['shot_type_de'] = clean_df[['eventmsgtype', 'eventmsgactiontype']]\
                                .apply(lambda x: shot_type_dict[int(x['eventmsgactiontype'])]
                                       if np.isin(x['eventmsgtype'],[1,2]) else np.nan, axis=1)

#create an event team colum
    clean_df['event_team'] = np.where(~clean_df['homedescription'].isnull(),
                                      clean_df['home_team_abbrev'],
                                      clean_df['away_team_abbrev'])
    
#creates column for whether shot is made or not
    clean_df['shot_made'] = clean_df.apply(made_shot, axis=1)

#create a column that says whether the shot was blocked or not
    clean_df['is_block'] = np.where(clean_df['homedescription'].str.contains('BLOCK') |
                                    clean_df['visitordescription'].str.contains('BLOCK'),
                                    1, 0)

#create a column for the type of shot taken
    clean_df['shot_type'] = clean_df.apply(parse_shot_types, axis=1)

#create seconds_elapsed column between plays
    clean_df['seconds_elapsed'] = clean_df.apply(create_seconds_elapsed, axis=1)

#calculate event length of each even in seconds
    clean_df['event_length'] =  clean_df['seconds_elapsed'] - clean_df['seconds_elapsed'].shift(1)

#determine whether shot was a three pointer
    clean_df['is_three'] = np.where(clean_df['de'].str.contains('3pt'), 1, 0)
    

#determine points earned
    clean_df['points_made'] = clean_df.apply(calc_points_made, axis=1)

#create columns that determine if rebound is offenseive or deffensive
    clean_df['is_d_rebound'] = np.where((clean_df['event_type_de'] == 'rebound') &
                                         (clean_df['event_team'] != clean_df['event_team'].shift(1)), 1, 0)

    clean_df['is_o_rebound'] = np.where((clean_df['event_type_de'] == 'rebound') &
                                        (clean_df['event_team'] == clean_df['event_team'].shift(1))
                                        & (clean_df['event_type_de'].shift(1) != 'free-throw'), 1, 0)

#create columns to determine turnovers and steals
    clean_df['is_turnover'] = np.where(clean_df['de'].str.contains('Turnover'), 1, 0)
    clean_df['is_steal'] = np.where(clean_df['de'].str.contains('Steal'), 1, 0)


#parse foul type
    clean_df['foul_type'] = clean_df.apply(parse_foul, axis=1)

# determine if a shot is a putback off an offensive reboundk
    clean_df['is_putback'] = np.where((clean_df['is_o_rebound'].shift(1) == 1) &
                                      (clean_df['event_length'] <= 3), 1, 0)

    clean_df = get_lineups(clean_df)
    return clean_df

# %%
test = scrape_pbp(1)
# Out:
# /Users/MattBarlowe/.virtualenvs/databasescripts/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Index(['game_id', 'eventnum', 'eventmsgtype', 'eventmsgactiontype', 'period',
#        'wctimestring', 'pctimestring', 'homedescription', 'neutraldescription',
#        'visitordescription', 'score', 'scoremargin', 'person1type',
#        'player1_id', 'player1_name', 'player1_team_id', 'player1_team_city',
#        'player1_team_nickname', 'player1_team_abbreviation', 'person2type',
#        'player2_id', 'player2_name', 'player2_team_id', 'player2_team_city',
#        'player2_team_nickname', 'player2_team_abbreviation', 'person3type',
#        'player3_id', 'player3_name', 'player3_team_id', 'player3_team_city',
#        'player3_team_nickname', 'player3_team_abbreviation'],
#       dtype='object')
# /Users/MattBarlowe/.virtualenvs/databasescripts/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
test
# Out:
#      level_0  index     game_id  eventnum  eventmsgtype  eventmsgactiontype  \
# 0          0      0  0021800549         2            12                   0
# 1          1      1  0021800549         4            10                   0
# 2          2      2  0021800549         7             1                  58
# 3          3      3  0021800549         8             1                   6
# 4          4      4  0021800549         9             2                  86
# 5          5      5  0021800549        10             4                   0
# 6          6      6  0021800549        11             1                 108
# 7          7      7  0021800549        13             1                  96
# 8          8      8  0021800549        15             6                   2
# 9          9      9  0021800549        17             3                  11
# 10        10     10  0021800549        18             4                   1
# 11        11     11  0021800549        19             3                  12
# 12        12     12  0021800549        20             4                   0
# 13        13     13  0021800549        21             1                 108
# 14        14     14  0021800549        23             2                   1
# 15        15     15  0021800549        24             4                   0
# 16        16     16  0021800549        25             5                  45
# 17        17     17  0021800549        26             2                   6
# 18        18     18  0021800549        28             4                   0
# 19        19     19  0021800549        30             6                   2
# 20        20     20  0021800549        32             3                  11
# 21        21     21  0021800549        33             4                   1
# 22        22     22  0021800549        34             3                  12
# 23        23     23  0021800549        35             1                  75
# 24        24     24  0021800549        36             2                   1
# 25        25     25  0021800549        37             4                   0
# 26        26     26  0021800549        38             1                   1
# 27        27     27  0021800549        40             2                   1
# 28        28     28  0021800549        41             4                   0
# 29        29     29  0021800549        42             2                  80
# ..       ...    ...         ...       ...           ...                 ...
# 460      125    460  0021800549       638             4                   1
# 461      126    461  0021800549       639             3                  12
# 462      127    462  0021800549       640             2                   1
# 463      128    463  0021800549       641             4                   0
# 464      129    464  0021800549       642             2                 102
# 465      130    465  0021800549       643             4                   0
# 466      131    466  0021800549       644             6                   2
# 467      132    467  0021800549       646             3                  11
# 468      133    468  0021800549       647             3                  12
# 469      134    469  0021800549       648             9                   1
# 470      135    470  0021800549       651             2                   1
# 471      136    471  0021800549       652             4                   0
# 472      137    472  0021800549       653             6                   3
# 473      138    473  0021800549       655             3                  11
# 474      139    474  0021800549       656             4                   1
# 475      140    475  0021800549       658             3                  12
# 476      141    476  0021800549       659             1                  73
# 477      142    477  0021800549       660             9                   1
# 478      143    478  0021800549       661             8                   0
# 479      144    479  0021800549       662             8                   0
# 480      145    480  0021800549       665             6                   1
# 481      146    481  0021800549       667             3                  11
# 482      147    482  0021800549       668             3                  12
# 483      148    483  0021800549       669             4                   0
# 484      149    484  0021800549       670             9                   1
# 485      150    485  0021800549       671             8                   0
# 486      151    486  0021800549       672             8                   0
# 487      152    487  0021800549       675             2                   1
# 488      153    488  0021800549       676             4                   0
# 489      154    489  0021800549       677            13                   0
#
#      period wctimestring pctimestring  \
# 0         1      7:41 PM        12:00
# 1         1      7:41 PM        12:00
# 2         1      7:41 PM        11:36
# 3         1      7:42 PM        11:23
# 26      Ibaka 24' 3PT Jump Shot (5 PTS) (Siakam 1 AST)               None
# 27                                                None               None
# 28                        Siakam REBOUND (Off:0 Def:3)               None
# 29               MISS VanVleet 23' Step Back Jump Shot               None
# ..                                                 ...                ...
# 460                                               None               None
# 461                                               None               None
# 462                          MISS Ibaka  3PT Jump Shot               None
# 463                        Green REBOUND (Off:2 Def:2)               None
# 464  MISS Leonard 26' 3PT Driving Floating Bank Jum...               None
# 465                       Siakam REBOUND (Off:1 Def:8)               None
# 466                                               None               None
# 467                  Siakam Free Throw 1 of 2 (27 PTS)               None
# 468                  Siakam Free Throw 2 of 2 (28 PTS)               None
# 469                                               None               None
# 470                                               None               None
# 471                                    RAPTORS Rebound               None
# 472                                               None               None
# 473                    MISS VanVleet Free Throw 1 of 2               None
# 474                                    RAPTORS Rebound               None
# 475                 VanVleet Free Throw 2 of 2 (8 PTS)               None
# 476                                               None               None
# 477          RAPTORS Timeout: Regular (Full 5 Short 0)               None
# 478                                               None               None
# 479                                               None               None
# 480                                               None               None
# 481                 Leonard Free Throw 1 of 2 (45 PTS)               None
# 482                     MISS Leonard Free Throw 2 of 2               None
# 483                                               None               None
# 484                                               None               None
# 485                                               None               None
# 486                                               None               None
# 487                                               None               None
# 488                       Siakam REBOUND (Off:1 Def:9)               None
# 489                                               None               None
#
#                                   visitordescription      score scoremargin  \
# 0                                               None       None        None
# 1                                               None       None        None
# 2                                               None      0 - 2           2
# 3                  Mitchell 1' Driving Layup (2 PTS)      2 - 2         TIE
# 4                                               None       None        None
# 5                       Gobert REBOUND (Off:0 Def:1)       None        None
# 6    Gobert  Cutting Dunk Shot (2 PTS) (Rubio 1 AST)      4 - 2          -2
# 7                                               None      4 - 4         TIE
# 8                                               None       None        None
# 9                      MISS Favors Free Throw 1 of 2       None        None
# 10                                      Jazz Rebound       None        None
# 11                     MISS Favors Free Throw 2 of 2       None        None
# 12                                              None       None        None
# 13                                              None      4 - 6           2
# 14                     MISS Ingles 24' 3PT Jump Shot       None        None
# 15                                              None       None        None
# 16                                              None       None        None
# 17                       MISS Rubio 1' Driving Layup       None        None
# 18                                      Jazz Rebound       None        None
# 19                                              None       None        None
# 20                     MISS Gobert Free Throw 1 of 2       None        None
# 21                                      Jazz Rebound       None        None
# 22                  Gobert Free Throw 2 of 2 (3 PTS)      5 - 6           1
# 23                                              None      5 - 8           3
# 24                      MISS Rubio 27' 3PT Jump Shot       None        None
# 25                                              None       None        None
# 26                                              None     5 - 11           6
# 27                          MISS Rubio 21' Jump Shot       None        None
# 28                                              None       None        None
# 29                                              None       None        None
# ..                                               ...        ...         ...
# 460                                     Jazz Rebound       None        None
# 461                 Rubio Free Throw 2 of 2 (12 PTS)  114 - 118           4
# 462                                             None       None        None
# 463                                             None       None        None
# 464                                             None       None        None
# 465                                             None       None        None
# 466             Mitchell S.FOUL (P2.PN) (T.Brothers)       None        None
# 467                                             None  114 - 119           5
# 468                                             None  114 - 120           6
# 469            Jazz Timeout: Regular (Reg.6 Short 0)       None        None
# 23    -14    -7    8    5  [TOR 8-5] VanVleet Driving Finger Roll Layup S...
# 24   -110   250    8    5                       [UTA] Rubio 3pt Shot: Missed
# 25   -110   250    8    5                 [TOR] Siakam Rebound (Off:0 Def:2)
# 26     89   228   11    5  [TOR 11-5] Ibaka 3pt Shot: Made (5 PTS) Assist...
# 27    -93   192   11    5                      [UTA] Rubio Jump Shot: Missed
# 28    -93   192   11    5                 [TOR] Siakam Rebound (Off:0 Def:3)
# 29     -8   229   11    5         [TOR] VanVleet Step Back Jump shot: Missed
# ..    ...   ...  ...  ...                                                ...
# 460     0   -80  118  113                                 [UTA] Team Rebound
# 461     0   -80  118  114     [UTA 114-118] Rubio Free Throw 2 of 2 (12 PTS)
# 462  -228    14  118  114                       [TOR] Ibaka 3pt Shot: Missed
# 463  -228    14  118  114                  [TOR] Green Rebound (Off:2 Def:2)
# 464  -185   187  118  114                     [TOR] Leonard 3pt Shot: Missed
# 465  -185   187  118  114                 [TOR] Siakam Rebound (Off:1 Def:8)
# 466   -28    48  118  114  [UTA] Mitchell Foul: Shooting (2 PF) (2 FTA) (...
# 467     0   -80  119  114    [TOR 119-114] Siakam Free Throw 1 of 2 (27 PTS)
# 468     0   -80  120  114    [TOR 120-114] Siakam Free Throw 2 of 2 (28 PTS)
# 469     0   -80  120  114                       [UTA] Team Timeout : Regular
# 470   185   225  120  114                    [UTA] Mitchell 3pt Shot: Missed
# 471   185   225  120  114                                 [TOR] Team Rebound
# 472  -110   839  120  114  [UTA] Crowder Foul: Loose Ball (3 PF) (2 FTA) ...
# 473     0   -80  120  114            [TOR] VanVleet Free Throw 1 of 2 Missed
# 474     0   -80  120  114                                 [TOR] Team Rebound
# 475     0   -80  121  114   [TOR 121-114] VanVleet Free Throw 2 of 2 (8 PTS)
# 476    -5    -7  121  116  [UTA 116-121] Rubio Driving Reverse Layup Shot...
# 477     0   -80  121  116                       [TOR] Team Timeout : Regular
# 478     0   -80  121  116      [UTA] Ingles Substitution replaced by O'Neale
# 479     0   -80  121  116          [UTA] Rubio Substitution replaced by Exum
# 480  -122   372  121  116  [UTA] Exum Foul: Personal (2 PF) (2 FTA) (S Tw...
# 481     0   -80  122  116   [TOR 122-116] Leonard Free Throw 1 of 2 (45 PTS)
# 482     0   -80  122  116             [TOR] Leonard Free Throw 2 of 2 Missed
# 483     0   -80  122  116               [UTA] Mitchell Rebound (Off:1 Def:3)
# 484     0   -80  122  116                       [UTA] Team Timeout : Regular
# 485     0   -80  122  116      [UTA] O'Neale Substitution replaced by Ingles
# 486     0   -80  122  116         [UTA] Exum Substitution replaced by Korver
# 487  -120   228  122  116                    [UTA] Mitchell 3pt Shot: Missed
# ...
# 464  Kawhi Leonard            202695    Serge Ibaka            201586
# 465  Kawhi Leonard            202695    Serge Ibaka            201586
# 466  Kawhi Leonard            202695    Serge Ibaka            201586
# 467  Kawhi Leonard            202695    Serge Ibaka            201586
# 468  Kawhi Leonard            202695    Serge Ibaka            201586
# 469  Kawhi Leonard            202695    Serge Ibaka            201586
# 476    Jae Crowder            203109     Joe Ingles            204060
# 477    Jae Crowder            203109     Joe Ingles            204060
# 478    Jae Crowder            203109  Royce O'Neale           1626220
# 479  Royce O'Neale           1626220     Dante Exum            203957
# 480  Royce O'Neale           1626220     Dante Exum            203957
# 481  Royce O'Neale           1626220     Dante Exum            203957
# 482  Royce O'Neale           1626220     Dante Exum            203957
# 483  Royce O'Neale           1626220     Dante Exum            203957
# 484  Royce O'Neale           1626220     Dante Exum            203957
# 485     Dante Exum            203957     Joe Ingles            204060
# 486     Joe Ingles            204060    Kyle Korver              2594
# 487     Joe Ingles            204060    Kyle Korver              2594
# 488     Joe Ingles            204060    Kyle Korver              2594
# 489     Joe Ingles            204060    Kyle Korver              2594
#
# [490 rows x 83 columns]

# %%
subs_df = test[(test.event_type_de == 'substitution')]
away_subs = subs_df[pd.isnull(subs_df['visitordescription']) == 0]
home_subs = subs_df[pd.isnull(subs_df['homedescription']) == 0]

#getting player ids of the players subbed into the game to check against later
#to determine starting lineups
away_subbed_players = list(away_subs['player2_id'].unique())
home_subbed_players = list(home_subs['player2_id'].unique())
#gets the index of the first sub for home and away to get the players who started
#the period by subsetting the dataframe to all actions before the first sub for
#each team
away_indexes = list(away_subs.index)
home_indexes = list(home_subs.index)
away_starting_line = list(test[(test.event_team == test['away_team_abbrev'].unique()[0])
                                       & (~pd.isnull(test['player1_name']))
                                       & (test['player1_team_abbreviation'] == test['away_team_abbrev'].unique()[0])
                                       & (test.is_block == 0)
                                       & (test.is_steal == 0)]
                                        .loc[:away_indexes[0], :]['player1_id'].unique())

# %%
away_starting_line
# Out:
# [1628378, 203497, 202324, 204060, 201937]

# %%
blah = test[(test['event_team'] == test['away_team_abbrev'].unique()[0]) 
            & (~pd.isnull(test['player1_name'])) 
           
            #& (test['player1_team_abbreviation'] == test['away_team_abbrev'].unique()[0])
            ]
'''
& (test['player1_team_abbreviation'] == test['away_team_abbrev'].unique()[0])
& (test.is_block == 0)
& (test.is_steal == 0)
 & (test.is_block == 0)
            & (test.is_steal == 0)]
'''
# Out:
# "\n& (test['player1_team_abbreviation'] == test['away_team_abbrev'].unique()[0])\n& (test.is_block == 0)\n& (test.is_steal == 0)\n & (test.is_block == 0)\n            & (test.is_steal == 0)]\n"

# %%
blah
# Out:
#         game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 1    0021800549         4            10                   0       1
# 2    0021800549         7             1                  58       1
# 4    0021800549         9             2                  86       1
# 7    0021800549        13             1                  96       1
# 8    0021800549        15             6                   2       1
# 12   0021800549        20             4                   0       1
# 13   0021800549        21             1                 108       1
# 15   0021800549        24             4                   0       1
# 16   0021800549        25             5                  45       1
# 17   0021800549        26             2                   6       1
# 19   0021800549        30             6                   2       1
# 23   0021800549        35             1                  75       1
# 25   0021800549        37             4                   0       1
# 26   0021800549        38             1                   1       1
# 28   0021800549        41             4                   0       1
# 29   0021800549        42             2                  80       1
# 32   0021800549        45             4                   0       1
# 33   0021800549        46             1                  79       1
# 36   0021800549        49             4                   0       1
# 37   0021800549        50             2                  57       1
# 40   0021800549        55             2                  57       1
# 43   0021800549        58             4                   0       1
# 467      9:52 PM         0:23
# 468      9:52 PM         0:23
# 473      9:55 PM         0:18
# 475      9:55 PM         0:18
# 481      9:57 PM         0:07
# 482      9:58 PM         0:07
# 488     10:00 PM         0:01
#
#                                        homedescription neutraldescription  \
# 1            Jump Ball Ibaka vs. Gobert: Tip to Siakam               None
# 2                Ibaka 2' Turnaround Hook Shot (2 PTS)               None
# 4              MISS Ibaka 11' Turnaround Fadeaway Shot               None
# 7    Green 1' Turnaround Bank Hook Shot (2 PTS) (Va...               None
# 8                    Siakam S.FOUL (P1.T1) (M.Lindsay)               None
# 12                        Siakam REBOUND (Off:0 Def:1)               None
# 13   Siakam  Cutting Dunk Shot (2 PTS) (VanVleet 2 ...               None
# 15                      VanVleet REBOUND (Off:0 Def:1)               None
# 16   Leonard Out of Bounds - Bad Pass Turnover Turn...               None
# 17                                 Ibaka BLOCK (1 BLK)               None
# 19                  Ibaka S.FOUL (P1.T2) (S.Twardoski)               None
# 23       VanVleet 2' Driving Finger Roll Layup (2 PTS)               None
# 25                        Siakam REBOUND (Off:0 Def:2)               None
# 26      Ibaka 24' 3PT Jump Shot (5 PTS) (Siakam 1 AST)               None
# 28                        Siakam REBOUND (Off:0 Def:3)               None
# 29               MISS VanVleet 23' Step Back Jump Shot               None
# 32                       Leonard REBOUND (Off:0 Def:1)               None
# 33                Leonard 19' Pullup Jump Shot (2 PTS)               None
# 36                         Ibaka REBOUND (Off:0 Def:1)               None
# 37                    MISS Siakam 4' Driving Hook Shot               None
# 40                   MISS Leonard 5' Driving Hook Shot               None
# 43                         Ibaka REBOUND (Off:0 Def:2)               None
# 44                  VanVleet Bad Pass Turnover (P1.T2)               None
# 46                    Green Lost Ball Turnover (P1.T3)               None
# 47                  Green P.FOUL (P1.T3) (S.Twardoski)               None
# 51                         Ibaka REBOUND (Off:0 Def:3)               None
# 53                   Leonard Free Throw 1 of 2 (3 PTS)               None
# 54                              SUB: Anunoby FOR Green               None
# 55                              SUB: Powell FOR Siakam               None
# 56                   Leonard Free Throw 2 of 2 (4 PTS)               None
# ..                                                 ...                ...
# 422                 Leonard Free Throw 1 of 2 (37 PTS)               None
# 423                              SUB: Green FOR Wright               None
# 424                 Leonard Free Throw 2 of 2 (38 PTS)               None
# 427                      Leonard REBOUND (Off:0 Def:6)               None
# 428          Leonard 2' Driving Reverse Layup (40 PTS)               None
# 429                  Green S.FOUL (P4.T4) (T.Brothers)               None
# 433                 Leonard Free Throw 1 of 2 (41 PTS)               None
# 434                 Leonard Free Throw 2 of 2 (42 PTS)               None
# 436                       Siakam REBOUND (Off:0 Def:8)               None
# 437                 MISS Ibaka 4' Turnaround Jump Shot               None
# 439                         MISS Siakam  3PT Jump Shot               None
# 442                       MISS Ibaka Free Throw 1 of 2               None
# 444                    Ibaka Free Throw 2 of 2 (8 PTS)               None
# 446                Leonard 8' Fadeaway Jumper (44 PTS)               None
# 447                   Ibaka S.FOUL (P3.PN) (M.Lindsay)               None
# 451                       MISS Ibaka Free Throw 1 of 2               None
# 453                       MISS Ibaka Free Throw 2 of 2               None
# 456                          MISS Green  3PT Jump Shot               None
# 458                 Ibaka L.B.FOUL (P4.PN) (M.Lindsay)               None
# 462                          MISS Ibaka  3PT Jump Shot               None
# 463                        Green REBOUND (Off:2 Def:2)               None
# 464  MISS Leonard 26' 3PT Driving Floating Bank Jum...               None
# 465                       Siakam REBOUND (Off:1 Def:8)               None
# 467                  Siakam Free Throw 1 of 2 (27 PTS)               None
# 468                  Siakam Free Throw 2 of 2 (28 PTS)               None
# 473                    MISS VanVleet Free Throw 1 of 2               None
# 475                 VanVleet Free Throw 2 of 2 (8 PTS)               None
# 481                 Leonard Free Throw 1 of 2 (45 PTS)               None
# 482                     MISS Leonard Free Throw 2 of 2               None
# 488                       Siakam REBOUND (Off:1 Def:9)               None
#
#               visitordescription      score scoremargin  person1type  \
# 1                           None       None        None            4
# 2                           None      0 - 2           2            4
# 4                           None       None        None            4
# 7                           None      4 - 4         TIE            4
# 8                           None       None        None            4
# 12                          None       None        None            4
# 13                          None      4 - 6           2            4
# 15                          None       None        None            4
# 16                          None       None        None            4
# 17   MISS Rubio 1' Driving Layup       None        None            5
# 19                          None       None        None            4
# 23                          None      5 - 8           3            4
# 25                          None       None        None            4
# 26                          None     5 - 11           6            4
# 28                          None       None        None            4
# 29                          None       None        None            4
# 32                          None       None        None            4
# 33                          None     5 - 13           8            4
# 36                          None       None        None            4
# 37          Favors BLOCK (1 BLK)       None        None            4
# 40                          None       None        None            4
# 43                          None       None        None            4
# 44          Gobert STEAL (1 STL)       None        None            4
# 46          Ingles STEAL (1 STL)       None        None            4
# 47                          None       None        None            4
# 51                          None       None        None            4
# 53                          None     9 - 14           5            4
# 54                          None       None        None            4
# 55                          None       None        None            4
# 56                          None     9 - 15           6            4
# ..                           ...        ...         ...          ...
# 422                         None  105 - 110           5            4
# 423                         None       None        None            4
# 424                         None  105 - 111           6            4
# 427                         None       None        None            4
# 428                         None  105 - 113           8            4
# 429                         None       None        None            4
# 433                         None  107 - 114           7            4
# 434                         None  107 - 115           8            4
# 436                         None       None        None            4
# 437          Rubio BLOCK (1 BLK)       None        None            4
# 439                         None       None        None            4
# 442                         None       None        None            4
# 444                         None  107 - 116           9            4
# 446                         None  109 - 118           9            4
# 447                         None       None        None            4
# 451                         None       None        None            4
# 453                         None       None        None            4
# 456                         None       None        None            4
# 458                         None       None        None            4
# 462                         None       None        None            4
# 463                         None       None        None            4
# 464                         None       None        None            4
# 465                         None       None        None            4
# 467                         None  114 - 119           5            4
# 468                         None  114 - 120           6            4
# 473                         None       None        None            4
# 475                         None  114 - 121           7            4
# 481                         None  116 - 122           6            4
# 482                         None       None        None            4
# 488                         None       None        None            4
#
#      player1_id   player1_name  player1_team_id player1_team_city  \
# 1        201586    Serge Ibaka     1.610613e+09           Toronto
# 2        201586    Serge Ibaka     1.610613e+09           Toronto
# 4        201586    Serge Ibaka     1.610613e+09           Toronto
# 7        201980    Danny Green     1.610613e+09           Toronto
# 8       1627783  Pascal Siakam     1.610613e+09           Toronto
# 12      1627783  Pascal Siakam     1.610613e+09           Toronto
# 473                  None                      None            0           0
# 475                  None                      None            0           0
# 481                  None                      None            0           0
# 482                  None                      None            0           0
# 488                  None                      None            0           0
#
#        player3_name  player3_team_id player3_team_city player3_team_nickname  \
# 1     Pascal Siakam     1.610613e+09           Toronto               Raptors
# 2              None              NaN              None                  None
# 4              None              NaN              None                  None
# 7              None              NaN              None                  None
# 8              None              NaN              None                  None
# 12             None              NaN              None                  None
# 13             None              NaN              None                  None
# 15             None              NaN              None                  None
# 16             None              NaN              None                  None
# 17      Serge Ibaka     1.610613e+09           Toronto               Raptors
# 19             None              NaN              None                  None
# 23             None              NaN              None                  None
# 25             None              NaN              None                  None
# 26             None              NaN              None                  None
# 28             None              NaN              None                  None
# 29             None              NaN              None                  None
# 32             None              NaN              None                  None
# 33             None              NaN              None                  None
# 36             None              NaN              None                  None
# 37   Derrick Favors     1.610613e+09              Utah                  Jazz
# 40             None              NaN              None                  None
# 43             None              NaN              None                  None
# 44             None              NaN              None                  None
# 46             None              NaN              None                  None
# 47             None              NaN              None                  None
# 51             None              NaN              None                  None
# 53             None              NaN              None                  None
# 54             None              NaN              None                  None
# 55             None              NaN              None                  None
# 56             None              NaN              None                  None
# ..              ...              ...               ...                   ...
# 422            None              NaN              None                  None
# 423            None              NaN              None                  None
# 424            None              NaN              None                  None
# 427            None              NaN              None                  None
# 428            None              NaN              None                  None
# 429            None              NaN              None                  None
# 433            None              NaN              None                  None
# 434            None              NaN              None                  None
# 436            None              NaN              None                  None
# 437     Ricky Rubio     1.610613e+09              Utah                  Jazz
# 439            None              NaN              None                  None
# 442            None              NaN              None                  None
# 444            None              NaN              None                  None
# 446            None              NaN              None                  None
# 447            None              NaN              None                  None
# 451            None              NaN              None                  None
# 453            None              NaN              None                  None
# 456            None              NaN              None                  None
# 458            None              NaN              None                  None
# 462            None              NaN              None                  None
# 463            None              NaN              None                  None
# 464            None              NaN              None                  None
# 465            None              NaN              None                  None
# 467            None              NaN              None                  None
# 468            None              NaN              None                  None
# 473            None              NaN              None                  None
# 475            None              NaN              None                  None
# 481            None              NaN              None                  None
# 482            None              NaN              None                  None
# 488            None              NaN              None                  None
#
#     player3_team_abbreviation  evt  locX  locY   hs   vs  \
# 1                         TOR    4     0   -80    0    0
# 2                        None    7     1    20    2    0
# 4                        None    9   107    -3    2    2
# 7                        None   13    12     2    4    4
# 8                        None   15     8    10    4    4
# 12                       None   20     0   -80    4    4
# 13                       None   21     2     3    6    4
# 15                       None   24   231    50    6    4
# 16                       None   25    28    82    6    4
# 17                        TOR   26    -7     6    6    4
# 19                       None   30   -13    16    6    4
# 23                       None   35   -14    -7    8    5
# 25                       None   37  -110   250    8    5
# 26                       None   38    89   228   11    5
# 28                       None   41   -93   192   11    5
# 29                       None   42    -8   229   11    5
# 32                       None   45  -172   200   11    5
# 33                       None   46    74   177   13    5
# 36                       None   49  -106   247   13    5
# 37                        UTA   50    30    30   13    5
# 40                       None   55    27    38   13    7
# 43                       None   58   230     9   13    7
# 44                       None   59    43    -2   13    7
# 46                       None   63    11   108   13    9
# 47                       None   65   -16   734   13    9
# 51                       None   72   112   157   13    9
# 53                       None   75     0   -80   14    9
# 54                       None   76     0   -80   14    9
# 55                       None   77     0   -80   14    9
# 56                       None   80     0   -80   15    9
# ..                        ...  ...   ...   ...  ...  ...
# 422                      None  590     0   -80  110  105
# 423                      None  591     0   -80  110  105
# 424                      None  593     0   -80  111  105
# 427                      None  596  -228     4  111  105
# 428                      None  597   -14     9  113  105
# 429                      None  598     5     3  113  105
# 433                      None  604     0   -80  114  107
# 434                      None  605     0   -80  115  107
# 436                      None  607  -234    -2  115  107
# 437                       UTA  608    -9    40  115  107
# 439                      None  612  -230     3  115  107
# 442                      None  616     0   -80  115  107
# 444                      None  618     0   -80  116  107
# 446                      None  620   -78    27  118  109
# 447                      None  621    23     8  118  109
# 451                      None  627     0   -80  118  111
# 453                      None  629     0   -80  118  111
# 456                      None  633   233     4  118  113
# 458                      None  635     1   817  118  113
# 462                      None  640  -228    14  118  114
# 463                      None  641  -228    14  118  114
# 464                      None  642  -185   187  118  114
# 465                      None  643  -185   187  118  114
# 467                      None  646     0   -80  119  114
# 468                      None  647     0   -80  120  114
# 473                      None  655     0   -80  120  114
# 475                      None  658     0   -80  121  114
# 481                      None  667     0   -80  122  116
# 482                      None  668     0   -80  122  116
# 488                      None  676  -120   228  122  116
#
#                                                     de home_team_abbrev  \
# 1    Jump Ball Ibaka vs Gobert (Siakam gains posses...              TOR
# 2    [TOR 2-0] Ibaka Turnaround Hook Shot: Made (2 ...              TOR
# 4         [TOR] Ibaka Turnaround Fadeaway shot: Missed              TOR
# 7    [TOR 4-4] Green Turnaround Bank Hook Shot: Mad...              TOR
# 8    [TOR] Siakam Foul: Shooting (1 PF) (2 FTA) (M ...              TOR
# 12                  [TOR] Siakam Rebound (Off:0 Def:1)              TOR
# 13   [TOR 6-4] Siakam Cutting Dunk Shot: Made (2 PT...              TOR
# 15                [TOR] VanVleet Rebound (Off:0 Def:1)              TOR
# 16   [TOR] Leonard Turnover : Out of Bounds - Bad P...              TOR
# 17              [UTA] Rubio Driving Layup Shot: Missed              TOR
# 19   [TOR] Ibaka Foul: Shooting (1 PF) (2 FTA) (S T...              TOR
# 23   [TOR 8-5] VanVleet Driving Finger Roll Layup S...              TOR
# 25                  [TOR] Siakam Rebound (Off:0 Def:2)              TOR
# 26   [TOR 11-5] Ibaka 3pt Shot: Made (5 PTS) Assist...              TOR
# 28                  [TOR] Siakam Rebound (Off:0 Def:3)              TOR
# 29          [TOR] VanVleet Step Back Jump shot: Missed              TOR
# 32                 [TOR] Leonard Rebound (Off:0 Def:1)              TOR
# 33   [TOR 13-5] Leonard Pullup Jump shot: Made (2 PTS)              TOR
# 36                   [TOR] Ibaka Rebound (Off:0 Def:1)              TOR
# 37              [TOR] Siakam Driving Hook Shot: Missed              TOR
# 40             [TOR] Leonard Driving Hook Shot: Missed              TOR
# 43                   [TOR] Ibaka Rebound (Off:0 Def:2)              TOR
# 44   [TOR] VanVleet Turnover : Bad Pass (1 TO) Stea...              TOR
# 46   [TOR] Green Turnover : Lost Ball (1 TO) Steal:...              TOR
# 47     [TOR] Green Foul: Personal (1 PF) (S Twardoski)              TOR
# 51                   [TOR] Ibaka Rebound (Off:0 Def:3)              TOR
# 53        [TOR 14-9] Leonard Free Throw 1 of 2 (3 PTS)              TOR
# 54        [TOR] Green Substitution replaced by Anunoby              TOR
# 55        [TOR] Siakam Substitution replaced by Powell              TOR
# 56        [TOR 15-9] Leonard Free Throw 2 of 2 (4 PTS)              TOR
# ..                                                 ...              ...
# 422   [TOR 110-105] Leonard Free Throw 1 of 2 (37 PTS)              TOR
# 423        [TOR] Wright Substitution replaced by Green              TOR
# 424   [TOR 111-105] Leonard Free Throw 2 of 2 (38 PTS)              TOR
# 427                [TOR] Leonard Rebound (Off:0 Def:6)              TOR
# 428  [TOR 113-105] Leonard Driving Reverse Layup Sh...              TOR
# 429  [TOR] Green Foul: Shooting (4 PF) (2 FTA) (T B...              TOR
# 433   [TOR 114-107] Leonard Free Throw 1 of 2 (41 PTS)              TOR
# 434   [TOR 115-107] Leonard Free Throw 2 of 2 (42 PTS)              TOR
# 436                 [TOR] Siakam Rebound (Off:0 Def:8)              TOR
# 437           [TOR] Ibaka Turnaround Jump Shot: Missed              TOR
# 439                      [TOR] Siakam 3pt Shot: Missed              TOR
# 442               [TOR] Ibaka Free Throw 1 of 2 Missed              TOR
# 444      [TOR 116-107] Ibaka Free Throw 2 of 2 (8 PTS)              TOR
# 446  [TOR 118-109] Leonard Fadeaway Jump Shot: Made...              TOR
# 447  [TOR] Ibaka Foul: Shooting (4 PF) (2 FTA) (M L...              TOR
# 451               [TOR] Ibaka Free Throw 1 of 2 Missed              TOR
# 453               [TOR] Ibaka Free Throw 2 of 2 Missed              TOR
# 456                       [TOR] Green 3pt Shot: Missed              TOR
# 458  [TOR] Ibaka Foul: Loose Ball (5 PF) (2 FTA) (M...              TOR
# 462                       [TOR] Ibaka 3pt Shot: Missed              TOR
# 463                  [TOR] Green Rebound (Off:2 Def:2)              TOR
# 464                     [TOR] Leonard 3pt Shot: Missed              TOR
# 465                 [TOR] Siakam Rebound (Off:1 Def:8)              TOR
# 467    [TOR 119-114] Siakam Free Throw 1 of 2 (27 PTS)              TOR
# 468    [TOR 120-114] Siakam Free Throw 2 of 2 (28 PTS)              TOR
# 473            [TOR] VanVleet Free Throw 1 of 2 Missed              TOR
# 475   [TOR 121-114] VanVleet Free Throw 2 of 2 (8 PTS)              TOR
# 481   [TOR 122-116] Leonard Free Throw 1 of 2 (45 PTS)              TOR
# 482             [TOR] Leonard Free Throw 2 of 2 Missed              TOR
# 488                 [TOR] Siakam Rebound (Off:1 Def:9)              TOR
#
#     away_team_abbrev  game_date  season  home_team_id  away_team_id  \
# 1                UTA 2019-01-01    2019    1610612761    1610612762
# 2                UTA 2019-01-01    2019    1610612761    1610612762
# 4                UTA 2019-01-01    2019    1610612761    1610612762
# 7                UTA 2019-01-01    2019    1610612761    1610612762
# 8                UTA 2019-01-01    2019    1610612761    1610612762
# 12               UTA 2019-01-01    2019    1610612761    1610612762
# 13               UTA 2019-01-01    2019    1610612761    1610612762
# 15               UTA 2019-01-01    2019    1610612761    1610612762
# 16               UTA 2019-01-01    2019    1610612761    1610612762
# 17               UTA 2019-01-01    2019    1610612761    1610612762
# 19               UTA 2019-01-01    2019    1610612761    1610612762
# 23               UTA 2019-01-01    2019    1610612761    1610612762
# 25               UTA 2019-01-01    2019    1610612761    1610612762
# ...
# 458              UTA 2019-01-01    2019    1610612761    1610612762
# 462              UTA 2019-01-01    2019    1610612761    1610612762
# 463              UTA 2019-01-01    2019    1610612761    1610612762
# 464              UTA 2019-01-01    2019    1610612761    1610612762
# 465              UTA 2019-01-01    2019    1610612761    1610612762
# 467              UTA 2019-01-01    2019    1610612761    1610612762
# 468              UTA 2019-01-01    2019    1610612761    1610612762
# 473              UTA 2019-01-01    2019    1610612761    1610612762
# 475              UTA 2019-01-01    2019    1610612761    1610612762
# 481              UTA 2019-01-01    2019    1610612761    1610612762
# 482              UTA 2019-01-01    2019    1610612761    1610612762
# 488              UTA 2019-01-01    2019    1610612761    1610612762
#
#     event_team event_type_de                          shot_type_de  shot_made  \
# 1          UTA     jump-ball                                   NaN        NaN
# 2          UTA          shot                  turnaround hook shot        1.0
# 4          UTA   missed_shot                   turnaround fadeaway        0.0
# 7          UTA          shot             turnaround bank hook shot        1.0
# 8          UTA          foul                                   NaN        NaN
# 12         UTA       rebound                                   NaN        NaN
# 13         UTA          shot                     cutting dunk shot        1.0
# 15         UTA       rebound                                   NaN        NaN
# 16         UTA      turnover                                   NaN        NaN
# 17         UTA   missed_shot                         driving layup        0.0
# 19         UTA          foul                                   NaN        NaN
# 23         UTA          shot             driving finger roll layup        1.0
# 25         UTA       rebound                                   NaN        NaN
# 26         UTA          shot                             jump shot        1.0
# 28         UTA       rebound                                   NaN        NaN
# 29         UTA   missed_shot                              3pt shot        0.0
# 32         UTA       rebound                                   NaN        NaN
# 33         UTA          shot                              3pt shot        1.0
# 36         UTA       rebound                                   NaN        NaN
# 37         UTA   missed_shot                     driving hook shot        0.0
# 40         UTA   missed_shot                     driving hook shot        0.0
# 43         UTA       rebound                                   NaN        NaN
# 44         UTA      turnover                                   NaN        NaN
# 46         UTA      turnover                                   NaN        NaN
# 47         UTA          foul                                   NaN        NaN
# 51         UTA       rebound                                   NaN        NaN
# 53         UTA    free-throw                                   NaN        1.0
# 54         UTA  substitution                                   NaN        NaN
# 55         UTA  substitution                                   NaN        NaN
# 56         UTA    free-throw                                   NaN        1.0
# ..         ...           ...                                   ...        ...
# 422        UTA    free-throw                                   NaN        1.0
# 423        UTA  substitution                                   NaN        NaN
# 424        UTA    free-throw                                   NaN        1.0
# 427        UTA       rebound                                   NaN        NaN
# 428        UTA          shot                 driving reverse layup        1.0
# 429        UTA          foul                                   NaN        NaN
# 433        UTA    free-throw                                   NaN        1.0
# 434        UTA    free-throw                                   NaN        1.0
# 436        UTA       rebound                                   NaN        NaN
# 437        UTA   missed_shot                  turnaround jump shot        0.0
# 439        UTA   missed_shot                             jump shot        0.0
# 442        UTA    free-throw                                   NaN        0.0
# 444        UTA    free-throw                                   NaN        1.0
# 446        UTA          shot                    fadeaway jump shot        1.0
# 447        UTA          foul                                   NaN        NaN
# 451        UTA    free-throw                                   NaN        0.0
# 453        UTA    free-throw                                   NaN        0.0
# 456        UTA   missed_shot                             jump shot        0.0
# 458        UTA          foul                                   NaN        NaN
# 462        UTA   missed_shot                             jump shot        0.0
# 463        UTA       rebound                                   NaN        NaN
# 464        UTA   missed_shot  driving floating bank shot jump shot        0.0
# 465        UTA       rebound                                   NaN        NaN
# 467        UTA    free-throw                                   NaN        1.0
# 468        UTA    free-throw                                   NaN        1.0
# 473        UTA    free-throw                                   NaN        0.0
# 475        UTA    free-throw                                   NaN        1.0
# 481        UTA    free-throw                                   NaN        1.0
# 482        UTA    free-throw                                   NaN        0.0
# 488        UTA       rebound                                   NaN        NaN
#
#      is_block shot_type  seconds_elapsed  event_length  is_three  points_made  \
# 1           0       NaN                0           0.0         0            0
# 2           0      hook               24          24.0         0            2
# 4           0      jump               57          20.0         0            0
# 7           0      hook               86          16.0         0            2
# 8           0       NaN              103          17.0         0            0
# 12          0       NaN              106           3.0         0            0
# 13          0      dunk              115           9.0         0            2
# 15          0       NaN              131           3.0         0            0
# 16          0       NaN              141          10.0         0            0
# 17          1     layup              155          14.0         0            0
# 19          0       NaN              163           8.0         0            0
# 23          0     layup              179          16.0         0            2
# 25          0       NaN              201           3.0         0            0
# 26          0      jump              210           9.0         1            3
# 28          0       NaN              232           3.0         0            0
# 29          0      jump              241           9.0         0            0
# 32          0       NaN              265           3.0         0            0
# 33          0      jump              272           7.0         0            2
# 36          0       NaN              290           3.0         0            0
# 37          1      hook              297           7.0         0            0
# 40          0      hook              326          17.0         0            0
# 43          0       NaN              348           3.0         0            0
# 44          0       NaN              359          11.0         0            0
# 46          0       NaN              385          19.0         0            0
# 47          0       NaN              385           0.0         0            0
# 51          0       NaN              402           2.0         0            0
# 53          0      free              412           0.0         0            1
# 54          0       NaN              412           0.0         0            0
# 55          0       NaN              412           0.0         0            0
# 56          0      free              412           0.0         0            1
# ..        ...       ...              ...           ...       ...          ...
# 422         0      free             2649           0.0         0            1
# 423         0       NaN             2649           0.0         0            0
# 424         0      free             2649           0.0         0            1
# 427         0       NaN             2661           2.0         0            0
# 428         0     layup             2670           9.0         0            2
# 429         0       NaN             2685          15.0         0            0
# 433         0      free             2697           0.0         0            1
# 434         0      free             2697           0.0         0            1
# 436         0       NaN             2720           6.0         0            0
# 437         1      jump             2730          10.0         0            0
# 439         0      jump             2741          11.0         1            0
# 442         0      free             2742           0.0         0            1
# 444         0      free             2742           0.0         0            1
# 446         0      jump             2768          17.0         0            2
# 447         0       NaN             2774           6.0         0            0
# 451         0      free             2791           0.0         0            1
# 453         0      free             2791           0.0         0            1
# 456         0      jump             2823          19.0         1            0
# 458         0       NaN             2824           0.0         0            0
# 462         0      jump             2841          17.0         1            0
# 463         0       NaN             2844           3.0         0            0
# 464         0      jump             2855          11.0         1            0
# 465         0       NaN             2857           2.0         0            0
#     'VISITORDESCRIPTION',
#     'SCORE',
#     'SCOREMARGIN',
#     'PERSON1TYPE',
#     'PLAYER1_ID',
#     'PLAYER1_NAME',
#     'PLAYER1_TEAM_ID',
#     'PLAYER1_TEAM_CITY',
#     'PLAYER1_TEAM_NICKNAME',
#     'PLAYER1_TEAM_ABBREVIATION',
#     'PERSON2TYPE',
#     'PLAYER2_ID',
#     'PLAYER2_NAME',
#     'PLAYER2_TEAM_ID',
#     'PLAYER2_TEAM_CITY',
#     'PLAYER2_TEAM_NICKNAME',
#     'PLAYER2_TEAM_ABBREVIATION',
#     'PERSON3TYPE',
#     'PLAYER3_ID',
#     'PLAYER3_NAME',
#     'PLAYER3_TEAM_ID',
#     'PLAYER3_TEAM_CITY',
#     'PLAYER3_TEAM_NICKNAME',
#     'PLAYER3_TEAM_ABBREVIATION'],
#    'rowSet': [['0021800549',
#      2,
#      12,
#      0,
#      1,
#      '7:41 PM',
#      '12:00',
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      4,
#      10,
#      0,
#      1,
#      '7:41 PM',
#      '12:00',
#      'Jump Ball Ibaka vs. Gobert: Tip to Siakam',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR'],
#     ['0021800549',
#      7,
#      1,
#      58,
#      1,
#      '7:41 PM',
#      '11:36',
#      "Ibaka 2' Turnaround Hook Shot (2 PTS)",
#      None,
#      None,
#      '0 - 2',
#      '2',
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      8,
#      1,
#      6,
#      1,
#      '7:42 PM',
#      '11:23',
#      None,
#      None,
#      "Mitchell 1' Driving Layup (2 PTS)",
#      '2 - 2',
#      'TIE',
#      5,
#      1628378,
#      'Donovan Mitchell',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      9,
#      2,
#      86,
#      1,
#      '7:42 PM',
#      '11:03',
#      "MISS Ibaka 11' Turnaround Fadeaway Shot",
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      10,
#      4,
#      0,
#      1,
#      '7:42 PM',
#      '11:00',
#      None,
#      None,
#      'Gobert REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      11,
#      1,
#      108,
#      1,
#      '7:42 PM',
#      '10:50',
#      None,
#      None,
#      'Gobert  Cutting Dunk Shot (2 PTS) (Rubio 1 AST)',
#      '4 - 2',
#      '-2',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      13,
#      1,
#      96,
#      1,
#      '7:42 PM',
#      '10:34',
#      "Green 1' Turnaround Bank Hook Shot (2 PTS) (VanVleet 1 AST)",
#      None,
#      None,
#      '4 - 4',
#      'TIE',
#      4,
#      201980,
#      'Danny Green',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      15,
#      6,
#      2,
#      1,
#      '7:43 PM',
#      '10:17',
#      'Siakam S.FOUL (P1.T1) (M.Lindsay)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      17,
#      3,
#      11,
#      1,
#      '7:43 PM',
#      '10:17',
#      None,
#      None,
#      'MISS Favors Free Throw 1 of 2',
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      18,
#      4,
#      1,
#      1,
#      '7:43 PM',
#      '10:17',
#      None,
#      None,
#      'Jazz Rebound',
#      None,
#      None,
#      3,
#      1610612762,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      19,
#      3,
#      12,
#      1,
#      '7:44 PM',
#      '10:17',
#      None,
#      None,
#      'MISS Favors Free Throw 2 of 2',
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      20,
#      4,
#      0,
#      1,
#      '7:44 PM',
#      '10:14',
#      'Siakam REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      21,
#      1,
#      108,
#      1,
#      '7:44 PM',
#      '10:05',
#      'Siakam  Cutting Dunk Shot (2 PTS) (VanVleet 2 AST)',
#      None,
#      None,
#      '4 - 6',
#      '2',
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      23,
#      2,
#      1,
#      1,
#      '7:44 PM',
#      '9:52',
#      None,
#      None,
#      "MISS Ingles 24' 3PT Jump Shot",
#      None,
#      None,
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      24,
#      4,
#      0,
#      1,
#      '7:44 PM',
#      '9:49',
#      'VanVleet REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      25,
#      5,
#      45,
#      1,
#      '7:44 PM',
#      '9:39',
#      'Leonard Out of Bounds - Bad Pass Turnover Turnover (P1.T1)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      26,
#      2,
#      6,
#      1,
#      '7:45 PM',
#      '9:25',
#      'Ibaka BLOCK (1 BLK)',
#      None,
#      "MISS Rubio 1' Driving Layup",
#      None,
#      None,
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR'],
#     ['0021800549',
#      28,
#      4,
#      0,
#      1,
#      '7:45 PM',
#      '9:25',
#      None,
#      None,
#      'Jazz Rebound',
#      None,
#      None,
#      3,
#      1610612762,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      30,
#      6,
#      2,
#      1,
#      '7:45 PM',
#      '9:17',
#      'Ibaka S.FOUL (P1.T2) (S.Twardoski)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      32,
#      3,
#      11,
#      1,
#      '7:46 PM',
#      '9:17',
#      None,
#      None,
#      'MISS Gobert Free Throw 1 of 2',
#      None,
#      None,
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      33,
#      4,
#      1,
#      1,
#      '7:46 PM',
#      '9:17',
#      None,
#      None,
#      'Jazz Rebound',
#      None,
#      None,
#      3,
#      1610612762,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      34,
#      3,
#      12,
#      1,
#      '7:46 PM',
#      '9:17',
#      None,
#      None,
#      'Gobert Free Throw 2 of 2 (3 PTS)',
#      '5 - 6',
#      '1',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      35,
#      1,
#      75,
#      1,
#      '7:46 PM',
#      '9:01',
#      "VanVleet 2' Driving Finger Roll Layup (2 PTS)",
#      None,
#      None,
#      '5 - 8',
#      '3',
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      36,
#      2,
#      1,
#      1,
#      '7:46 PM',
#      '8:42',
#      None,
#      None,
#      "MISS Rubio 27' 3PT Jump Shot",
#      None,
#      None,
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      37,
#      4,
#      0,
#      1,
#      '7:46 PM',
#      '8:39',
#      'Siakam REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      38,
#      1,
#      1,
#      1,
#      '7:47 PM',
#      '8:30',
#      "Ibaka 24' 3PT Jump Shot (5 PTS) (Siakam 1 AST)",
#      None,
#      None,
#      '5 - 11',
#      '6',
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      40,
#      2,
#      1,
#      1,
#      '7:47 PM',
#      '8:11',
#      None,
#      None,
#      "MISS Rubio 21' Jump Shot",
#      None,
#      None,
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      41,
#      4,
#      0,
#      1,
#      '7:47 PM',
#      '8:08',
#      'Siakam REBOUND (Off:0 Def:3)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      42,
#      2,
#      80,
#      1,
#      '7:47 PM',
#      '7:59',
#      "MISS VanVleet 23' Step Back Jump Shot",
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      43,
#      4,
#      0,
#      1,
#      '7:47 PM',
#      '7:57',
#      None,
#      None,
#      'Gobert REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      44,
#      2,
#      80,
#      1,
#      '7:48 PM',
#      '7:38',
#      None,
#      None,
#      "MISS Ingles 26' 3PT Step Back Jump Shot",
#      None,
#      None,
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      45,
#      4,
#      0,
#      1,
#      '7:48 PM',
#      '7:35',
#      'Leonard REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      46,
#      1,
#      79,
#      1,
#      '7:48 PM',
#      '7:28',
#      "Leonard 19' Pullup Jump Shot (2 PTS)",
#      None,
#      None,
#      '5 - 13',
#      '8',
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      47,
#      9,
#      1,
#      1,
#      '7:48 PM',
#      '7:27',
#      None,
#      None,
#      'Jazz Timeout: Regular (Reg.1 Short 0)',
#      None,
#      None,
#      3,
#      1610612762,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      48,
#      2,
#      1,
#      1,
#      '7:51 PM',
#      '7:13',
#      None,
#      None,
#      "MISS Mitchell 27' 3PT Jump Shot",
#      None,
#      None,
#      5,
#      1628378,
#      'Donovan Mitchell',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      49,
#      4,
#      0,
#      1,
#      '7:51 PM',
#      '7:10',
#      'Ibaka REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      50,
#      2,
#      57,
#      1,
#      '7:51 PM',
#      '7:03',
#      "MISS Siakam 4' Driving Hook Shot",
#      None,
#      'Favors BLOCK (1 BLK)',
#      None,
#      None,
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA'],
#     ['0021800549',
#      52,
#      4,
#      0,
#      1,
#      '7:51 PM',
#      '7:01',
#      None,
#      None,
#      'Rubio REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      53,
#      1,
#      5,
#      1,
#      '7:51 PM',
#      '6:51',
#      None,
#      None,
#      "Favors 1' Layup (2 PTS) (Gobert 1 AST)",
#      '7 - 13',
#      '6',
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      55,
#      2,
#      57,
#      1,
#      '7:52 PM',
#      '6:34',
#      "MISS Leonard 5' Driving Hook Shot",
#      None,
#      None,
#      None,
#      None,
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      56,
#      4,
#      0,
#      1,
#      '7:52 PM',
#      '6:32',
#      None,
#      None,
#      'Favors REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      57,
#      2,
#      1,
#      1,
#      '7:52 PM',
#      '6:15',
#      None,
#      None,
#      'MISS Favors  3PT Jump Shot',
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      58,
#      4,
#      0,
#      1,
#      '7:52 PM',
#      '6:12',
#      'Ibaka REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      59,
#      5,
#      1,
#      1,
#      '7:52 PM',
#      '6:01',
#      'VanVleet Bad Pass Turnover (P1.T2)',
#      None,
#      'Gobert STEAL (1 STL)',
#      None,
#      None,
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      61,
#      1,
#      99,
#      1,
#      '7:52 PM',
#      '5:54',
#      None,
#      None,
#      "Favors 1' Cutting Finger Roll Layup Shot (4 PTS) (Ingles 1 AST)",
#      '9 - 13',
#      '4',
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      63,
#      5,
#      2,
#      1,
#      '7:53 PM',
#      '5:35',
#      'Green Lost Ball Turnover (P1.T3)',
#      None,
#      'Ingles STEAL (1 STL)',
#      None,
#      None,
#      4,
#      201980,
#      'Danny Green',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      65,
#      6,
#      1,
#      1,
#      '7:53 PM',
#      '5:35',
#      'Green P.FOUL (P1.T3) (S.Twardoski)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201980,
#      'Danny Green',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      67,
#      8,
#      0,
#      1,
#      '7:53 PM',
#      '5:35',
#      None,
#      None,
#      "SUB: O'Neale FOR Ingles",
#      None,
#      None,
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      1626220,
#      "Royce O'Neale",
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      68,
#      8,
#      0,
#      1,
#      '7:53 PM',
#      '5:35',
#      None,
#      None,
#      'SUB: Crowder FOR Favors',
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      71,
#      2,
#      79,
#      1,
#      '7:53 PM',
#      '5:20',
#      None,
#      None,
#      "MISS Rubio 19' Pullup Jump Shot",
#      None,
#      None,
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      72,
#      4,
#      0,
#      1,
#      '7:53 PM',
#      '5:18',
#      'Ibaka REBOUND (Off:0 Def:3)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      73,
#      6,
#      2,
#      1,
#      '7:53 PM',
#      '5:08',
#      None,
#      None,
#      'Crowder S.FOUL (P1.T1) (S.Twardoski)',
#      None,
#      None,
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      75,
#      3,
#      11,
#      1,
#      '7:54 PM',
#      '5:08',
#      'Leonard Free Throw 1 of 2 (3 PTS)',
#      None,
#      None,
#      '9 - 14',
#      '5',
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      76,
#      8,
#      0,
#      1,
#      '7:54 PM',
#      '5:08',
#      'SUB: Anunoby FOR Green',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201980,
#      'Danny Green',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      4,
#      1628384,
#      'OG Anunoby',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      77,
#      8,
#      0,
#      1,
#      '7:54 PM',
#      '5:08',
#      'SUB: Powell FOR Siakam',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      4,
#      1626181,
#      'Norman Powell',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      80,
#      3,
#      12,
#      1,
#      '7:54 PM',
#      '5:08',
#      'Leonard Free Throw 2 of 2 (4 PTS)',
#      None,
#      None,
#      '9 - 15',
#      '6',
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      81,
#      1,
#      57,
#      1,
#      '7:55 PM',
#      '4:50',
#      None,
#      None,
#      "Gobert 4' Driving Hook Shot (5 PTS)",
#      '11 - 15',
#      '4',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      82,
#      6,
#      2,
#      1,
#      '7:55 PM',
#      '4:50',
#      'Powell S.FOUL (P1.T4) (T.Brothers)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1626181,
#      'Norman Powell',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      84,
#      3,
#      10,
#      1,
#      '7:55 PM',
#      '4:50',
#      None,
#      None,
#      'Gobert Free Throw 1 of 1 (6 PTS)',
#      '12 - 15',
#      '3',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      85,
#      1,
#      79,
#      1,
#      '7:55 PM',
#      '4:39',
#      "Leonard 14' Pullup Jump Shot (6 PTS) (Anunoby 1 AST)",
#      None,
#      None,
#      '12 - 17',
#      '5',
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      4,
#      1628384,
#      'OG Anunoby',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      87,
#      2,
#      79,
#      1,
#      '7:55 PM',
#      '4:28',
#      None,
#      None,
#      "MISS Mitchell 19' Pullup Jump Shot",
#      None,
#      None,
#      5,
#      1628378,
#      'Donovan Mitchell',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      88,
#      4,
#      0,
#      1,
#      '7:56 PM',
#      '4:26',
#      'Powell REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1626181,
#      'Norman Powell',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      89,
#      2,
#      57,
#      1,
#      '7:56 PM',
#      '4:15',
#      "MISS Ibaka 8' Driving Hook Shot",
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      90,
#      4,
#      0,
#      1,
#      '7:56 PM',
#      '4:13',
#      None,
#      None,
#      'Rubio REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      91,
#      1,
#      76,
#      1,
#      '7:56 PM',
#      '4:08',
#      None,
#      None,
#      "Mitchell 1' Running Finger Roll Layup (4 PTS) (Rubio 2 AST)",
#      '14 - 17',
#      '3',
#      5,
#      1628378,
#      'Donovan Mitchell',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      93,
#      1,
#      6,
#      1,
#      '7:56 PM',
#      '3:47',
#      "Powell 1' Driving Layup (2 PTS)",
#      None,
#      None,
#      '14 - 19',
#      '5',
#      4,
#      1626181,
#      'Norman Powell',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      94,
#      6,
#      17,
#      1,
#      '7:56 PM',
#      '3:35',
#      'RAPTORS T.Foul (Def. 3 Sec Ibaka ) (M.Lindsay)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      95,
#      3,
#      16,
#      1,
#      '7:57 PM',
#      '3:35',
#      None,
#      None,
#      'Rubio Free Throw Technical (1 PTS)',
#      '15 - 19',
#      '4',
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      96,
#      8,
#      0,
#      1,
#      '7:57 PM',
#      '3:35',
#      'SUB: Monroe FOR Ibaka',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      4,
#      202328,
#      'Greg Monroe',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      97,
#      8,
#      0,
#      1,
#      '7:57 PM',
#      '3:35',
#      None,
#      None,
#      'SUB: Exum FOR Rubio',
#      None,
#      None,
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      203957,
#      'Dante Exum',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      100,
#      2,
#      75,
#      1,
#      '7:57 PM',
#      '3:26',
#      None,
#      None,
#      "MISS Exum 2' Driving Finger Roll Layup",
#      None,
#      None,
#      5,
#      203957,
#      'Dante Exum',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      101,
#      4,
#      0,
#      1,
#      '7:57 PM',
#      '3:24',
#      'VanVleet REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      102,
#      1,
#      1,
#      1,
#      '7:57 PM',
#      '3:12',
#      "Powell 26' 3PT Jump Shot (5 PTS) (Monroe 1 AST)",
#      None,
#      None,
#      '15 - 22',
#      '7',
#      4,
#      1626181,
#      'Norman Powell',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      4,
#      202328,
#      'Greg Monroe',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      104,
#      2,
#      79,
#      1,
#      '7:58 PM',
#      '2:50',
#      None,
#      None,
#      "MISS Mitchell 21' Pullup Jump Shot",
#      None,
#      None,
#      5,
#      1628378,
#      'Donovan Mitchell',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      105,
#      4,
#      0,
#      1,
#      '7:58 PM',
#      '2:47',
#      None,
#      None,
#      'Gobert REBOUND (Off:1 Def:2)',
#      None,
#      None,
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      106,
#      6,
#      2,
#      1,
#      '7:58 PM',
#      '2:43',
#      'Anunoby S.FOUL (P1.PN) (M.Lindsay)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1628384,
#      'OG Anunoby',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      108,
#      9,
#      1,
#      1,
#      '7:58 PM',
#      '2:43',
#      'RAPTORS Timeout: Regular (Full 1 Short 0)',
#      None,
#      None,
#      None,
#      None,
#      2,
#      1610612761,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      109,
#      18,
#      0,
#      1,
#      '7:58 PM',
#      '2:43',
#      None,
#      None,
#      None,
#      '15 - 22',
#      '7',
#      0,
#      106,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      110,
#      8,
#      0,
#      1,
#      '7:59 PM',
#      '2:43',
#      'SUB: Wright FOR VanVleet',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      4,
#      1626153,
#      'Delon Wright',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      111,
#      8,
#      0,
#      1,
#      '7:59 PM',
#      '2:43',
#      None,
#      None,
#      "SUB: Korver FOR O'Neale",
#      None,
#      None,
#      5,
#      1626220,
#      "Royce O'Neale",
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      2594,
#      'Kyle Korver',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      112,
#      8,
#      0,
#      1,
#      '7:59 PM',
#      '2:43',
#      None,
#      None,
#      'SUB: Favors FOR Gobert',
#      None,
#      None,
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      113,
#      8,
#      0,
#      1,
#      '7:59 PM',
#      '2:43',
#      None,
#      None,
#      'SUB: Ingles FOR Mitchell',
#      None,
#      None,
#      5,
#      1628378,
#      'Donovan Mitchell',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      118,
#      3,
#      11,
#      1,
#      '8:01 PM',
#      '2:43',
#      None,
#      None,
#      'Crowder Free Throw 1 of 2 (1 PTS)',
#      '16 - 22',
#      '6',
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      119,
#      3,
#      12,
#      1,
#      '8:02 PM',
#      '2:43',
#      None,
#      None,
#      'Crowder Free Throw 2 of 2 (2 PTS)',
#      '17 - 22',
#      '5',
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      120,
#      1,
#      79,
#      1,
#      '8:02 PM',
#      '2:31',
#      "Leonard 19' Pullup Jump Shot (8 PTS)",
#      None,
#      None,
#      '17 - 24',
#      '7',
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      121,
#      2,
#      79,
#      1,
#      '8:02 PM',
#      '2:14',
#      None,
#      None,
#      "MISS Korver 27' 3PT Pullup Jump Shot",
#      None,
#      None,
#      5,
#      2594,
#      'Kyle Korver',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      122,
#      4,
#      0,
#      1,
#      '8:02 PM',
#      '2:11',
#      None,
#      None,
#      'Favors REBOUND (Off:1 Def:1)',
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      124,
#      6,
#      2,
#      1,
#      '8:02 PM',
#      '2:07',
#      'Leonard S.FOUL (P1.PN) (S.Twardoski)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      126,
#      3,
#      13,
#      1,
#      '8:03 PM',
#      '2:07',
#      None,
#      None,
#      'Crowder Free Throw 1 of 3 (3 PTS)',
#      '18 - 24',
#      '6',
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      127,
#      3,
#      14,
#      1,
#      '8:03 PM',
#      '2:07',
#      None,
#      None,
#      'Crowder Free Throw 2 of 3 (4 PTS)',
#      '19 - 24',
#      '5',
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      128,
#      3,
#      15,
#      1,
#      '8:03 PM',
#      '2:07',
#      None,
#      None,
#      'Crowder Free Throw 3 of 3 (5 PTS)',
#      '20 - 24',
#      '4',
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      129,
#      2,
#      79,
#      1,
#      '8:04 PM',
#      '1:50',
#      "MISS Leonard 20' Pullup Jump Shot",
#      None,
#      None,
#      None,
#      None,
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      130,
#      4,
#      0,
#      1,
#      '8:04 PM',
#      '1:47',
#      None,
#      None,
#      'Exum REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      5,
#      203957,
#      'Dante Exum',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      131,
#      1,
#      108,
#      1,
#      '8:04 PM',
#      '1:35',
#      None,
#      None,
#      "Favors 1' Cutting Dunk Shot (6 PTS) (Ingles 2 AST)",
#      '22 - 24',
#      '2',
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      133,
#      2,
#      3,
#      1,
#      '8:04 PM',
#      '1:21',
#      "MISS Monroe 2' Hook Shot",
#      None,
#      None,
#      None,
#      None,
#      4,
#      202328,
#      'Greg Monroe',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      134,
#      4,
#      0,
#      1,
#      '8:04 PM',
#      '1:17',
#      'Monroe REBOUND (Off:1 Def:0)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      202328,
#      'Greg Monroe',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      135,
#      2,
#      72,
#      1,
#      '8:04 PM',
#      '1:17',
#      "MISS Monroe 1' Putback Layup",
#      None,
#      'Favors BLOCK (2 BLK)',
#      None,
#      None,
#      4,
#      202328,
#      'Greg Monroe',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA'],
#     ['0021800549',
#      137,
#      4,
#      0,
#      1,
#      '8:04 PM',
#      '1:15',
#      None,
#      None,
#      'Crowder REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      138,
#      2,
#      1,
#      1,
#      '8:04 PM',
#      '1:09',
#      None,
#      None,
#      "MISS Crowder 27' 3PT Jump Shot",
#      None,
#      None,
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      139,
#      4,
#      0,
#      1,
#      '8:04 PM',
#      '1:06',
#      'Leonard REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      140,
#      1,
#      86,
#      1,
#      '8:04 PM',
#      '1:00',
#      "Leonard 11' Turnaround Fadeaway (10 PTS)",
#      None,
#      None,
#      '22 - 26',
#      '4',
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      141,
#      2,
#      98,
#      1,
#      '8:05 PM',
#      '0:46',
#      None,
#      None,
#      "MISS Favors 2' Cutting Layup Shot",
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      142,
#      4,
#      0,
#      1,
#      '8:05 PM',
#      '0:44',
#      None,
#      None,
#      'Favors REBOUND (Off:2 Def:1)',
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      143,
#      1,
#      97,
#      1,
#      '8:05 PM',
#      '0:44',
#      None,
#      None,
#      "Favors 1' Tip Layup Shot (8 PTS)",
#      '24 - 26',
#      '2',
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      144,
#      5,
#      40,
#      1,
#      '8:05 PM',
#      '0:34',
#      'Wright Out of Bounds Lost Ball Turnover (P1.T4)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1626153,
#      'Delon Wright',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      145,
#      8,
#      0,
#      1,
#      '8:05 PM',
#      '0:34',
#      'SUB: Green FOR Leonard',
#      None,
#      None,
#      None,
#      None,
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      4,
#      201980,
#      'Danny Green',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      147,
#      2,
#      66,
#      1,
#      '8:05 PM',
#      '0:20',
#      None,
#      None,
#      "MISS Favors 11' Jump Bank Shot",
#      None,
#      None,
#      5,
#      202324,
#      'Derrick Favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      148,
#      4,
#      0,
#      1,
#      '8:06 PM',
#      '0:17',
#      'Anunoby REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1628384,
#      'OG Anunoby',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      149,
#      2,
#      80,
#      1,
#      '8:06 PM',
#      '0:02',
#      "MISS Powell 26' 3PT Step Back Jump Shot",
#      None,
#      None,
#      None,
#      None,
#      4,
#      1626181,
#      'Norman Powell',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      150,
#      4,
#      0,
#      1,
#      '8:06 PM',
#      '0:02',
#      None,
#      None,
#      'Ingles REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      151,
#      13,
#      0,
#      1,
#      '8:06 PM',
#      '0:00',
#      None,
#      None,
#      None,
#      '24 - 26',
#      '2',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      154,
#      12,
#      0,
#      2,
#      '8:09 PM',
#      '12:00',
#      None,
#      None,
#      None,
#      '24 - 26',
#      '2',
#      0,
#      0,
#      None,
# ...
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      628,
#      4,
#      1,
#      4,
#      '9:49 PM',
#      '1:29',
#      'RAPTORS Rebound',
#      None,
#      None,
#      None,
#      None,
#      2,
#      1610612761,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      629,
#      3,
#      12,
#      4,
#      '9:49 PM',
#      '1:29',
#      'MISS Ibaka Free Throw 2 of 2',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      630,
#      4,
#      0,
#      4,
#      '9:49 PM',
#      '1:27',
#      None,
#      None,
#      'Gobert REBOUND (Off:3 Def:6)',
#      None,
#      None,
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      631,
#      1,
#      52,
#      4,
#      '9:49 PM',
#      '1:16',
#      None,
#      None,
#      'Gobert  Alley Oop Dunk (16 PTS) (Ingles 6 AST)',
#      '113 - 118',
#      '5',
#      5,
#      203497,
#      'Rudy Gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      633,
#      2,
#      1,
#      4,
#      '9:49 PM',
#      '0:57',
#      'MISS Green  3PT Jump Shot',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201980,
#      'Danny Green',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      634,
#      4,
#      0,
#      4,
#      '9:50 PM',
#      '0:56',
#      None,
#      None,
#      'Jazz Rebound',
#      None,
#      None,
#      3,
#      1610612762,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      635,
#      6,
#      3,
#      4,
#      '9:50 PM',
#      '0:56',
#      'Ibaka L.B.FOUL (P4.PN) (M.Lindsay)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      637,
#      3,
#      11,
#      4,
#      '9:50 PM',
#      '0:56',
#      None,
#      None,
#      'MISS Rubio Free Throw 1 of 2',
#      None,
#      None,
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      638,
#      4,
#      1,
#      4,
#      '9:50 PM',
#      '0:56',
#      None,
#      None,
#      'Jazz Rebound',
#      None,
#      None,
#      3,
#      1610612762,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      639,
#      3,
#      12,
#      4,
#      '9:50 PM',
#      '0:56',
#      None,
#      None,
#      'Rubio Free Throw 2 of 2 (12 PTS)',
#      '114 - 118',
#      '4',
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      640,
#      2,
#      1,
#      4,
#      '9:51 PM',
#      '0:39',
#      'MISS Ibaka  3PT Jump Shot',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201586,
#      'Serge Ibaka',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      641,
#      4,
#      0,
#      4,
#      '9:51 PM',
#      '0:36',
#      'Green REBOUND (Off:2 Def:2)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      201980,
#      'Danny Green',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      642,
#      2,
#      102,
#      4,
#      '9:51 PM',
#      '0:25',
#      "MISS Leonard 26' 3PT Driving Floating Bank Jump Shot",
#      None,
#      None,
#      None,
#      None,
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      643,
#      4,
#      0,
#      4,
#      '9:51 PM',
#      '0:23',
#      'Siakam REBOUND (Off:1 Def:8)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      644,
#      6,
#      2,
#      4,
#      '9:51 PM',
#      '0:23',
#      None,
#      None,
#      'Mitchell S.FOUL (P2.PN) (T.Brothers)',
#      None,
#      None,
#      5,
#      1628378,
#      'Donovan Mitchell',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      646,
#      3,
#      11,
#      4,
#      '9:52 PM',
#      '0:23',
#      'Siakam Free Throw 1 of 2 (27 PTS)',
#      None,
#      None,
#      '114 - 119',
#      '5',
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      647,
#      3,
#      12,
#      4,
#      '9:52 PM',
#      '0:23',
#      'Siakam Free Throw 2 of 2 (28 PTS)',
#      None,
#      None,
#      '114 - 120',
#      '6',
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      648,
#      9,
#      1,
#      4,
#      '9:52 PM',
#      '0:23',
#      None,
#      None,
#      'Jazz Timeout: Regular (Reg.6 Short 0)',
#      None,
#      None,
#      3,
#      1610612762,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      651,
#      2,
#      1,
#      4,
#      '9:54 PM',
#      '0:20',
#      None,
#      None,
#      "MISS Mitchell 29' 3PT Jump Shot",
#      None,
#      None,
#      5,
#      1628378,
#      'Donovan Mitchell',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      652,
#      4,
#      0,
#      4,
#      '9:54 PM',
#      '0:18',
#      'RAPTORS Rebound',
#      None,
#      None,
#      None,
#      None,
#      2,
#      1610612761,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      653,
#      6,
#      3,
#      4,
#      '9:54 PM',
#      '0:18',
#      None,
#      None,
#      'Crowder L.B.FOUL (P3.PN) (T.Brothers)',
#      None,
#      None,
#      5,
#      203109,
#      'Jae Crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      655,
#      3,
#      11,
#      4,
#      '9:55 PM',
#      '0:18',
#      'MISS VanVleet Free Throw 1 of 2',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      656,
#      4,
#      1,
#      4,
#      '9:55 PM',
#      '0:18',
#      'RAPTORS Rebound',
#      None,
#      None,
#      None,
#      None,
#      2,
#      1610612761,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      658,
#      3,
#      12,
#      4,
#      '9:55 PM',
#      '0:18',
#      'VanVleet Free Throw 2 of 2 (8 PTS)',
#      None,
#      None,
#      '114 - 121',
#      '7',
#      4,
#      1627832,
#      'Fred VanVleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      659,
#      1,
#      73,
#      4,
#      '9:55 PM',
#      '0:13',
#      None,
#      None,
#      "Rubio 1' Driving Reverse Layup (14 PTS)",
#      '116 - 121',
#      '5',
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      660,
#      9,
#      1,
#      4,
#      '9:55 PM',
#      '0:08',
#      'RAPTORS Timeout: Regular (Full 5 Short 0)',
#      None,
#      None,
#      None,
#      None,
#      2,
#      1610612761,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      661,
#      8,
#      0,
#      4,
#      '9:56 PM',
#      '0:08',
#      None,
#      None,
#      "SUB: O'Neale FOR Ingles",
#      None,
#      None,
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      1626220,
#      "Royce O'Neale",
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      662,
#      8,
#      0,
#      4,
#      '9:56 PM',
#      '0:08',
#      None,
#      None,
#      'SUB: Exum FOR Rubio',
#      None,
#      None,
#      5,
#      201937,
#      'Ricky Rubio',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      203957,
#      'Dante Exum',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      665,
#      6,
#      1,
#      4,
#      '9:57 PM',
#      '0:07',
#      None,
#      None,
#      'Exum P.FOUL (P2.PN) (S.Twardoski)',
#      None,
#      None,
#      5,
#      203957,
#      'Dante Exum',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      1,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      667,
#      3,
#      11,
#      4,
#      '9:57 PM',
#      '0:07',
#      'Leonard Free Throw 1 of 2 (45 PTS)',
#      None,
#      None,
#      '116 - 122',
#      '6',
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      668,
#      3,
#      12,
#      4,
#      '9:58 PM',
#      '0:07',
#      'MISS Leonard Free Throw 2 of 2',
#      None,
#      None,
#      None,
#      None,
#      4,
#      202695,
#      'Kawhi Leonard',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      669,
#      4,
#      0,
#      4,
#      '9:58 PM',
#      '0:06',
#      None,
#      None,
#      'Mitchell REBOUND (Off:1 Def:3)',
#      None,
#      None,
#      5,
#      1628378,
#      'Donovan Mitchell',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      670,
#      9,
#      1,
#      4,
#      '9:58 PM',
#      '0:06',
#      None,
#      None,
#      'Jazz Timeout: Regular (Reg.7 Short 0)',
#      None,
#      None,
#      3,
#      1610612762,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      671,
#      8,
#      0,
#      4,
#      '9:59 PM',
#      '0:06',
#      None,
#      None,
#      "SUB: Ingles FOR O'Neale",
#      None,
#      None,
#      5,
#      1626220,
#      "Royce O'Neale",
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      204060,
#      'Joe Ingles',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      672,
#      8,
#      0,
#      4,
#      '9:59 PM',
#      '0:06',
#      None,
#      None,
#      'SUB: Korver FOR Exum',
#      None,
#      None,
#      5,
#      203957,
#      'Dante Exum',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      5,
#      2594,
#      'Kyle Korver',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      675,
#      2,
#      1,
#      4,
#      '10:00 PM',
#      '0:05',
#      None,
#      None,
#      "MISS Mitchell 26' 3PT Jump Shot",
#      None,
#      None,
#      5,
#      1628378,
#      'Donovan Mitchell',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      676,
#      4,
#      0,
#      4,
#      '10:00 PM',
#      '0:01',
#      'Siakam REBOUND (Off:1 Def:9)',
#      None,
#      None,
#      None,
#      None,
#      4,
#      1627783,
#      'Pascal Siakam',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021800549',
#      677,
#      13,
#      0,
#      4,
#      '10:00 PM',
#      '0:00',
#      None,
#      None,
#      None,
#      '116 - 122',
#      '6',
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None]]},
#   {'name': 'AvailableVideo',
#    'headers': ['VIDEO_AVAILABLE_FLAG'],
#    'rowSet': [[1]]}]}

# %%
#this part gets the lines probably should put this in a function
#since I will need to loop over each period and match them up

    home_lineup_api = ('https://stats.nba.com/stats/leaguedashlineups?Conference=&'
                       f'DateFrom={game_date}&DateTo={game_date}&Division=&'
                       'GameSegment=&GroupQuantity=5&LastNGames=0&LeagueID=&Location=&'
                       f'MeasureType=Base&Month=0&OpponentTeamID={team_id}&Outcome=&PORound=&'
                       f'PaceAdjust=N&PerMode=Totals&Period={period}&PlusMinus=N&Rank=N&'
                       'Season=2018-19&SeasonSegment=&SeasonType=Regular+'
                       'Season&ShotClockRange=&TeamID=&VsConference=&VsDivision=')


    home_lineup_req = requests.get(home_lineup_api, headers=user_agent)
    home_lineup_dict = home_lineup_req.json()

#extract the player ids of each lineup
    lineups = []
    for lineup in home_lineup_dict['resultSets'][0]['rowSet']:
        lineups.append([lineup[1]])

#clean the id strings into a list of ids for each lineup
    for x in range(len(lineups)):
        print(lineups[x][0])
        lineups[x] = list(filter(None,lineups[x][0].split('-')))

#TODO parse mtype column to get all the shot types being taken

#this pulls out the starting lineups from the play by play if every player
#on the court has done something that is recorded by the play by play
#if not then I will need to check the players against the lineups returned
#from the api and weed out which one doesn't fit. This needs to be repeated
#for every period
    periods = []
    for period in range(1, clean_df['PERIOD'].max()+1):
        #subsets main dataframe by period and subsets into a home and away subs
        period_df = clean_df[clean_df['PERIOD'] == period].reset_index()
        subs_df = period_df[(period_df.event_type_de == 'substitution')]
        away_subs = subs_df[pd.isnull(subs_df.VISITORDESCRIPTION) == 0]
        home_subs = subs_df[pd.isnull(subs_df.HOMEDESCRIPTION) == 0]

        #getting player ids of the players subbed into the game to check against later
        #to determine starting lineups
        away_subbed_players = list(away_subs['PLAYER2_ID'].unique())
        home_subbed_players = list(home_subs['PLAYER2_ID'].unique())
        #gets the index of the first sub for home and away to get the players who started
        #the period by subsetting the dataframe to all actions before the first sub for
        #each team
        away_indexes = list(away_subs.index)
        home_indexes = list(home_subs.index)
        #create variables for the lineup API in case just looking at
        game_date = str(period_df.game_date.unique()[0])[:10]
        away_team_id = period_df.away_team_id.unique()[0]
        home_team_id = period_df.home_team_id.unique()[0]
        api_season = f'{period_df.season.unique()[0]-1}-{str(period_df.season.unique()[0])[2:]}'
        home_lineup_api = ('https://stats.nba.com/stats/leaguedashlineups?Conference=&'
                           f'DateFrom={game_date}&DateTo={game_date}&Division=&'
                           'GameSegment=&GroupQuantity=5&LastNGames=0&LeagueID=&Location=&'
                           f'MeasureType=Base&Month=0&OpponentTeamID={away_team_id}&Outcome=&PORound=&'
                           f'PaceAdjust=N&PerMode=Totals&Period={period}&PlusMinus=N&Rank=N&'
                           f'Season={api_season}&SeasonSegment=&SeasonType=Regular+'
                           'Season&ShotClockRange=&TeamID=&VsConference=&VsDivision=')

        away_lineup_api = ('https://stats.nba.com/stats/leaguedashlineups?Conference=&'
                           f'DateFrom={game_date}&DateTo={game_date}&Division=&'
                           'GameSegment=&GroupQuantity=5&LastNGames=0&LeagueID=&Location=&'
                           f'MeasureType=Base&Month=0&OpponentTeamID={home_team_id}&Outcome=&PORound=&'
                           f'PaceAdjust=N&PerMode=Totals&Period={period}&PlusMinus=N&Rank=N&'
                           f'Season={api_season}&SeasonSegment=&SeasonType=Regular+'
                           'Season&ShotClockRange=&TeamID=&VsConference=&VsDivision=')


        home_lineup_req = requests.get(home_lineup_api, headers=user_agent)

        home_lineup_dict = home_lineup_req.json()

        #extract the player ids of each lineup
        home_lineups = []
        for lineup in home_lineup_dict['resultSets'][0]['rowSet']:
            home_lineups.append([lineup[1]])

        #clean the id strings into a list of ids for each lineup and convert them to ints
        for x in range(len(home_lineups)):
            home_lineups[x] = list(map(int,list(filter(None,home_lineups[x][0].split('-')))))

        away_lineup_req = requests.get(away_lineup_api, headers=user_agent)
        away_lineup_dict = away_lineup_req.json()

        #extract the player ids of each lineup
        away_lineups = []
        for lineup in away_lineup_dict['resultSets'][0]['rowSet']:
            away_lineups.append([lineup[1]])

        #clean the id strings into a list of ids for each lineup and convert them to ints
        for x in range(len(away_lineups)):
            away_lineups[x] = list(map(int,list(filter(None,away_lineups[x][0].split('-')))))
        #looking at the people before the first sub and if
        #it doesn't equal five then continue till next sub excluding the id of the first
        #subbed player and etc. until a list of five players is achieved if five is never
        #achieved by end of period then goto lineup api



        away_starting_line = list(period_df[(period_df.event_team == away_team_abbrev)
                                       & (~pd.isnull(period_df.PLAYER1_NAME))
                                       & (period_df.PLAYER1_TEAM_ABBREVIATION == away_team_abbrev)
                                       & (period_df.is_block == 0)
                                       & (period_df.is_steal == 0)]
                                        .loc[:away_indexes[0], :]['PLAYER1_ID'].unique())

        home_starting_line = list(period_df[(period_df.event_team == home_team_abbrev)
                                       & (~pd.isnull(period_df.PLAYER1_NAME))
                                       & (period_df.PLAYER1_TEAM_ABBREVIATION == home_team_abbrev)
                                       & (period_df.is_block == 0)
                                       & (period_df.is_steal == 0)]
                                        .loc[:home_indexes[0], :]['PLAYER1_ID'].unique())
#theres a large possibility that my catching of posssible lines might return
#two possible lines that fit the criteria in extreme edge cases may have to
#resort to brute forcing it if that happens often
        if len(away_starting_line) < 5:
            possible_away_lines = []
            for x in away_lineups:
                if set(away_starting_line).issubset(x):
                    possible_away_lines.append(x)
            if len(possible_away_lines) > 1:
                index = 0
                for line in possible_away_lines:
                    for player in line:
                        if player in away_subs and player not in away_starting_line:
                            index = possible_home_lines.index(line)
                    possible_home_lines.pop(index)
            away_ids_names = [(x, period_df[period_df['PLAYER1_ID'] == x]['PLAYER1_NAME'].unique()[0]) for x in possible_away_lines[0]]
        else:
            away_ids_names = [(x, period_df[period_df['PLAYER1_ID'] == x]['PLAYER1_NAME'].unique()[0]) for x in away_starting_line]
        #repeating the process for home players
        if len(home_starting_line) < 5:
            possible_home_lines = []
            for x in home_lineups:
                if set(home_starting_line).issubset(x):
                    possible_home_lines.append(x)
            if len(possible_home_lines) > 1:
                index = 0
                for line in possible_home_lines:
                    for player in line:
                        if player in home_subs and player not in home_starting_line:
                            index = possible_home_lines.index(line)
                    possible_home_lines.pop(index)
            home_ids_names = [(x, period_df[period_df['PLAYER1_ID'] == x]['PLAYER1_NAME'].unique()[0]) for x in possible_home_lines[0]]
        else:
            home_ids_names = [(x, period_df[period_df['PLAYER1_ID'] == x]['PLAYER1_NAME'].unique()[0]) for x in home_starting_line]




        for x in range(period_df.shape[0]):
            if period_df.iloc[x, :]['event_type_de'] == 'substitution' and pd.isnull(period_df.iloc[x, :]['VISITORDESCRIPTION']) == 1:
                home_ids_names = [ids for ids in home_ids_names if ids[0] != period_df.iloc[x, :]['PLAYER1_ID']]
                home_ids_names.append((period_df.iloc[x, 21], period_df.iloc[x,22]))
                period_df.iloc[x, 63] = home_ids_names[0][0]
                period_df.iloc[x, 62] = home_ids_names[0][1]
                period_df.iloc[x, 65] = home_ids_names[1][0]
                period_df.iloc[x, 64] = home_ids_names[1][1]
                period_df.iloc[x, 67] = home_ids_names[2][0]
                period_df.iloc[x, 66] = home_ids_names[2][1]
                period_df.iloc[x, 69] = home_ids_names[3][0]
                period_df.iloc[x, 68] = home_ids_names[3][1]
                period_df.iloc[x, 71] = home_ids_names[4][0]
                period_df.iloc[x, 70] = home_ids_names[4][1]
                period_df.iloc[x, 73] = away_ids_names[0][0]
                period_df.iloc[x, 72] = away_ids_names[0][1]
                period_df.iloc[x, 75] = away_ids_names[1][0]
                period_df.iloc[x, 74] = away_ids_names[1][1]
                period_df.iloc[x, 77] = away_ids_names[2][0]
                period_df.iloc[x, 76] = away_ids_names[2][1]
                period_df.iloc[x, 79] = away_ids_names[3][0]
                period_df.iloc[x, 78] = away_ids_names[3][1]
                period_df.iloc[x, 81] = away_ids_names[4][0]
                period_df.iloc[x, 80] = away_ids_names[4][1]
            elif period_df.iloc[x, :]['event_type_de'] == 'substitution' and pd.isnull(period_df.iloc[x, :]['HOMEDESCRIPTION']) == 1:
                away_ids_names = [ids for ids in away_ids_names if ids[0] != period_df.iloc[x, :]['PLAYER1_ID']]
                away_ids_names.append((period_df.iloc[x,21], period_df.iloc[x,22]))
                period_df.iloc[x, 63] = home_ids_names[0][0]
                period_df.iloc[x, 62] = home_ids_names[0][1]
                period_df.iloc[x, 65] = home_ids_names[1][0]
                period_df.iloc[x, 64] = home_ids_names[1][1]
                period_df.iloc[x, 67] = home_ids_names[2][0]
                period_df.iloc[x, 66] = home_ids_names[2][1]
                period_df.iloc[x, 69] = home_ids_names[3][0]
                period_df.iloc[x, 68] = home_ids_names[3][1]
                period_df.iloc[x, 71] = home_ids_names[4][0]
                period_df.iloc[x, 70] = home_ids_names[4][1]
                period_df.iloc[x, 73] = away_ids_names[0][0]
                period_df.iloc[x, 72] = away_ids_names[0][1]
                period_df.iloc[x, 75] = away_ids_names[1][0]
                period_df.iloc[x, 74] = away_ids_names[1][1]
                period_df.iloc[x, 77] = away_ids_names[2][0]
                period_df.iloc[x, 76] = away_ids_names[2][1]
                period_df.iloc[x, 79] = away_ids_names[3][0]
                period_df.iloc[x, 78] = away_ids_names[3][1]
                period_df.iloc[x, 81] = away_ids_names[4][0]
                period_df.iloc[x, 80] = away_ids_names[4][1]
            else:
                period_df.iloc[x, 63] = home_ids_names[0][0]
                period_df.iloc[x, 62] = home_ids_names[0][1]
                period_df.iloc[x, 65] = home_ids_names[1][0]
                period_df.iloc[x, 64] = home_ids_names[1][1]
                period_df.iloc[x, 67] = home_ids_names[2][0]
                period_df.iloc[x, 66] = home_ids_names[2][1]
                period_df.iloc[x, 69] = home_ids_names[3][0]
                period_df.iloc[x, 68] = home_ids_names[3][1]
                period_df.iloc[x, 71] = home_ids_names[4][0]
                period_df.iloc[x, 70] = home_ids_names[4][1]
                period_df.iloc[x, 73] = away_ids_names[0][0]
                period_df.iloc[x, 72] = away_ids_names[0][1]
                period_df.iloc[x, 75] = away_ids_names[1][0]
                period_df.iloc[x, 74] = away_ids_names[1][1]
                period_df.iloc[x, 77] = away_ids_names[2][0]
                period_df.iloc[x, 76] = away_ids_names[2][1]
                period_df.iloc[x, 79] = away_ids_names[3][0]
                period_df.iloc[x, 78] = away_ids_names[3][1]
                period_df.iloc[x, 81] = away_ids_names[4][0]
                period_df.iloc[x, 80] = away_ids_names[4][1]
        periods.append(period_df)

    new_df = pd.concat(periods).reset_index()
    return new_df
