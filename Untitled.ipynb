# %%
'''
Date: 2019-01-02
Contributor: Matthew Barlowe
Twitter: @matt_barlowe
Email: matt@barloweanalytics.com

This file contains the main functions to scrape and compile the NBA api and
return a CSV file of the pbp for the provided game
'''
import json
import requests
import bs4
import pandas as pd
import numpy as np
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)
pd.options.display.max_columns = None
# have to pass this to the requests function or the api will return a 403 code
user_agent = {'User-agent': 'Mozilla/5.0'}

#this will catalog the shot types recorded in the NBA play by play
#not sure how accurate this is it seems to change for the same shots
shot_type_dict = {58: 'turnaround hook shot', 5: 'layup', 6: 'driving layup',
                  96: 'turnaround bank hook shot', 108: 'cutting dunk shot',
                  79: 'pullup jump shot', 72: 'putback layup', 1: 'jump shot',
                  57: 'driving hook shot', 75: 'driving finger roll layup',
                  76: 'running finger roll layup', 79: '3pt shot', 80: '3pt shot',
                  2: '3pt shot', 3: 'hook shot', 98: 'cutting layup', 67: 'hook bank shot',
                  101: 'driving floating jump shot', 102: 'driving floating bank shot jump shot',
                  73: 'driving reverse layup', 63: 'fadeaway jump shot', 47: 'turnaround jump shot',
                  52: 'alley oop dunk', 97: 'tip layup', 66: 'jump bank shot',
                  50: 'running dunk shot', 41: 'running layup', 93: 'driving bank hook shot',
                  87: 'putback dunk shot', 99:'cutting finger roll layup',
                  86: 'turnaround fadeaway', 78: 'floating jump shot', 9: 'driving dunk',
                  74: 'running reverse layup', 44: 'reverse layup',
                  71: 'finger roll layup', 43: 'alley oop layup', 7: 'dunk',
                  103: 'running pull up jump shot', 110: 'running reverse dunk',
                  107: 'tip dunk', 51: 'reverse dunk', 105: 'turnaround fadeaway bank jump shot',
                  100: 'running alley oop layup', 106: 'running alley oop dunk',
                  104: 'step back bank jump shot', 109: 'driving reverse dunk'
                  }

#this dictionary will categorize the event types that happen in the NBA
#play by play
event_type_dict = {1: 'shot', 2: 'missed_shot', 4: 'rebound', 5: 'turnover',
                   20: 'stoppage: out-of-bounds', 6: 'foul', 3: 'free-throw',
                   8: 'substitution', 12: 'period-start', 10: 'jump-ball',
                   9: 'team-timeout', 18: 'instant-replay', 13: 'period-end',
                   7: 'goal-tending', 0: 'game-end'
                  }

# %%
#create column whether shot was succesful or not
def made_shot(row):
    '''
    function to determine whether shot was made or missed

    Input:
    row - pandas row

    Output:
    shot_made - binary variable
    '''

    if row['event_type_de'] == 'shot':
        return 1
    elif row['event_type_de'] == 'missed_shot':
        return 0
    elif (row['event_type_de'] == 'free-throw') & ('Missed' in row['de']):
        return 0
    elif (row['event_type_de'] == 'free-throw') & ('Missed' not in row['de']):
        return 1
    else:
        return np.nan

# %%
#parse mtype column to get all the shot types being taken
def parse_shot_types(row):
    '''
    function to parse what type of shot is being taken

    Inputs:
    row - pandas row of play by play dataframe

    Outputs:
    shot_type - returns a shot type of the values hook, jump, layup, dunk, tip
    '''
    if pd.isnull(row['shot_made']) == 0:
        if 'Layup' in row['de']:
            return 'layup'
        elif 'Hook' in row['de']:
            return 'hook'
        elif 'Dunk' in row['de']:
            return 'dunk'
        elif 'Free' in row['de']:
            return 'free'
        else:
            return 'jump'
    else:
        return np.nan

# %%
#Clean time to get a seconds elapsed column

def create_seconds_elapsed(row):
    '''
    this function parses the string time column and converts it into game
    seconds elapsed

    Inputs:
    row - row of play by play dataframe

    Outputs:
    time_in_seconds - the elapsed game time expressed in seconds
    '''

    time = row['pctimestring'].strip()
    time_list = time.split(':')
    max_time = 720
    ot_max_time = 300

    if row['period'] in [1,2,3,4]:
        time_in_seconds = (max_time - (int(time_list[0]) * 60 + int(time_list[1]))) + (720 * (int(row['period']) - 1))
    elif row['period'] > 4:
        time_in_seconds = (ot_max_time - (int(time_list[0]) * 60 + int(time_list[1]))) + (300 * (int(row['period']) - 5)) + 2880

    return time_in_seconds

# %%
def calc_points_made(row):
    '''
    function to calculate the points earned by a team with each shot made

    Inputs:
    row - row of pbp dataframe

    Outputs - value of shot made
    '''

    if row['is_three'] == 1 and row['shot_made'] == 1:
        return 3
    elif row['is_three'] == 0 and row['shot_made'] == 1 and row['shot_type'] != 'free':
        return 2
    elif row['shot_type'] == 'free':
        return 1
    else:
        return 0

# %%
#determine what type of fouls are being commited

def parse_foul(row):
    '''
    function to determine what type of foul is being commited by the player

    Input:
    row - row of nba play by play

    Output:
    foul_type - the foul type of the fould commited by the player
    '''

    if 'Shooting' in row['de']:
        return 'shooting'
    if 'Personal' in row['de']:
        return 'personal'
    if 'Loose Ball' in row['de']:
        return 'loose_ball'
    if 'Technical' in row['de']:
        return 'technical'
    if 'Charge' in row['de']:
        return 'charge'
    if 'Defense 3 Second' in row['de']:
        return '3 second'
    if 'Flagrant' in row['de']:
        return 'flagrant'
    if 'Flagrant 2' in row['de']:
        return 'flagrant 2'
    else:
        return np.nan

# %%
def scrape_pbp(game_id, season, user_agent=user_agent):
    '''
    This function scrapes both of the pbp urls and returns a joined/cleaned
    pbp dataframe

    Inputs:
    game_id - integer id of the nba game you want to scrape in question
    user_agent - this is the user agent to pass to the requests function

    Outputs:
    clean_df - final cleaned dataframe
    '''

#hard coding these in for testing purposes
    #v2_api_url = 'https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800549&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk'
    #pbp_api_url = 'https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800549_full_pbp.json'

# this will be the main url used for the v2 api url once testing is done
#v2 api will contain all the player info for each play in the game while the
#pbp_api_url will contain xy coords for each event
    v2_season = f'{season - 1}-{str(season)[2:]}'
    pbp_season = f'{season - 1}'
    v2_api_url = f'https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID={game_id}&RangeType=2&Season={v2_season}&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk'
    pbp_api_url = f'https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/{pbp_season}/scores/pbp/{game_id}_full_pbp.json'
    print(v2_api_url)
    print(pbp_api_url)
# have to pass this to the requests function or the api will return a 403 code
    v2_rep = requests.get(v2_api_url, headers=user_agent, verify=False) # remove this when package is finalized
    v2_dict = v2_rep.json()

#this pulls the v2 stats.nba play by play api
    pbp_v2_headers = v2_dict['resultSets'][0]['headers']
    pbp_v2_data = v2_dict['resultSets'][0]['rowSet']
    pbp_v2_df = pd.DataFrame(pbp_v2_data, columns=pbp_v2_headers)
    pbp_v2_df.columns = list(map(str.lower, pbp_v2_df.columns))

#this pulls the data.nba api end play by play
    pbp_rep = requests.get(pbp_api_url, headers=user_agent, verify=False)
    pbp_dict = pbp_rep.json()

#this will be used to concat each quarter from the play by play
    pbp_df_list = []

    for qtr in range(len(pbp_dict['g']['pd'])):
        pbp_df_list.append(pd.DataFrame(pbp_dict['g']['pd'][qtr]['pla']))

#pulling the home and away team abbreviations and the game date
    gcode = pbp_dict['g']['gcode'].split('/')
    date = gcode[0]
    teams = gcode[1]
    home_team_abbrev = teams[3:]
    away_team_abbrev = teams[:3]
    pbp_df = pd.concat(pbp_df_list)

#joining the two dataframes together and only pulling in relavent columns
    clean_df = pbp_v2_df.merge(pbp_df[['evt', 'locX', 'locY', 'hs', 'vs', 'de']],
                               left_on = 'eventnum', right_on='evt')
    #clean_df = pbp_v2_df
#add date and team abbrev columns to dataframe
    clean_df.loc[:, 'home_team_abbrev'] = home_team_abbrev
    clean_df.loc[:, 'away_team_abbrev'] = away_team_abbrev
    clean_df.loc[:, 'game_date'] = date
    clean_df.loc[:, 'game_date'] = clean_df.loc[:, 'game_date'].astype('datetime64')
    clean_df.loc[:, ('season')] = np.where(clean_df.game_date.dt.month.isin([10, 11, 12]),
                                           clean_df.game_date.dt.year + 1,
                                           clean_df.game_date.dt.year)
    #code to properly get the team ids as the scientific notation cuts off some digits
    home_team_id = clean_df[clean_df['player1_team_abbreviation'] == home_team_abbrev]['player1_team_id'].astype(int).unique()
    away_team_id = clean_df[clean_df['player1_team_abbreviation'] == away_team_abbrev]['player1_team_id'].astype(int).unique()
    clean_df.loc[:, 'home_team_id'] = home_team_id
    clean_df.loc[:, 'away_team_id'] = away_team_id
#create an event team colum
    clean_df['event_team'] = np.where(clean_df['homedescription'].isnull(),
                                    clean_df['home_team_abbrev'], clean_df['away_team_abbrev'])

#create and event type description column
    clean_df['event_type_de'] = clean_df[['eventmsgtype']].replace({'eventmsgtype': event_type_dict})

    #print(clean_df.iloc[317, :])
#create and shot type description column
    
    clean_df['shot_type_de'] = clean_df[['eventmsgtype', 'eventmsgactiontype']]\
                                .apply(lambda x: shot_type_dict[int(x['eventmsgactiontype'])]
                                       if np.isin(x['eventmsgtype'],[1,2]) else np.nan, axis=1)
    
#create an event team colum
    clean_df['event_team'] = np.where(~clean_df['homedescription'].isnull(),
                                      clean_df['home_team_abbrev'],
                                      clean_df['away_team_abbrev'])
    
#creates column for whether shot is made or not
    clean_df['shot_made'] = clean_df.apply(made_shot, axis=1)

#create a column that says whether the shot was blocked or not
    clean_df['is_block'] = np.where(clean_df['homedescription'].str.contains('BLOCK') |
                                    clean_df['visitordescription'].str.contains('BLOCK'),
                                    1, 0)

#create a column for the type of shot taken
    clean_df['shot_type'] = clean_df.apply(parse_shot_types, axis=1)

#create seconds_elapsed column between plays
    clean_df['seconds_elapsed'] = clean_df.apply(create_seconds_elapsed, axis=1)

#calculate event length of each even in seconds
    clean_df['event_length'] =  clean_df['seconds_elapsed'] - clean_df['seconds_elapsed'].shift(1)

#determine whether shot was a three pointer
    clean_df['is_three'] = np.where(clean_df['de'].str.contains('3pt'), 1, 0)
    #determine points earned

    clean_df['points_made'] = clean_df.apply(calc_points_made, axis=1)

#create columns that determine if rebound is offenseive or deffensive

    clean_df['is_d_rebound'] = np.where((clean_df['event_type_de'] == 'rebound') &
                                         (clean_df['event_team'] != clean_df['event_team'].shift(1)), 1, 0)

    clean_df['is_o_rebound'] = np.where((clean_df['event_type_de'] == 'rebound') &
                                        (clean_df['event_team'] == clean_df['event_team'].shift(1))
                                        & (clean_df['event_type_de'].shift(1) != 'free-throw'), 1, 0)

#create columns to determine turnovers and steals

    clean_df['is_turnover'] = np.where(clean_df['de'].str.contains('Turnover'), 1, 0)
    clean_df['is_steal'] = np.where(clean_df['de'].str.contains('Steal'), 1, 0)

#determine what type of fouls are being commited


    clean_df['foul_type'] = clean_df.apply(parse_foul, axis=1)

# determine if a shot is a putback off an offensive reboundk
    clean_df['is_putback'] = np.where((clean_df['is_o_rebound'].shift(1) == 1) &
                                      (clean_df['event_length'] <= 3), 1, 0)

#pull lineups
    clean_df = get_lineups(clean_df)

    return clean_df

# %%
def get_lineups(dataframe):
    '''
    This function gets the lineups for the game and creates columns 
    for each player on the court for each event of the play by play
    
    Inputs:
    dataframe  - the nba dataframe that's been computed up to this point
    
    Outputs:
    lineup_df  - the dataframe with lineups computed 
    '''
    #this pulls out the starting lineups from the play by play if every player
#on the court has done something that is recorded by the play by play
#if not then I will need to check the players against the lineups returned
#from the api and weed out which one doesn't fit. This needs to be repeated
#for every period

    periods = []
    
    for period in range(1, dataframe['period'].max()+1):
        #subsets main dataframe by period and subsets into a home and away subs
        print(period)
        period_df = dataframe[dataframe['period'] == period].reset_index()
        subs_df = period_df[(period_df.event_type_de == 'substitution')]
        away_subs = subs_df[pd.isnull(subs_df['visitordescription']) == 0]
        home_subs = subs_df[pd.isnull(subs_df['homedescription']) == 0]

        #getting player ids of the players subbed into the game to check against later
        #to determine starting lineups
        away_subbed_players = list(away_subs['player2_id'].unique())
        home_subbed_players = list(home_subs['player2_id'].unique())
        #gets the index of the first sub for home and away to get the players who started
        #the period by subsetting the dataframe to all actions before the first sub for
        #each team
        away_indexes = list(away_subs.index)
        home_indexes = list(home_subs.index)
        #create variables for the lineup API in case just looking at
        game_date = str(period_df.game_date.unique()[0])[:10]
        away_team_id = period_df.away_team_id.unique()[0]
        home_team_id = period_df.home_team_id.unique()[0]
        api_season = f'{period_df.season.unique()[0]-1}-{str(period_df.season.unique()[0])[2:]}'
        home_lineup_api = ('https://stats.nba.com/stats/leaguedashlineups?Conference=&'
                           f'DateFrom={game_date}&DateTo={game_date}&Division=&'
                           'GameSegment=&GroupQuantity=5&LastNGames=0&LeagueID=&Location=&'
                           f'MeasureType=Base&Month=0&OpponentTeamID={away_team_id}&Outcome=&PORound=&'
                           f'PaceAdjust=N&PerMode=Totals&Period={period}&PlusMinus=N&Rank=N&'
                           f'Season={api_season}&SeasonSegment=&SeasonType=Regular+'
                           'Season&ShotClockRange=&TeamID=&VsConference=&VsDivision=')

        away_lineup_api = ('https://stats.nba.com/stats/leaguedashlineups?Conference=&'
                           f'DateFrom={game_date}&DateTo={game_date}&Division=&'
                           'GameSegment=&GroupQuantity=5&LastNGames=0&LeagueID=&Location=&'
                           f'MeasureType=Base&Month=0&OpponentTeamID={home_team_id}&Outcome=&PORound=&'
                           f'PaceAdjust=N&PerMode=Totals&Period={period}&PlusMinus=N&Rank=N&'
                           f'Season={api_season}&SeasonSegment=&SeasonType=Regular+'
                           'Season&ShotClockRange=&TeamID=&VsConference=&VsDivision=')


        home_lineup_req = requests.get(home_lineup_api, headers=user_agent, verify=False)

        home_lineup_dict = home_lineup_req.json()

        #extract the player ids of each lineup
        home_lineups = []
        for lineup in home_lineup_dict['resultSets'][0]['rowSet']:
            home_lineups.append([lineup[1]])

        #clean the id strings into a list of ids for each lineup and convert them to ints
        for x in range(len(home_lineups)):
            home_lineups[x] = list(map(int,list(filter(None,home_lineups[x][0].split('-')))))

        away_lineup_req = requests.get(away_lineup_api, headers=user_agent, verify=False)
        away_lineup_dict = away_lineup_req.json()

        #extract the player ids of each lineup
        away_lineups = []
        for lineup in away_lineup_dict['resultSets'][0]['rowSet']:
            away_lineups.append([lineup[1]])

        #clean the id strings into a list of ids for each lineup and convert them to ints
        for x in range(len(away_lineups)):
            away_lineups[x] = list(map(int,list(filter(None,away_lineups[x][0].split('-')))))
        #looking at the people before the first sub and if
        #it doesn't equal five then continue till next sub excluding the id of the first
        #subbed player and etc. until a list of five players is achieved if five is never
        #achieved by end of period then goto lineup api

        #try/except blocks are to catch if the team does not make a sub in the period then just
        #pulls the unique values from the whole period dataframe
        try:
            away_starting_line = list(period_df[(period_df.event_team == period_df['away_team_abbrev'].unique()[0])
                                           & (~pd.isnull(period_df['player1_name']))
                                           & (period_df['player1_team_abbreviation'] == period_df['away_team_abbrev'].unique()[0])
                                           & (period_df.is_block == 0)
                                           & (period_df.is_steal == 0)]
                                            .loc[:away_indexes[0], :]['player1_id'].unique())
        except IndexError as ex:
            print("No subs this period")
            away_starting_line = list(period_df[(period_df.event_team == period_df['away_team_abbrev'].unique()[0])
                                           & (~pd.isnull(period_df['player1_name']))
                                           & (period_df['player1_team_abbreviation'] == period_df['away_team_abbrev'].unique()[0])
                                           & (period_df.is_block == 0)
                                           & (period_df.is_steal == 0)]
                                      ['player1_id'].unique())
        try:
            home_starting_line = list(period_df[(period_df.event_team == period_df['home_team_abbrev'].unique()[0])
                                           & (~pd.isnull(period_df['player1_name']))
                                           & (period_df['player1_team_abbreviation'] == period_df['home_team_abbrev'].unique()[0])
                                           & (period_df.is_block == 0)
                                           & (period_df.is_steal == 0)]
                                            .loc[:home_indexes[0], :]['player1_id'].unique())
        except IndexError as ex:
            print("No subs this period")
            home_starting_line = list(period_df[(period_df.event_team == period_df['home_team_abbrev'].unique()[0])
                                           & (~pd.isnull(period_df['player1_name']))
                                           & (period_df['player1_team_abbreviation'] == period_df['home_team_abbrev'].unique()[0])
                                           & (period_df.is_block == 0)
                                           & (period_df.is_steal == 0)]
                                     ['player1_id'].unique())
        print(away_starting_line)
        print(home_starting_line)
#if the above methods
        
        if len(away_starting_line) < 5:

            lineups = set()
            subs = set()
            for x in range(period_df.shape[0]):
        
                if (period_df.iloc[x, :]['event_team'] == period_df['away_team_abbrev'].unique()[0] and 
                    pd.isnull(period_df.iloc[x, :]['player1_name']) != 1 and 
                    period_df.iloc[x, :]['player1_team_abbreviation'] == period_df.iloc[x, :]['away_team_abbrev'] and 
                    period_df.iloc[x, :]['is_block'] == 0 and period_df.iloc[x, :]['is_steal'] == 0):
                    if period_df.iloc[x, :]['event_type_de'] != 'substitution':
                        if period_df.iloc[x, :]['player1_id'] != 0 and period_df.iloc[x, :]['player1_id'] not in subs:
                            lineups.add(period_df.iloc[x, :]['player1_id'])
                    else:
                        if period_df.iloc[x, :]['player2_id'] not in lineups:
                            subs.add(period_df.iloc[x, :]['player2_id'])
                        if period_df.iloc[x, :]['player1_id'] not in subs:
                            lineups.add(period_df.iloc[x, :]['player1_id'])

                    if len(lineups) == 5:
                        break
            away_ids_names = [(x, dataframe[dataframe['player1_id'] == x]['player1_name'].unique()[0]) for x in lineups]
        else:
            away_ids_names = [(x, dataframe[dataframe['player1_id'] == x]['player1_name'].unique()[0]) for x in away_starting_line]
        #repeating the process for home players
        if len(home_starting_line) < 5:
            lineups = set()
            subs = set()
            for x in range(period_df.shape[0]):
                if (period_df.iloc[x, :]['event_team'] == period_df['home_team_abbrev'].unique()[0] and 
                    pd.isnull(period_df.iloc[x, :]['player1_name']) != 1 and 
                    period_df.iloc[x, :]['player1_team_abbreviation'] == period_df.iloc[x, :]['home_team_abbrev'] and 
                    period_df.iloc[x, :]['is_block'] == 0 and period_df.iloc[x, :]['is_steal'] == 0):
                    if period_df.iloc[x, :]['event_type_de'] != 'substitution':
                        if period_df.iloc[x, :]['player1_id'] != 0 and period_df.iloc[x, :]['player1_id'] not in subs:
                            lineups.add(period_df.iloc[x, :]['player1_id'])
                    else:
                        if period_df.iloc[x, :]['player2_id'] not in lineups:
                            subs.add(period_df.iloc[x, :]['player2_id'])
                        if period_df.iloc[x, :]['player1_id'] not in subs:
                            lineups.add(period_df.iloc[x, :]['player1_id'])

                    if len(lineups) == 5:
                        break
           
           
            home_ids_names = [(x, dataframe[dataframe['player1_id'] == x]['player1_name'].unique()[0]) for x in lineups]
        else:
            home_ids_names = [(x, dataframe[dataframe['player1_id'] == x]['player1_name'].unique()[0]) for x in home_starting_line]
        print(away_ids_names)
        print(home_ids_names)
        period_df['home_player_1'] = ''
        period_df['home_player_1_id'] = ''
        period_df['home_player_2'] = ''
        period_df['home_player_2_id'] = ''
        period_df['home_player_3'] = ''
        period_df['home_player_3_id'] = ''
        period_df['home_player_4'] = ''
        period_df['home_player_4_id'] = ''
        period_df['home_player_5'] = ''
        period_df['home_player_5_id'] = ''
        period_df['away_player_1'] = ''
        period_df['away_player_1_id'] = ''
        period_df['away_player_2'] = ''
        period_df['away_player_2_id'] = ''
        period_df['away_player_3'] = ''
        period_df['away_player_3_id'] = ''
        period_df['away_player_4'] = ''
        period_df['away_player_4_id'] = ''
        period_df['away_player_5'] = ''
        period_df['away_player_5_id'] = ''
        
        
        for x in range(period_df.shape[0]):
            if period_df.iloc[x, :]['event_type_de'] == 'substitution' and pd.isnull(period_df.iloc[x, :]['visitordescription']) == 1:
                home_ids_names = [ids for ids in home_ids_names if ids[0] != period_df.iloc[x, :]['player1_id']]
                home_ids_names.append((period_df.iloc[x, 21], period_df.iloc[x,22]))
                period_df.iloc[x, 63] = home_ids_names[0][0]
                period_df.iloc[x, 62] = home_ids_names[0][1]
                period_df.iloc[x, 65] = home_ids_names[1][0]
                period_df.iloc[x, 64] = home_ids_names[1][1]
                period_df.iloc[x, 67] = home_ids_names[2][0]
                period_df.iloc[x, 66] = home_ids_names[2][1]
                period_df.iloc[x, 69] = home_ids_names[3][0]
                period_df.iloc[x, 68] = home_ids_names[3][1]
                period_df.iloc[x, 71] = home_ids_names[4][0]
                period_df.iloc[x, 70] = home_ids_names[4][1]
                period_df.iloc[x, 73] = away_ids_names[0][0]
                period_df.iloc[x, 72] = away_ids_names[0][1]
                period_df.iloc[x, 75] = away_ids_names[1][0]
                period_df.iloc[x, 74] = away_ids_names[1][1]
                period_df.iloc[x, 77] = away_ids_names[2][0]
                period_df.iloc[x, 76] = away_ids_names[2][1]
                period_df.iloc[x, 79] = away_ids_names[3][0]
                period_df.iloc[x, 78] = away_ids_names[3][1]
                period_df.iloc[x, 81] = away_ids_names[4][0]
                period_df.iloc[x, 80] = away_ids_names[4][1]
            elif period_df.iloc[x, :]['event_type_de'] == 'substitution' and pd.isnull(period_df.iloc[x, :]['homedescription']) == 1:
                away_ids_names = [ids for ids in away_ids_names if ids[0] != period_df.iloc[x, :]['player1_id']]
                away_ids_names.append((period_df.iloc[x,21], period_df.iloc[x,22]))
                period_df.iloc[x, 63] = home_ids_names[0][0]
                period_df.iloc[x, 62] = home_ids_names[0][1]
                period_df.iloc[x, 65] = home_ids_names[1][0]
                period_df.iloc[x, 64] = home_ids_names[1][1]
                period_df.iloc[x, 67] = home_ids_names[2][0]
                period_df.iloc[x, 66] = home_ids_names[2][1]
                period_df.iloc[x, 69] = home_ids_names[3][0]
                period_df.iloc[x, 68] = home_ids_names[3][1]
                period_df.iloc[x, 71] = home_ids_names[4][0]
                period_df.iloc[x, 70] = home_ids_names[4][1]
                period_df.iloc[x, 73] = away_ids_names[0][0]
                period_df.iloc[x, 72] = away_ids_names[0][1]
                period_df.iloc[x, 75] = away_ids_names[1][0]
                period_df.iloc[x, 74] = away_ids_names[1][1]
                period_df.iloc[x, 77] = away_ids_names[2][0]
                period_df.iloc[x, 76] = away_ids_names[2][1]
                period_df.iloc[x, 79] = away_ids_names[3][0]
                period_df.iloc[x, 78] = away_ids_names[3][1]
                period_df.iloc[x, 81] = away_ids_names[4][0]
                period_df.iloc[x, 80] = away_ids_names[4][1]
            else:
                period_df.iloc[x, 63] = home_ids_names[0][0]
                period_df.iloc[x, 62] = home_ids_names[0][1]
                period_df.iloc[x, 65] = home_ids_names[1][0]
                period_df.iloc[x, 64] = home_ids_names[1][1]
                period_df.iloc[x, 67] = home_ids_names[2][0]
                period_df.iloc[x, 66] = home_ids_names[2][1]
                period_df.iloc[x, 69] = home_ids_names[3][0]
                period_df.iloc[x, 68] = home_ids_names[3][1]
                period_df.iloc[x, 71] = home_ids_names[4][0]
                period_df.iloc[x, 70] = home_ids_names[4][1]
                period_df.iloc[x, 73] = away_ids_names[0][0]
                period_df.iloc[x, 72] = away_ids_names[0][1]
                period_df.iloc[x, 75] = away_ids_names[1][0]
                period_df.iloc[x, 74] = away_ids_names[1][1]
                period_df.iloc[x, 77] = away_ids_names[2][0]
                period_df.iloc[x, 76] = away_ids_names[2][1]
                period_df.iloc[x, 79] = away_ids_names[3][0]
                period_df.iloc[x, 78] = away_ids_names[3][1]
                period_df.iloc[x, 81] = away_ids_names[4][0]
                period_df.iloc[x, 80] = away_ids_names[4][1]
        periods.append(period_df)

    lineup_df = pd.concat(periods).reset_index()
    return lineup_df

# %%
for x in range(21800778, 21801230): #21801230
    print(x)
    test = scrape_pbp(f'00{x}', 2019)
# Out:
# 21800778
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800778&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800778_full_pbp.json
# 1
# [201572, 203507, 1627763, 203114, 203503]
# [1628418, 2772, 203107, 203490, 203078]
# [(201572, 'Brook Lopez'), (203507, 'Giannis Antetokounmpo'), (1627763, 'Malcolm Brogdon'), (203114, 'Khris Middleton'), (203503, 'Tony Snell')]
# [(1628418, 'Thomas Bryant'), (2772, 'Trevor Ariza'), (203107, 'Tomas Satoransky'), (203490, 'Otto Porter Jr.'), (203078, 'Bradley Beal')]
# 2
# [1627763, 1626192, 203507, 101141]
# [1626184, 203490]
# [(203503, 'Tony Snell'), (1626192, 'Pat Connaughton'), (1627763, 'Malcolm Brogdon'), (203507, 'Giannis Antetokounmpo'), (101141, 'Ersan Ilyasova')]
# [(203490, 'Otto Porter Jr.'), (1626184, 'Chasson Randle'), (1626155, 'Sam Dekker'), (2772, 'Trevor Ariza'), (201145, 'Jeff Green')]
# 3
# [203507, 203503, 201572, 203114, 1627763]
# [203078, 203490, 1628418, 203107, 2772]
# [(203507, 'Giannis Antetokounmpo'), (203503, 'Tony Snell'), (201572, 'Brook Lopez'), (203114, 'Khris Middleton'), (1627763, 'Malcolm Brogdon')]
# [(203078, 'Bradley Beal'), (203490, 'Otto Porter Jr.'), (1628418, 'Thomas Bryant'), (203107, 'Tomas Satoransky'), (2772, 'Trevor Ariza')]
# 4
# [203507, 203503, 201572, 201588]
# [1626155, 201145, 203078, 203895, 2772]
# [(201572, 'Brook Lopez'), (203503, 'Tony Snell'), (1626192, 'Pat Connaughton'), (203507, 'Giannis Antetokounmpo'), (201588, 'George Hill')]
# [(1626155, 'Sam Dekker'), (201145, 'Jeff Green'), (203078, 'Bradley Beal'), (203895, 'Jordan McRae'), (2772, 'Trevor Ariza')]
# 21800779
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800779&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800779_full_pbp.json
# 1
# [201950, 203524, 1628402, 203121, 1626143]
# [200746, 1628401, 201942, 1627854, 200752]
# [(201950, 'Jrue Holiday'), (203524, 'Solomon Hill'), (1628402, 'Frank Jackson'), (203121, 'Darius Miller'), (1626143, 'Jahlil Okafor')]
# [(200746, 'LaMarcus Aldridge'), (1628401, 'Derrick White'), (201942, 'DeMar DeRozan'), (1627854, 'Bryn Forbes'), (200752, 'Rudy Gay')]
# 2
# [1627767, 1628402, 1629026, 204025, 203546]
# [201988, 201158, 2200, 202347]
# [(1627767, 'Cheick Diallo'), (1628402, 'Frank Jackson'), (1629026, 'Kenrich Williams'), (204025, 'Tim Frazier'), (203546, 'Ian Clark')]
# [(202722, 'Davis Bertans'), (201988, 'Patty Mills'), (201158, 'Marco Belinelli'), (202347, 'Quincy Pondexter'), (2200, 'Pau Gasol')]
# 3
# [201950, 1626143, 203524, 1628402, 203121]
# [201942, 200752, 1627854, 200746, 1628401]
# [(201950, 'Jrue Holiday'), (1626143, 'Jahlil Okafor'), (203524, 'Solomon Hill'), (1628402, 'Frank Jackson'), (203121, 'Darius Miller')]
# [(201942, 'DeMar DeRozan'), (200752, 'Rudy Gay'), (1627854, 'Bryn Forbes'), (200746, 'LaMarcus Aldridge'), (1628401, 'Derrick White')]
# 4
# [202325, 203546, 1626143, 204025, 1629026]
# [2200, 202722, 200752, 201158, 201988]
# [(202325, 'Wesley Johnson'), (203546, 'Ian Clark'), (1626143, 'Jahlil Okafor'), (204025, 'Tim Frazier'), (1629026, 'Kenrich Williams')]
# [(2200, 'Pau Gasol'), (202722, 'Davis Bertans'), (200752, 'Rudy Gay'), (201158, 'Marco Belinelli'), (201988, 'Patty Mills')]
# 21800780
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800780&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800780_full_pbp.json
# 1
# [1629029, 1628467, 203084, 1627827, 1628973]
# [1627790, 1629012, 202692, 203918, 1626224]
# [(1629029, 'Luka Doncic'), (1628467, 'Maxi Kleber'), (203084, 'Harrison Barnes'), (1627827, 'Dorian Finney-Smith'), (1628973, 'Jalen Brunson')]
# [(1627790, 'Ante Zizic'), (1629012, 'Collin Sexton'), (202692, 'Alec Burks'), (203918, 'Rodney Hood'), (1626224, 'Cedi Osman')]
# 2
# [1629151, 1629029, 203939, 2734]
# [203903, 203918, 1626204, 1626224, 203521]
# [(203939, 'Dwight Powell'), (1629029, 'Luka Doncic'), (203084, 'Harrison Barnes'), (2734, 'Devin Harris'), (1629151, 'Ryan Broekhoff')]
# [(203903, 'Jordan Clarkson'), (203918, 'Rodney Hood'), (1626204, 'Larry Nance Jr.'), (1626224, 'Cedi Osman'), (203521, 'Matthew Dellavedova')]
# 3
# [1629029, 203084, 1628467, 1627827, 1628973]
# [1629012, 1627790, 1628021, 203918, 202692]
# [(1629029, 'Luka Doncic'), (203084, 'Harrison Barnes'), (1628467, 'Maxi Kleber'), (1627827, 'Dorian Finney-Smith'), (1628973, 'Jalen Brunson')]
# [(1629012, 'Collin Sexton'), (1627790, 'Ante Zizic'), (1628021, 'David Nwaba'), (203918, 'Rodney Hood'), (202692, 'Alec Burks')]
# 4
# [1629151, 1629029, 1717, 203939, 2734]
# [203918, 1626204, 1629061, 203521, 203903]
# [(1629151, 'Ryan Broekhoff'), (1629029, 'Luka Doncic'), (1717, 'Dirk Nowitzki'), (203939, 'Dwight Powell'), (2734, 'Devin Harris')]
# [(203918, 'Rodney Hood'), (1626204, 'Larry Nance Jr.'), (1629061, 'Deng Adel'), (203521, 'Matthew Dellavedova'), (203903, 'Jordan Clarkson')]
# 21800781
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800781&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800781_full_pbp.json
# 1
# [201954, 202711, 1626167, 201152, 202709]
# [202355, 1626196, 204020, 201949, 1626159]
# [(201954, 'Darren Collison'), (202711, 'Bojan Bogdanovic'), (1626167, 'Myles Turner'), (201152, 'Thaddeus Young'), (202709, 'Cory Joseph')]
# [(202355, 'Hassan Whiteside'), (1626196, 'Josh Richardson'), (204020, 'Tyler Johnson'), (201949, 'James Johnson'), (1626159, 'Justise Winslow')]
# 2
# [1628410, 201936, 1627734, 1628388]
# [203482, 203079, 2548]
# [(1628388, 'TJ Leaf'), (201936, 'Tyreke Evans'), (1627734, 'Domantas Sabonis'), (1628410, 'Edmond Sumner'), (1628988, 'Aaron Holiday')]
# [(1628389, 'Bam Adebayo'), (203079, 'Dion Waiters'), (1626196, 'Josh Richardson'), (2548, 'Dwyane Wade'), (203482, 'Kelly Olynyk')]
# 3
# [201152, 202711, 202709, 1626167, 201954]
# [202355, 1626159, 201949, 1626196]
# [(201152, 'Thaddeus Young'), (202711, 'Bojan Bogdanovic'), (202709, 'Cory Joseph'), (1626167, 'Myles Turner'), (201954, 'Darren Collison')]
# [(1626159, 'Justise Winslow'), (202355, 'Hassan Whiteside'), (204020, 'Tyler Johnson'), (1626196, 'Josh Richardson'), (201949, 'James Johnson')]
# 4
# [1628988, 201152, 1627734, 1628410]
# [202355, 203482, 2548, 203079, 1626159]
# [(201152, 'Thaddeus Young'), (201936, 'Tyreke Evans'), (1627734, 'Domantas Sabonis'), (1628410, 'Edmond Sumner'), (1628988, 'Aaron Holiday')]
# [(202355, 'Hassan Whiteside'), (203482, 'Kelly Olynyk'), (2548, 'Dwyane Wade'), (203079, 'Dion Waiters'), (1626159, 'Justise Winslow')]
# 21800782
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800782&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800782_full_pbp.json
# 1
# [1627826, 1628398, 200765, 203484, 1627742]
# [202326, 202691, 201939, 201142, 203110]
# [(1627826, 'Ivica Zubac'), (1628398, 'Kyle Kuzma'), (200765, 'Rajon Rondo'), (203484, 'Kentavious Caldwell-Pope'), (1627742, 'Brandon Ingram')]
# [(202326, 'DeMarcus Cousins'), (202691, 'Klay Thompson'), (201939, 'Stephen Curry'), (201142, 'Kevin Durant'), (203110, 'Draymond Green')]
# 2
# [201563, 1629021, 202362, 1627742]
# [202691, 2738, 203110]
# [(1628404, 'Josh Hart'), (202362, 'Lance Stephenson'), (201563, 'Michael Beasley'), (1629021, 'Moritz Wagner'), (1627742, 'Brandon Ingram')]
# [(202691, 'Klay Thompson'), (203110, 'Draymond Green'), (2733, 'Shaun Livingston'), (2738, 'Andre Iguodala'), (202326, 'DeMarcus Cousins')]
# 3
# [1627742, 200765, 203484, 1627826, 1628398]
# [201939, 201142, 202326, 203110, 202691]
# [(1627742, 'Brandon Ingram'), (200765, 'Rajon Rondo'), (203484, 'Kentavious Caldwell-Pope'), (1627826, 'Ivica Zubac'), (1628398, 'Kyle Kuzma')]
# [(201939, 'Stephen Curry'), (201142, 'Kevin Durant'), (202326, 'DeMarcus Cousins'), (203110, 'Draymond Green'), (202691, 'Klay Thompson')]
# 4
# [200765, 202362, 1627826, 1628398, 1628404]
# [2733, 202326, 203110, 202691, 2738]
# [(200765, 'Rajon Rondo'), (202362, 'Lance Stephenson'), (1627826, 'Ivica Zubac'), (1628398, 'Kyle Kuzma'), (1628404, 'Josh Hart')]
# [(2733, 'Shaun Livingston'), (202326, 'DeMarcus Cousins'), (203110, 'Draymond Green'), (202691, 'Klay Thompson'), (2738, 'Andre Iguodala')]
# 21800783
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800783&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800783_full_pbp.json
# 1
# [203999, 203115, 1627736, 200794, 1628420]
# [1626157, 203952, 1629006, 201959, 201573]
# [(203999, 'Nikola Jokic'), (203115, 'Will Barton'), (1627736, 'Malik Beasley'), (200794, 'Paul Millsap'), (1628420, 'Monte Morris')]
# [(1626157, 'Karl-Anthony Towns'), (203952, 'Andrew Wiggins'), (1629006, 'Josh Okogie'), (201959, 'Taj Gibson'), (201573, 'Jerryd Bayless')]
# 2
# [1628470, 1626168, 203486, 1627823, 1628420]
# [203476, 203967, 201565]
# [(1628470, 'Torrey Craig'), (1626168, 'Trey Lyles'), (203486, 'Mason Plumlee'), (1627823, 'Juancho Hernangomez'), (1628420, 'Monte Morris')]
# [(1629006, 'Josh Okogie'), (2736, 'Luol Deng'), (203476, 'Gorgui Dieng'), (201565, 'Derrick Rose'), (203967, 'Dario Saric')]
# 3
# [1627736, 203115, 203999, 200794, 1628420]
# [201959, 201573, 1629006, 203952, 1626157]
# [(1627736, 'Malik Beasley'), (203115, 'Will Barton'), (203999, 'Nikola Jokic'), (200794, 'Paul Millsap'), (1628420, 'Monte Morris')]
# [(201959, 'Taj Gibson'), (201573, 'Jerryd Bayless'), (1629006, 'Josh Okogie'), (203952, 'Andrew Wiggins'), (1626157, 'Karl-Anthony Towns')]
# 4
# [1628420, 1627823, 1626168, 1628470, 203486]
# [201565, 203477, 203967, 203476]
# [(1628420, 'Monte Morris'), (1627823, 'Juancho Hernangomez'), (1626168, 'Trey Lyles'), (1628470, 'Torrey Craig'), (203486, 'Mason Plumlee')]
# [(201229, 'Anthony Tolliver'), (203476, 'Gorgui Dieng'), (203477, 'Isaiah Canaan'), (201565, 'Derrick Rose'), (203967, 'Dario Saric')]
# 21800784
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800784&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800784_full_pbp.json
# 1
# [1628381, 1629027, 1628989, 203473]
# [1629028, 1628367, 1626164, 1629059, 1628969]
# [(1629027, 'Trae Young'), (1627752, 'Taurean Prince'), (1628989, 'Kevin Huerter'), (203473, 'Dewayne Dedmon'), (1628381, 'John Collins')]
# [(1629028, 'Deandre Ayton'), (1628367, 'Josh Jackson'), (1626164, 'Devin Booker'), (1629059, 'Elie Okobo'), (1628969, 'Mikal Bridges')]
# 2
# [1627761, 1713, 203145, 202391, 203458]
# [1628367, 1626162, 1628969, 1626158]
# [(1627761, "DeAndre' Bembry"), (1713, 'Vince Carter'), (203145, 'Kent Bazemore'), (202391, 'Jeremy Lin'), (203458, 'Alex Len')]
# [(1628969, 'Mikal Bridges'), (1626158, 'Richaun Holmes'), (1628367, 'Josh Jackson'), (1626162, 'Kelly Oubre Jr.'), (2037, 'Jamal Crawford')]
# 3
# [1628381, 203473, 1629027, 1627752]
# [1629059, 1628367, 1628969, 1629028, 1626164]
# [(1629027, 'Trae Young'), (1627752, 'Taurean Prince'), (1628989, 'Kevin Huerter'), (203473, 'Dewayne Dedmon'), (1628381, 'John Collins')]
# [(1629059, 'Elie Okobo'), (1628367, 'Josh Jackson'), (1628969, 'Mikal Bridges'), (1629028, 'Deandre Ayton'), (1626164, 'Devin Booker')]
# 4
# [1628381, 1629027, 203145, 1628989]
# [1626162, 1628969, 1629059, 1629028, 1626164]
# [(1629027, 'Trae Young'), (203145, 'Kent Bazemore'), (1628989, 'Kevin Huerter'), (203473, 'Dewayne Dedmon'), (1628381, 'John Collins')]
# [(1626162, 'Kelly Oubre Jr.'), (1628969, 'Mikal Bridges'), (1629059, 'Elie Okobo'), (1629028, 'Deandre Ayton'), (1626164, 'Devin Booker')]
# 21800785
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800785&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800785_full_pbp.json
# 1
# [203954, 1627732, 203488, 202710]
# [1626161, 1627741, 202357, 202697, 1628368]
# [(203488, 'Mike Muscala'), (203954, 'Joel Embiid'), (1627732, 'Ben Simmons'), (1629013, 'Landry Shamet'), (202710, 'Jimmy Butler')]
# [(1626161, 'Willie Cauley-Stein'), (1627741, 'Buddy Hield'), (202357, 'Nemanja Bjelica'), (202697, 'Iman Shumpert'), (1628368, "De'Aaron Fox")]
# 2
# [203954, 1629003, 203488, 204456]
# [1628963, 1628382, 1627812, 1628385]
# [(203488, 'Mike Muscala'), (204456, 'T.J. McConnell'), (1629003, 'Shake Milton'), (203954, 'Joel Embiid'), (202710, 'Jimmy Butler')]
# [(1628385, 'Harry Giles III'), (1628963, 'Marvin Bagley III'), (1627812, 'Yogi Ferrell'), (203992, 'Bogdan Bogdanovic'), (1628382, 'Justin Jackson')]
# 3
# [202710, 1627732, 203954, 203488, 1629013]
# [1627741, 1628368]
# [(202710, 'Jimmy Butler'), (1627732, 'Ben Simmons'), (203954, 'Joel Embiid'), (203488, 'Mike Muscala'), (1629013, 'Landry Shamet')]
# [(202697, 'Iman Shumpert'), (1628368, "De'Aaron Fox"), (1626161, 'Willie Cauley-Stein'), (202357, 'Nemanja Bjelica'), (1627741, 'Buddy Hield')]
# 4
# [202710, 203954, 204456, 1627732, 1629003]
# [1628385, 1628368, 203992, 1628382, 1628963]
# [(202710, 'Jimmy Butler'), (203954, 'Joel Embiid'), (204456, 'T.J. McConnell'), (1627732, 'Ben Simmons'), (1629003, 'Shake Milton')]
# [(1628385, 'Harry Giles III'), (1628368, "De'Aaron Fox"), (203992, 'Bogdan Bogdanovic'), (1628382, 'Justin Jackson'), (1628963, 'Marvin Bagley III')]
# 21800786
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800786&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800786_full_pbp.json
# 1
# [202702, 201935, 201569, 203516, 200782]
# [203497, 204060, 201937, 1628378, 203109]
# [(202702, 'Kenneth Faried'), (201935, 'James Harden'), (201569, 'Eric Gordon'), (203516, 'James Ennis III'), (200782, 'PJ Tucker')]
# [(203497, 'Rudy Gobert'), (204060, 'Joe Ingles'), (201937, 'Ricky Rubio'), (1628378, 'Donovan Mitchell'), (203109, 'Jae Crowder')]
# 2
# [101123, 201569, 202702]
# [204060, 1626220, 1627777, 203497]
# [(201569, 'Eric Gordon'), (101123, 'Gerald Green'), (203085, 'Austin Rivers'), (202702, 'Kenneth Faried'), (203516, 'James Ennis III')]
# [(1627777, 'Georges Niang'), (203497, 'Rudy Gobert'), (1626220, "Royce O'Neale"), (201937, 'Ricky Rubio'), (204060, 'Joe Ingles')]
# 3
# [200782, 201935, 203516, 201569, 202702]
# [201937, 203497, 1628378, 204060, 203109]
# [(200782, 'PJ Tucker'), (201935, 'James Harden'), (203516, 'James Ennis III'), (201569, 'Eric Gordon'), (202702, 'Kenneth Faried')]
# [(201937, 'Ricky Rubio'), (203497, 'Rudy Gobert'), (1628378, 'Donovan Mitchell'), (204060, 'Joe Ingles'), (203109, 'Jae Crowder')]
# 4
# [203085, 201569, 1628392, 203516, 101123]
# [201937, 1628378, 203497, 203109, 204060]
# [(203085, 'Austin Rivers'), (201569, 'Eric Gordon'), (1628392, 'Isaiah Hartenstein'), (203516, 'James Ennis III'), (101123, 'Gerald Green')]
# [(201937, 'Ricky Rubio'), (1628378, 'Donovan Mitchell'), (203497, 'Rudy Gobert'), (203109, 'Jae Crowder'), (204060, 'Joe Ingles')]
# 21800787
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800787&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800787_full_pbp.json
# 1
# [201188, 203200, 1628991, 203998, 201144]
# [201599, 1628995, 1628372, 1628422, 203943]
# [(201188, 'Marc Gasol'), (203200, 'Justin Holiday'), (1628991, 'Jaren Jackson Jr.'), (203998, 'Bruno Caboclo'), (201144, 'Mike Conley')]
# [(201599, 'DeAndre Jordan'), (1628995, 'Kevin Knox'), (1628372, 'Dennis Smith Jr.'), (1628422, 'Damyean Dotson'), (203943, 'Noah Vonleh')]
# 2
# [1628397, 201149, 202714]
# [1626209, 202083, 1628436, 1629019]
# [(203210, 'JaMychal Green'), (1628397, 'Ivan Rabb'), (1628975, 'Jevon Carter'), (202714, 'Shelvin Mack'), (201149, 'Joakim Noah')]
# [(1626209, 'Mario Hezonja'), (1629019, 'Allonzo Trier'), (202083, 'Wesley Matthews'), (1628436, 'Luke Kornet'), (1628443, 'Kadeem Allen')]
# 3
# [1628991, 201188, 201144, 203998]
# [1628372, 1628995, 203943, 1628422]
# [(203200, 'Justin Holiday'), (201188, 'Marc Gasol'), (201144, 'Mike Conley'), (203998, 'Bruno Caboclo'), (1628991, 'Jaren Jackson Jr.')]
# [(1628995, 'Kevin Knox'), (1628422, 'Damyean Dotson'), (203943, 'Noah Vonleh'), (1628372, 'Dennis Smith Jr.'), (201599, 'DeAndre Jordan')]
# 4
# [202714, 203200, 201149, 1628975, 1628991]
# [1626209, 1628436, 1628995, 1628443, 202083]
# [(202714, 'Shelvin Mack'), (203200, 'Justin Holiday'), (201149, 'Joakim Noah'), (1628975, 'Jevon Carter'), (1628991, 'Jaren Jackson Jr.')]
# [(1626209, 'Mario Hezonja'), (1628436, 'Luke Kornet'), (1628995, 'Kevin Knox'), (1628443, 'Kadeem Allen'), (202083, 'Wesley Matthews')]
# 21800788
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800788&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800788_full_pbp.json
# 1
# [201566, 203500, 202331, 1628390, 203924]
# [201143, 202681, 203935, 202694, 1628369]
# [(201566, 'Russell Westbrook'), (203500, 'Steven Adams'), (202331, 'Paul George'), (1628390, 'Terrance Ferguson'), (203924, 'Jerami Grant')]
# [(201143, 'Al Horford'), (202681, 'Kyrie Irving'), (203935, 'Marcus Smart'), (202694, 'Marcus Morris'), (1628369, 'Jayson Tatum')]
# 2
# [202331, 203471]
# [1626179, 202694, 1627759, 1628464, 202330]
# [(203457, 'Nerlens Noel'), (203471, 'Dennis Schroder'), (1628977, 'Hamidou Diallo'), (202331, 'Paul George'), (202335, 'Patrick Patterson')]
# [(1626179, 'Terry Rozier'), (202694, 'Marcus Morris'), (1627759, 'Jaylen Brown'), (1628464, 'Daniel Theis'), (202330, 'Gordon Hayward')]
# 3
# [201566, 202331, 203924, 1628390, 203500]
# [201143, 202681, 202694, 1628369, 203935]
# [(201566, 'Russell Westbrook'), (202331, 'Paul George'), (203924, 'Jerami Grant'), (1628390, 'Terrance Ferguson'), (203500, 'Steven Adams')]
# [(201143, 'Al Horford'), (202681, 'Kyrie Irving'), (202694, 'Marcus Morris'), (1628369, 'Jayson Tatum'), (203935, 'Marcus Smart')]
# 4
# [202331, 203471, 203457]
# [202694, 1626179, 1628464, 1627759]
# [(203457, 'Nerlens Noel'), (203471, 'Dennis Schroder'), (1628977, 'Hamidou Diallo'), (202331, 'Paul George'), (202335, 'Patrick Patterson')]
# [(1626179, 'Terry Rozier'), (202694, 'Marcus Morris'), (1627759, 'Jaylen Brown'), (1628464, 'Daniel Theis'), (202330, 'Gordon Hayward')]
# 21800789
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800789&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800789_full_pbp.json
# 1
# [202340, 1628983, 202699, 201976, 1626149]
# [201586, 1627832, 201980, 202695, 1627783]
# [(202340, 'Avery Bradley'), (1628983, 'Shai Gilgeous-Alexander'), (202699, 'Tobias Harris'), (201976, 'Patrick Beverley'), (1626149, 'Montrezl Harrell')]
# [(201586, 'Serge Ibaka'), (1627832, 'Fred VanVleet'), (201980, 'Danny Green'), (202695, 'Kawhi Leonard'), (1627783, 'Pascal Siakam')]
# 2
# [203118, 101150, 1626246, 201976]
# [1628384, 101139, 1626153, 202328, 1626181]
# [(1626246, 'Boban Marjanovic'), (203118, 'Mike Scott'), (1629010, 'Jerome Robinson'), (201976, 'Patrick Beverley'), (101150, 'Lou Williams')]
# [(1628384, 'OG Anunoby'), (101139, 'CJ Miles'), (1626153, 'Delon Wright'), (202328, 'Greg Monroe'), (1626181, 'Norman Powell')]
# 3
# [1628983, 201976, 202699, 1626149, 202340]
# [1627832, 201586, 202695, 201980, 1627783]
# [(1628983, 'Shai Gilgeous-Alexander'), (201976, 'Patrick Beverley'), (202699, 'Tobias Harris'), (1626149, 'Montrezl Harrell'), (202340, 'Avery Bradley')]
# [(1627832, 'Fred VanVleet'), (201586, 'Serge Ibaka'), (202695, 'Kawhi Leonard'), (201980, 'Danny Green'), (1627783, 'Pascal Siakam')]
# 4
# [1627820, 203118, 1629010, 101150, 1626149]
# [1626181, 202328, 1626153, 1628384, 101139]
# [(1627820, 'Tyrone Wallace'), (203118, 'Mike Scott'), (1629010, 'Jerome Robinson'), (101150, 'Lou Williams'), (1626149, 'Montrezl Harrell')]
# [(1626181, 'Norman Powell'), (202328, 'Greg Monroe'), (1626153, 'Delon Wright'), (1628384, 'OG Anunoby'), (101139, 'CJ Miles')]
# 21800790
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800790&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800790_full_pbp.json
# 1
# [203999, 1628420, 1627736, 203115, 203486]
# [203083, 203493, 201933, 202704, 1628971]
# [(203999, 'Nikola Jokic'), (1628420, 'Monte Morris'), (1627736, 'Malik Beasley'), (203115, 'Will Barton'), (203486, 'Mason Plumlee')]
# [(203083, 'Andre Drummond'), (203493, 'Reggie Bullock'), (201933, 'Blake Griffin'), (202704, 'Reggie Jackson'), (1628971, 'Bruce Brown')]
# 2
# [1626168, 1628420, 1627823, 1628399, 1628470]
# [204038, 1628379, 2585, 202397, 1626169]
# [(1626168, 'Trey Lyles'), (1628420, 'Monte Morris'), (1627823, 'Juancho Hernangomez'), (1628399, 'Tyler Lydon'), (1628470, 'Torrey Craig')]
# [(204038, 'Langston Galloway'), (1628379, 'Luke Kennard'), (2585, 'Zaza Pachulia'), (202397, 'Ish Smith'), (1626169, 'Stanley Johnson')]
# 3
# [1627736, 203486, 203999, 203115, 1628420]
# [1628971, 202704, 203493, 201933, 203083]
# [(1627736, 'Malik Beasley'), (203486, 'Mason Plumlee'), (203999, 'Nikola Jokic'), (203115, 'Will Barton'), (1628420, 'Monte Morris')]
# [(1628971, 'Bruce Brown'), (202704, 'Reggie Jackson'), (203493, 'Reggie Bullock'), (201933, 'Blake Griffin'), (203083, 'Andre Drummond')]
# 4
# [1626168, 1628420, 203999]
# [1628379, 2585, 204038, 1626169, 202397]
# [(1628420, 'Monte Morris'), (1627736, 'Malik Beasley'), (1627823, 'Juancho Hernangomez'), (1626168, 'Trey Lyles'), (203999, 'Nikola Jokic')]
# [(1628379, 'Luke Kennard'), (2585, 'Zaza Pachulia'), (204038, 'Langston Galloway'), (1626169, 'Stanley Johnson'), (202397, 'Ish Smith')]
# 21800791
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800791&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800791_full_pbp.json
# 1
# [1629027, 203473, 1628381, 1628989, 1627752]
# [1628418, 2772, 203107, 203490, 203078]
# [(1629027, 'Trae Young'), (203473, 'Dewayne Dedmon'), (1628381, 'John Collins'), (1628989, 'Kevin Huerter'), (1627752, 'Taurean Prince')]
# [(1628418, 'Thomas Bryant'), (2772, 'Trevor Ariza'), (203107, 'Tomas Satoransky'), (203490, 'Otto Porter Jr.'), (203078, 'Bradley Beal')]
# 2
# [1629016, 203145, 1627761, 203458]
# [201145, 203490, 101133, 1626184, 1626155]
# [(203458, 'Alex Len'), (203145, 'Kent Bazemore'), (1627761, "DeAndre' Bembry"), (202391, 'Jeremy Lin'), (1629016, 'Omari Spellman')]
# [(201145, 'Jeff Green'), (203490, 'Otto Porter Jr.'), (101133, 'Ian Mahinmi'), (1626184, 'Chasson Randle'), (1626155, 'Sam Dekker')]
# 3
# [1628989, 1629016, 203473, 1627752, 1629027]
# [2772, 203078, 203107, 203490, 1628418]
# [(1628989, 'Kevin Huerter'), (1629016, 'Omari Spellman'), (203473, 'Dewayne Dedmon'), (1627752, 'Taurean Prince'), (1629027, 'Trae Young')]
# [(2772, 'Trevor Ariza'), (203078, 'Bradley Beal'), (203107, 'Tomas Satoransky'), (203490, 'Otto Porter Jr.'), (1628418, 'Thomas Bryant')]
# 4
# [203473, 203145, 202391]
# [203078, 1628418, 203490, 2772]
# [(203145, 'Kent Bazemore'), (203473, 'Dewayne Dedmon'), (1713, 'Vince Carter'), (1627761, "DeAndre' Bembry"), (202391, 'Jeremy Lin')]
# [(203490, 'Otto Porter Jr.'), (1628418, 'Thomas Bryant'), (203078, 'Bradley Beal'), (2772, 'Trevor Ariza'), (203895, 'Jordan McRae')]
# 21800792
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800792&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800792_full_pbp.json
# 1
# [203507, 201572, 203114, 202339, 1627763]
# [1628386, 1629066, 1626156, 203894, 1626203]
# [(203507, 'Giannis Antetokounmpo'), (201572, 'Brook Lopez'), (203114, 'Khris Middleton'), (202339, 'Eric Bledsoe'), (1627763, 'Malcolm Brogdon')]
# [(1628386, 'Jarrett Allen'), (1629066, 'Rodions Kurucs'), (1626156, "D'Angelo Russell"), (203894, 'Shabazz Napier'), (1626203, 'Treveon Graham')]
# 2
# [101141, 202339, 203503, 203507, 1627763]
# [1629033, 202334, 1626156, 201960]
# [(101141, 'Ersan Ilyasova'), (202339, 'Eric Bledsoe'), (203503, 'Tony Snell'), (203507, 'Giannis Antetokounmpo'), (1627763, 'Malcolm Brogdon')]
# [(1626178, 'Rondae Hollis-Jefferson'), (201960, 'DeMarre Carroll'), (1629033, 'Theo Pinson'), (1626156, "D'Angelo Russell"), (202334, 'Ed Davis')]
# 3
# [1627763, 202339, 203507, 201572, 203114]
# [203894, 1626156, 1628386, 1629066, 1626203]
# [(1627763, 'Malcolm Brogdon'), (202339, 'Eric Bledsoe'), (203507, 'Giannis Antetokounmpo'), (201572, 'Brook Lopez'), (203114, 'Khris Middleton')]
# [(203894, 'Shabazz Napier'), (1626156, "D'Angelo Russell"), (1628386, 'Jarrett Allen'), (1629066, 'Rodions Kurucs'), (1626203, 'Treveon Graham')]
# 4
# [202339, 101141, 203503, 1626192]
# [1626178, 1626156, 201960, 1629033]
# [(202339, 'Eric Bledsoe'), (203503, 'Tony Snell'), (1626192, 'Pat Connaughton'), (203507, 'Giannis Antetokounmpo'), (101141, 'Ersan Ilyasova')]
# [(1626178, 'Rondae Hollis-Jefferson'), (201960, 'DeMarre Carroll'), (1629033, 'Theo Pinson'), (1626156, "D'Angelo Russell"), (1628249, 'Mitchell Creek')]
# 21800793
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800793&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800793_full_pbp.json
# 1
# [1626167, 202711, 202709, 201152, 201954]
# [1626143, 1629026, 203121, 1628402, 201950]
# [(1626167, 'Myles Turner'), (202711, 'Bojan Bogdanovic'), (202709, 'Cory Joseph'), (201152, 'Thaddeus Young'), (201954, 'Darren Collison')]
# [(1626143, 'Jahlil Okafor'), (1629026, 'Kenrich Williams'), (203121, 'Darius Miller'), (1628402, 'Frank Jackson'), (201950, 'Jrue Holiday')]
# 2
# [201936, 1628388, 1627734, 1628988]
# [1626143, 1627767, 1628402, 203546, 204025]
# [(1628388, 'TJ Leaf'), (201936, 'Tyreke Evans'), (1627734, 'Domantas Sabonis'), (1628410, 'Edmond Sumner'), (1628988, 'Aaron Holiday')]
# [(1626143, 'Jahlil Okafor'), (1627767, 'Cheick Diallo'), (1628402, 'Frank Jackson'), (203546, 'Ian Clark'), (204025, 'Tim Frazier')]
# 3
# [201152, 1626167, 202711, 202709, 201954]
# [1629026, 203121, 1628402, 201950, 1626143]
# [(201152, 'Thaddeus Young'), (1626167, 'Myles Turner'), (202711, 'Bojan Bogdanovic'), (202709, 'Cory Joseph'), (201954, 'Darren Collison')]
# [(1629026, 'Kenrich Williams'), (203121, 'Darius Miller'), (1628402, 'Frank Jackson'), (201950, 'Jrue Holiday'), (1626143, 'Jahlil Okafor')]
# 4
# [1628988, 201936, 1628410, 1627734, 201152]
# [203121, 201950, 1626143, 203546, 203524]
# [(1628988, 'Aaron Holiday'), (201936, 'Tyreke Evans'), (1628410, 'Edmond Sumner'), (1627734, 'Domantas Sabonis'), (201152, 'Thaddeus Young')]
# [(203121, 'Darius Miller'), (201950, 'Jrue Holiday'), (1626143, 'Jahlil Okafor'), (203546, 'Ian Clark'), (203524, 'Solomon Hill')]
# 21800794
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800794&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800794_full_pbp.json
# 1
# [201935, 203516, 200782, 202702, 101108]
# [1629028, 1628969, 1626164, 1628367, 1629059]
# [(201935, 'James Harden'), (203516, 'James Ennis III'), (200782, 'PJ Tucker'), (202702, 'Kenneth Faried'), (101108, 'Chris Paul')]
# [(1629028, 'Deandre Ayton'), (1628969, 'Mikal Bridges'), (1626164, 'Devin Booker'), (1628367, 'Josh Jackson'), (1629059, 'Elie Okobo')]
# 2
# [101123, 203085, 202702, 203516, 101108]
# [1626158, 2037, 1628969, 1626162, 1629059]
# [(101123, 'Gerald Green'), (203085, 'Austin Rivers'), (202702, 'Kenneth Faried'), (203516, 'James Ennis III'), (101108, 'Chris Paul')]
# [(1626158, 'Richaun Holmes'), (2037, 'Jamal Crawford'), (1628969, 'Mikal Bridges'), (1626162, 'Kelly Oubre Jr.'), (1629059, 'Elie Okobo')]
# 3
# [101108, 200782, 202702, 201935, 203516]
# [1629028, 1626164, 1628367, 1628969]
# [(101108, 'Chris Paul'), (200782, 'PJ Tucker'), (202702, 'Kenneth Faried'), (201935, 'James Harden'), (203516, 'James Ennis III')]
# [(1629059, 'Elie Okobo'), (1629028, 'Deandre Ayton'), (1628969, 'Mikal Bridges'), (1628367, 'Josh Jackson'), (1626164, 'Devin Booker')]
# 4
# [203516]
# [1628367, 1628969, 1629028, 1626162, 2037]
# [(101123, 'Gerald Green'), (2403, 'Nene'), (203085, 'Austin Rivers'), (101108, 'Chris Paul'), (203516, 'James Ennis III')]
# [(1628367, 'Josh Jackson'), (1628969, 'Mikal Bridges'), (1629028, 'Deandre Ayton'), (1626162, 'Kelly Oubre Jr.'), (2037, 'Jamal Crawford')]
# 21800795
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800795&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800795_full_pbp.json
# 1
# [201942, 200746, 200752, 202722, 1627854]
# [1626161, 202357, 1627741, 1628368]
# [(201942, 'DeMar DeRozan'), (200746, 'LaMarcus Aldridge'), (200752, 'Rudy Gay'), (202722, 'Davis Bertans'), (1627854, 'Bryn Forbes')]
# [(202697, 'Iman Shumpert'), (1628368, "De'Aaron Fox"), (1626161, 'Willie Cauley-Stein'), (202357, 'Nemanja Bjelica'), (1627741, 'Buddy Hield')]
# 2
# [1627751, 201158, 1627854, 200752, 201988]
# [203992, 1628385, 1628963, 1627812, 1628382]
# [(1627751, 'Jakob Poeltl'), (201158, 'Marco Belinelli'), (1627854, 'Bryn Forbes'), (200752, 'Rudy Gay'), (201988, 'Patty Mills')]
# [(203992, 'Bogdan Bogdanovic'), (1628385, 'Harry Giles III'), (1628963, 'Marvin Bagley III'), (1627812, 'Yogi Ferrell'), (1628382, 'Justin Jackson')]
# 3
# [200752, 200746, 1627854, 202722, 201942]
# [1626161, 1627741, 202697, 202357, 1628368]
# [(200752, 'Rudy Gay'), (200746, 'LaMarcus Aldridge'), (1627854, 'Bryn Forbes'), (202722, 'Davis Bertans'), (201942, 'DeMar DeRozan')]
# [(1626161, 'Willie Cauley-Stein'), (1627741, 'Buddy Hield'), (202697, 'Iman Shumpert'), (202357, 'Nemanja Bjelica'), (1628368, "De'Aaron Fox")]
# 4
# [200752, 1627751, 201158, 202722, 201988]
# [1627741]
# [(200752, 'Rudy Gay'), (1627751, 'Jakob Poeltl'), (201158, 'Marco Belinelli'), (202722, 'Davis Bertans'), (201988, 'Patty Mills')]
# [(1628963, 'Marvin Bagley III'), (1627812, 'Yogi Ferrell'), (202357, 'Nemanja Bjelica'), (203992, 'Bogdan Bogdanovic'), (1627741, 'Buddy Hield')]
# 21800796
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800796&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800796_full_pbp.json
# 1
# [201976, 202699, 101162, 1628983, 202340]
# [202687, 101107, 202689, 203087, 201587]
# [(201976, 'Patrick Beverley'), (202699, 'Tobias Harris'), (101162, 'Marcin Gortat'), (1628983, 'Shai Gilgeous-Alexander'), (202340, 'Avery Bradley')]
# [(202687, 'Bismack Biyombo'), (101107, 'Marvin Williams'), (202689, 'Kemba Walker'), (203087, 'Jeremy Lamb'), (201587, 'Nicolas Batum')]
# 2
# [203118, 101150, 1628983]
# [2225, 203077, 1628370, 101107, 1628970]
# [(1626149, 'Montrezl Harrell'), (203118, 'Mike Scott'), (1629010, 'Jerome Robinson'), (1628983, 'Shai Gilgeous-Alexander'), (101150, 'Lou Williams')]
# [(2225, 'Tony Parker'), (203077, 'Michael Kidd-Gilchrist'), (1628370, 'Malik Monk'), (101107, 'Marvin Williams'), (1628970, 'Miles Bridges')]
# 3
# [202699, 201976, 101162, 1628983]
# [202687, 101107, 203087, 202689]
# [(202340, 'Avery Bradley'), (101162, 'Marcin Gortat'), (202699, 'Tobias Harris'), (1628983, 'Shai Gilgeous-Alexander'), (201976, 'Patrick Beverley')]
# [(202689, 'Kemba Walker'), (203087, 'Jeremy Lamb'), (101107, 'Marvin Williams'), (201587, 'Nicolas Batum'), (202687, 'Bismack Biyombo')]
# 4
# [1628414, 101150, 202340, 1626149, 203118]
# [101107, 202689, 203077, 1628970, 1628370]
# [(1628414, 'Sindarius Thornwell'), (101150, 'Lou Williams'), (202340, 'Avery Bradley'), (1626149, 'Montrezl Harrell'), (203118, 'Mike Scott')]
# [(101107, 'Marvin Williams'), (202689, 'Kemba Walker'), (203077, 'Michael Kidd-Gilchrist'), (1628970, 'Miles Bridges'), (1628370, 'Malik Monk')]
# 21800797
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800797&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800797_full_pbp.json
# 1
# [201143, 1628369, 1626179, 203935, 1627759]
# [1627790, 1628021, 202692, 1629012, 1629061]
# [(201143, 'Al Horford'), (1628369, 'Jayson Tatum'), (1626179, 'Terry Rozier'), (203935, 'Marcus Smart'), (1627759, 'Jaylen Brown')]
# [(1627790, 'Ante Zizic'), (1628021, 'David Nwaba'), (202692, 'Alec Burks'), (1629012, 'Collin Sexton'), (1629061, 'Deng Adel')]
# 2
# [1627759, 1628464, 202954, 202330]
# [1628417, 203521, 1626204, 1629012]
# [(202954, 'Brad Wanamaker'), (1627759, 'Jaylen Brown'), (1628464, 'Daniel Theis'), (1628400, 'Semi Ojeleye'), (202330, 'Gordon Hayward')]
# [(1628417, 'Jaron Blossomgame'), (203521, 'Matthew Dellavedova'), (1629012, 'Collin Sexton'), (1626204, 'Larry Nance Jr.'), (203903, 'Jordan Clarkson')]
# 3
# [201143, 1626179, 203935, 1627759, 1628369]
# [1627790, 1628021, 1629012, 1629061]
# [(201143, 'Al Horford'), (1626179, 'Terry Rozier'), (203935, 'Marcus Smart'), (1627759, 'Jaylen Brown'), (1628369, 'Jayson Tatum')]
# [(202692, 'Alec Burks'), (1629061, 'Deng Adel'), (1627790, 'Ante Zizic'), (1629012, 'Collin Sexton'), (1628021, 'David Nwaba')]
# 4
# [202330, 1627759, 202954, 1628400, 1628464]
# [203903, 1629012, 1626204, 203521]
# [(202330, 'Gordon Hayward'), (1627759, 'Jaylen Brown'), (202954, 'Brad Wanamaker'), (1628400, 'Semi Ojeleye'), (1628464, 'Daniel Theis')]
# [(203521, 'Matthew Dellavedova'), (1628417, 'Jaron Blossomgame'), (1629012, 'Collin Sexton'), (1626204, 'Larry Nance Jr.'), (203903, 'Jordan Clarkson')]
# 21800798
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800798&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800798_full_pbp.json
# 1
# [200765, 1628398, 1627742, 1627826, 2544]
# [1626167, 201954, 202711, 201152, 201936]
# [(200765, 'Rajon Rondo'), (1628398, 'Kyle Kuzma'), (1627742, 'Brandon Ingram'), (1627826, 'Ivica Zubac'), (2544, 'LeBron James')]
# [(1626167, 'Myles Turner'), (201954, 'Darren Collison'), (202711, 'Bojan Bogdanovic'), (201152, 'Thaddeus Young'), (201936, 'Tyreke Evans')]
# 2
# [201563, 203484]
# [1628988, 202709, 1628410]
# [(2199, 'Tyson Chandler'), (202362, 'Lance Stephenson'), (201563, 'Michael Beasley'), (203484, 'Kentavious Caldwell-Pope'), (1627742, 'Brandon Ingram')]
# [(1628388, 'TJ Leaf'), (202709, 'Cory Joseph'), (1627734, 'Domantas Sabonis'), (1628410, 'Edmond Sumner'), (1628988, 'Aaron Holiday')]
# 3
# [200765, 1627742, 1628398, 1627826, 2544]
# [1626167, 201152, 201936, 201954, 202711]
# [(200765, 'Rajon Rondo'), (1627742, 'Brandon Ingram'), (1628398, 'Kyle Kuzma'), (1627826, 'Ivica Zubac'), (2544, 'LeBron James')]
# [(1626167, 'Myles Turner'), (201152, 'Thaddeus Young'), (201936, 'Tyreke Evans'), (201954, 'Darren Collison'), (202711, 'Bojan Bogdanovic')]
# 4
# [202362, 200765, 1629021, 201580]
# [1627734, 202711, 1628988, 202709, 1628410]
# [(201580, 'JaVale McGee'), (1629004, 'Svi Mykhailiuk'), (200765, 'Rajon Rondo'), (202362, 'Lance Stephenson'), (1629021, 'Moritz Wagner')]
# [(1627734, 'Domantas Sabonis'), (202711, 'Bojan Bogdanovic'), (1628988, 'Aaron Holiday'), (202709, 'Cory Joseph'), (1628410, 'Edmond Sumner')]
# 21800799
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800799&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800799_full_pbp.json
# 1
# [203083, 202704, 201933, 1628971, 203493]
# [201599, 203943, 1628995, 202083, 1628372]
# [(203083, 'Andre Drummond'), (202704, 'Reggie Jackson'), (201933, 'Blake Griffin'), (1628971, 'Bruce Brown'), (203493, 'Reggie Bullock')]
# [(201599, 'DeAndre Jordan'), (203943, 'Noah Vonleh'), (1628995, 'Kevin Knox'), (202083, 'Wesley Matthews'), (1628372, 'Dennis Smith Jr.')]
# 2
# [101181, 1628379, 1626169, 204038, 2585]
# [1629019, 1629011, 1628422, 1628443]
# [(101181, 'Jose Calderon'), (1628379, 'Luke Kennard'), (1626169, 'Stanley Johnson'), (204038, 'Langston Galloway'), (2585, 'Zaza Pachulia')]
# [(1629019, 'Allonzo Trier'), (202498, 'Lance Thomas'), (1628422, 'Damyean Dotson'), (1629011, 'Mitchell Robinson'), (1628443, 'Kadeem Allen')]
# 3
# [201933, 202704, 203493, 203083, 1628971]
# [1628372, 203943, 201599, 202083, 1628995]
# [(201933, 'Blake Griffin'), (202704, 'Reggie Jackson'), (203493, 'Reggie Bullock'), (203083, 'Andre Drummond'), (1628971, 'Bruce Brown')]
# [(1628372, 'Dennis Smith Jr.'), (203943, 'Noah Vonleh'), (201599, 'DeAndre Jordan'), (202083, 'Wesley Matthews'), (1628995, 'Kevin Knox')]
# 4
# [201933, 2585, 1626169, 1628379]
# [1628422, 202498, 1628443, 1629019, 1629011]
# [(201933, 'Blake Griffin'), (2585, 'Zaza Pachulia'), (1628379, 'Luke Kennard'), (101181, 'Jose Calderon'), (1626169, 'Stanley Johnson')]
# [(1628422, 'Damyean Dotson'), (202498, 'Lance Thomas'), (1628443, 'Kadeem Allen'), (1629019, 'Allonzo Trier'), (1629011, 'Mitchell Robinson')]
# 21800800
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800800&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800800_full_pbp.json
# 1
# [200768, 201980, 202695, 1627783, 201586]
# [203954, 202710, 1627732, 203488, 1629013]
# [(200768, 'Kyle Lowry'), (201980, 'Danny Green'), (202695, 'Kawhi Leonard'), (1627783, 'Pascal Siakam'), (201586, 'Serge Ibaka')]
# [(203954, 'Joel Embiid'), (202710, 'Jimmy Butler'), (1627732, 'Ben Simmons'), (203488, 'Mike Muscala'), (1629013, 'Landry Shamet')]
# 2
# [201586, 1628384, 1626153, 1626181]
# [203954, 1628413]
# [(1628384, 'OG Anunoby'), (1626181, 'Norman Powell'), (1626153, 'Delon Wright'), (201586, 'Serge Ibaka'), (1627832, 'Fred VanVleet')]
# [(204456, 'T.J. McConnell'), (1627788, 'Furkan Korkmaz'), (203954, 'Joel Embiid'), (202710, 'Jimmy Butler'), (1628413, 'Jonah Bolden')]
# 3
# [1627783, 201586, 200768, 202695]
# [1629013, 202710, 1627732, 203954, 203488]
# [(200768, 'Kyle Lowry'), (202695, 'Kawhi Leonard'), (1627783, 'Pascal Siakam'), (201586, 'Serge Ibaka'), (201980, 'Danny Green')]
# [(1629013, 'Landry Shamet'), (202710, 'Jimmy Butler'), (1627732, 'Ben Simmons'), (203954, 'Joel Embiid'), (203488, 'Mike Muscala')]
# 4
# [202328, 1626153, 1627832, 1628384, 1626181]
# [202710, 1627732, 203954, 1629013, 203488]
# [(202328, 'Greg Monroe'), (1626153, 'Delon Wright'), (1627832, 'Fred VanVleet'), (1628384, 'OG Anunoby'), (1626181, 'Norman Powell')]
# [(202710, 'Jimmy Butler'), (1627732, 'Ben Simmons'), (203954, 'Joel Embiid'), (1629013, 'Landry Shamet'), (203488, 'Mike Muscala')]
# 21800801
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800801&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800801_full_pbp.json
# 1
# [1626157, 203952, 1629006, 201959, 201573]
# [1628991, 1628397, 203200, 201144, 1627395]
# [(1626157, 'Karl-Anthony Towns'), (203952, 'Andrew Wiggins'), (1629006, 'Josh Okogie'), (201959, 'Taj Gibson'), (201573, 'Jerryd Bayless')]
# [(1628991, 'Jaren Jackson Jr.'), (1628397, 'Ivan Rabb'), (203200, 'Justin Holiday'), (201144, 'Mike Conley'), (1627395, 'Julian Washburn')]
# 2
# [203967, 203476, 203477, 1629006]
# [203998, 202714, 1628397]
# [(201229, 'Anthony Tolliver'), (1629006, 'Josh Okogie'), (203476, 'Gorgui Dieng'), (203477, 'Isaiah Canaan'), (203967, 'Dario Saric')]
# [(1628397, 'Ivan Rabb'), (1628975, 'Jevon Carter'), (1629139, 'Yuta Watanabe'), (202714, 'Shelvin Mack'), (203998, 'Bruno Caboclo')]
# 3
# [201959, 1626157]
# [203200, 1628991, 1628397, 201144, 1627395]
# [(201573, 'Jerryd Bayless'), (201959, 'Taj Gibson'), (1626157, 'Karl-Anthony Towns'), (1629006, 'Josh Okogie'), (203952, 'Andrew Wiggins')]
# [(203200, 'Justin Holiday'), (1628991, 'Jaren Jackson Jr.'), (1628397, 'Ivan Rabb'), (201144, 'Mike Conley'), (1627395, 'Julian Washburn')]
# 4
# [201229, 2736, 203476]
# [1627395, 1628397, 1629139, 201144]
# [(201573, 'Jerryd Bayless'), (201229, 'Anthony Tolliver'), (2736, 'Luol Deng'), (203476, 'Gorgui Dieng'), (203477, 'Isaiah Canaan')]
# [(1627395, 'Julian Washburn'), (1628397, 'Ivan Rabb'), (1629139, 'Yuta Watanabe'), (201144, 'Mike Conley'), (202714, 'Shelvin Mack')]
# 21800802
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800802&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800802_full_pbp.json
# 1
# [203932, 1628371, 203095, 202696, 201571]
# [203500, 202331, 203924, 201566, 1628390]
# [(203932, 'Aaron Gordon'), (1628371, 'Jonathan Isaac'), (203095, 'Evan Fournier'), (202696, 'Nikola Vucevic'), (201571, 'D.J. Augustin')]
# [(203500, 'Steven Adams'), (202331, 'Paul George'), (203924, 'Jerami Grant'), (201566, 'Russell Westbrook'), (1628390, 'Terrance Ferguson')]
# 2
# [203932, 203095, 203920, 1628515, 203082]
# [1627846, 203457, 202331]
# [(203932, 'Aaron Gordon'), (203095, 'Evan Fournier'), (203920, 'Khem Birch'), (1628515, 'Isaiah Briscoe'), (203082, 'Terrence Ross')]
# [(203457, 'Nerlens Noel'), (1627846, 'Abdel Nader'), (203471, 'Dennis Schroder'), (202331, 'Paul George'), (202335, 'Patrick Patterson')]
# 3
# [202696, 1628371, 201571, 203095, 203932]
# [201566, 202331, 203500, 203924, 1628390]
# [(202696, 'Nikola Vucevic'), (1628371, 'Jonathan Isaac'), (201571, 'D.J. Augustin'), (203095, 'Evan Fournier'), (203932, 'Aaron Gordon')]
# [(201566, 'Russell Westbrook'), (202331, 'Paul George'), (203500, 'Steven Adams'), (203924, 'Jerami Grant'), (1628390, 'Terrance Ferguson')]
# 4
# [1628515, 203082, 203932, 203920, 203095]
# [203471, 202335, 1627846, 202331, 203457]
# [(1628515, 'Isaiah Briscoe'), (203082, 'Terrence Ross'), (203932, 'Aaron Gordon'), (203920, 'Khem Birch'), (203095, 'Evan Fournier')]
# [(203471, 'Dennis Schroder'), (202335, 'Patrick Patterson'), (1627846, 'Abdel Nader'), (202331, 'Paul George'), (203457, 'Nerlens Noel')]
# 21800803
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800803&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800803_full_pbp.json
# 1
# [202355, 1626159, 203482, 204020, 1626196]
# [203994, 203468, 203081, 203090, 202329]
# [(202355, 'Hassan Whiteside'), (1626159, 'Justise Winslow'), (203482, 'Kelly Olynyk'), (204020, 'Tyler Johnson'), (1626196, 'Josh Richardson')]
# [(203994, 'Jusuf Nurkic'), (203468, 'CJ McCollum'), (203081, 'Damian Lillard'), (203090, 'Maurice Harkless'), (202329, 'Al-Farouq Aminu')]
# 2
# [201949, 2548, 1628389, 1626196, 203079]
# [1627774, 203086, 202323, 203552]
# [(201949, 'James Johnson'), (2548, 'Dwyane Wade'), (1628389, 'Bam Adebayo'), (1626196, 'Josh Richardson'), (203079, 'Dion Waiters')]
# [(203552, 'Seth Curry'), (203086, 'Meyers Leonard'), (202323, 'Evan Turner'), (1628380, 'Zach Collins'), (1627774, 'Jake Layman')]
# 3
# [1626159, 203482, 202355, 1626196, 204020]
# [203090, 203468, 203994, 202329, 203081]
# [(1626159, 'Justise Winslow'), (203482, 'Kelly Olynyk'), (202355, 'Hassan Whiteside'), (1626196, 'Josh Richardson'), (204020, 'Tyler Johnson')]
# [(203090, 'Maurice Harkless'), (203468, 'CJ McCollum'), (203994, 'Jusuf Nurkic'), (202329, 'Al-Farouq Aminu'), (203081, 'Damian Lillard')]
# 4
# [2548, 1628389, 203079, 1626196, 201949]
# [203086, 1627774, 203468, 202323, 203552]
# [(2548, 'Dwyane Wade'), (1628389, 'Bam Adebayo'), (203079, 'Dion Waiters'), (1626196, 'Josh Richardson'), (201949, 'James Johnson')]
# [(203086, 'Meyers Leonard'), (1627774, 'Jake Layman'), (203468, 'CJ McCollum'), (202323, 'Evan Turner'), (203552, 'Seth Curry')]
# 21800804
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800804&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800804_full_pbp.json
# 1
# [203486, 203115, 203999, 1627750, 1627736]
# [1628386, 1629066, 203925, 1626203, 1626156]
# [(203486, 'Mason Plumlee'), (203115, 'Will Barton'), (203999, 'Nikola Jokic'), (1627750, 'Jamal Murray'), (1627736, 'Malik Beasley')]
# [(1628386, 'Jarrett Allen'), (1629066, 'Rodions Kurucs'), (203925, 'Joe Harris'), (1626203, 'Treveon Graham'), (1626156, "D'Angelo Russell")]
# 2
# [1628420, 203999, 1626168, 1627823, 1628470]
# [201960, 203459, 1626203, 1626156, 202334]
# [(1628420, 'Monte Morris'), (203999, 'Nikola Jokic'), (1626168, 'Trey Lyles'), (1627823, 'Juancho Hernangomez'), (1628470, 'Torrey Craig')]
# [(201960, 'DeMarre Carroll'), (203459, 'Allen Crabbe'), (1626203, 'Treveon Graham'), (1626156, "D'Angelo Russell"), (202334, 'Ed Davis')]
# 3
# [203486, 203115, 1627750, 1627736, 203999]
# [1629066, 1626156, 1626203, 1628386]
# [(203486, 'Mason Plumlee'), (203115, 'Will Barton'), (1627750, 'Jamal Murray'), (1627736, 'Malik Beasley'), (203999, 'Nikola Jokic')]
# [(1628386, 'Jarrett Allen'), (1629066, 'Rodions Kurucs'), (1626156, "D'Angelo Russell"), (203925, 'Joe Harris'), (1626203, 'Treveon Graham')]
# 4
# [203486, 1628470, 203999, 1628420]
# [1626178, 203459, 202334]
# [(1628420, 'Monte Morris'), (1628470, 'Torrey Craig'), (1627736, 'Malik Beasley'), (203486, 'Mason Plumlee'), (203999, 'Nikola Jokic')]
# [(1626178, 'Rondae Hollis-Jefferson'), (203459, 'Allen Crabbe'), (1626156, "D'Angelo Russell"), (203894, 'Shabazz Napier'), (202334, 'Ed Davis')]
# 21800805
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800805&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800805_full_pbp.json
# 1
# [201950, 1628402, 1626143, 203121, 1629026]
# [201577, 1628374, 1627782, 1627739, 203897]
# [(201950, 'Jrue Holiday'), (1628402, 'Frank Jackson'), (1626143, 'Jahlil Okafor'), (203121, 'Darius Miller'), (1629026, 'Kenrich Williams')]
# [(201577, 'Robin Lopez'), (1628374, 'Lauri Markkanen'), (1627782, 'Wayne Selden'), (1627739, 'Kris Dunn'), (203897, 'Zach LaVine')]
# 2
# [203944, 1627767, 1629026, 203546]
# [1627782]
# [(1629026, 'Kenrich Williams'), (203944, 'Julius Randle'), (1627767, 'Cheick Diallo'), (204025, 'Tim Frazier'), (203546, 'Ian Clark')]
# [(1626245, 'Cristiano Felicio'), (1627782, 'Wayne Selden'), (1627885, 'Shaquille Harrison'), (1627789, 'Timothe Luwawu-Cabarrot'), (1627853, 'Ryan Arcidiacono')]
# 3
# [1626143, 1628402, 1629026, 201950, 203121]
# [203897, 1627739, 1628374, 1627782]
# [(1626143, 'Jahlil Okafor'), (1628402, 'Frank Jackson'), (1629026, 'Kenrich Williams'), (201950, 'Jrue Holiday'), (203121, 'Darius Miller')]
# [(1627782, 'Wayne Selden'), (201577, 'Robin Lopez'), (1628374, 'Lauri Markkanen'), (203897, 'Zach LaVine'), (1627739, 'Kris Dunn')]
# 4
# [1627767, 203546, 1629026, 203944, 204025]
# [1627789, 1627782, 1627885]
# [(1627767, 'Cheick Diallo'), (203546, 'Ian Clark'), (1629026, 'Kenrich Williams'), (203944, 'Julius Randle'), (204025, 'Tim Frazier')]
# [(1626245, 'Cristiano Felicio'), (1627782, 'Wayne Selden'), (1627853, 'Ryan Arcidiacono'), (1627885, 'Shaquille Harrison'), (1627789, 'Timothe Luwawu-Cabarrot')]
# 21800806
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800806&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800806_full_pbp.json
# 1
# [1628418, 203078, 201145, 203107, 2772]
# [201572, 1627763, 202339, 203507, 203114]
# ...
# [(201961, 'Wayne Ellington'), (202397, 'Ish Smith'), (1627748, 'Thon Maker'), (201933, 'Blake Griffin'), (1628379, 'Luke Kennard')]
# 21800841
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800841&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800841_full_pbp.json
# 1
# [201587, 203469, 101107, 203087, 202689]
# [1626167, 202083, 201152, 202711, 201954]
# [(201587, 'Nicolas Batum'), (203469, 'Cody Zeller'), (101107, 'Marvin Williams'), (203087, 'Jeremy Lamb'), (202689, 'Kemba Walker')]
# [(1626167, 'Myles Turner'), (202083, 'Wesley Matthews'), (201152, 'Thaddeus Young'), (202711, 'Bojan Bogdanovic'), (201954, 'Darren Collison')]
# 2
# [1626163, 202714, 201587, 1628370]
# [1627734, 201936, 202709, 1628388, 203926]
# [(1628370, 'Malik Monk'), (1626163, 'Frank Kaminsky'), (201587, 'Nicolas Batum'), (202714, 'Shelvin Mack'), (202687, 'Bismack Biyombo')]
# [(1627734, 'Domantas Sabonis'), (201936, 'Tyreke Evans'), (202709, 'Cory Joseph'), (1628388, 'TJ Leaf'), (203926, 'Doug McDermott')]
# 3
# [203469, 202689, 101107, 203087, 201587]
# [202711, 202083, 201152, 1626167, 201954]
# [(203469, 'Cody Zeller'), (202689, 'Kemba Walker'), (101107, 'Marvin Williams'), (203087, 'Jeremy Lamb'), (201587, 'Nicolas Batum')]
# [(202711, 'Bojan Bogdanovic'), (202083, 'Wesley Matthews'), (201152, 'Thaddeus Young'), (1626167, 'Myles Turner'), (201954, 'Darren Collison')]
# 4
# [203077, 101107, 202714, 1628970]
# [1627734, 203926, 201152, 202709, 201936]
# [(203077, 'Michael Kidd-Gilchrist'), (1628970, 'Miles Bridges'), (1628370, 'Malik Monk'), (101107, 'Marvin Williams'), (202714, 'Shelvin Mack')]
# [(1627734, 'Domantas Sabonis'), (203926, 'Doug McDermott'), (201152, 'Thaddeus Young'), (202709, 'Cory Joseph'), (201936, 'Tyreke Evans')]
# 21800842
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800842&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800842_full_pbp.json
# 1
# [203925, 1629066, 1626203, 1628386, 1626156]
# [201586, 201980, 202695, 200768, 1627783]
# [(203925, 'Joe Harris'), (1629066, 'Rodions Kurucs'), (1626203, 'Treveon Graham'), (1628386, 'Jarrett Allen'), (1626156, "D'Angelo Russell")]
# [(201586, 'Serge Ibaka'), (201980, 'Danny Green'), (202695, 'Kawhi Leonard'), (200768, 'Kyle Lowry'), (1627783, 'Pascal Siakam')]
# 2
# [1627747, 203459, 1626178, 203894]
# [1627775, 201188, 1626181, 1627783, 1628384]
# [(1626178, 'Rondae Hollis-Jefferson'), (1627747, 'Caris LeVert'), (203459, 'Allen Crabbe'), (203894, 'Shabazz Napier'), (202334, 'Ed Davis')]
# [(1627775, 'Patrick McCaw'), (201188, 'Marc Gasol'), (1626181, 'Norman Powell'), (1627783, 'Pascal Siakam'), (1628384, 'OG Anunoby')]
# 3
# [1626156, 1626203, 1629066, 1628386]
# [201586, 1627783, 201980, 202695, 200768]
# [(1628386, 'Jarrett Allen'), (1629066, 'Rodions Kurucs'), (1626156, "D'Angelo Russell"), (203925, 'Joe Harris'), (1626203, 'Treveon Graham')]
# [(201586, 'Serge Ibaka'), (1627783, 'Pascal Siakam'), (201980, 'Danny Green'), (202695, 'Kawhi Leonard'), (200768, 'Kyle Lowry')]
# 4
# [1626203, 202334, 1627747, 203894]
# [1628384, 201980, 201188, 1626181, 1627775]
# [(203459, 'Allen Crabbe'), (1627747, 'Caris LeVert'), (203894, 'Shabazz Napier'), (1626203, 'Treveon Graham'), (202334, 'Ed Davis')]
# [(1628384, 'OG Anunoby'), (201980, 'Danny Green'), (201188, 'Marc Gasol'), (1626181, 'Norman Powell'), (1627775, 'Patrick McCaw')]
# 21800843
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800843&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800843_full_pbp.json
# 1
# [1627763, 203114, 202339, 203507, 201572]
# [201577, 1628374, 203897, 203490, 1627739]
# [(1627763, 'Malcolm Brogdon'), (203114, 'Khris Middleton'), (202339, 'Eric Bledsoe'), (203507, 'Giannis Antetokounmpo'), (201572, 'Brook Lopez')]
# [(201577, 'Robin Lopez'), (1628374, 'Lauri Markkanen'), (203897, 'Zach LaVine'), (203490, 'Otto Porter Jr.'), (1627739, 'Kris Dunn')]
# 2
# [203503, 201588, 101141, 203507, 1627763]
# [1627782, 1627789, 203490, 1627853, 1627885]
# [(203503, 'Tony Snell'), (201588, 'George Hill'), (101141, 'Ersan Ilyasova'), (203507, 'Giannis Antetokounmpo'), (1627763, 'Malcolm Brogdon')]
# [(1627782, 'Wayne Selden'), (1627789, 'Timothe Luwawu-Cabarrot'), (203490, 'Otto Porter Jr.'), (1627853, 'Ryan Arcidiacono'), (1627885, 'Shaquille Harrison')]
# 3
# [201572, 203114, 203507, 202339, 1627763]
# [1628374, 203897, 1627739, 203490, 201577]
# [(201572, 'Brook Lopez'), (203114, 'Khris Middleton'), (203507, 'Giannis Antetokounmpo'), (202339, 'Eric Bledsoe'), (1627763, 'Malcolm Brogdon')]
# [(1628374, 'Lauri Markkanen'), (203897, 'Zach LaVine'), (1627739, 'Kris Dunn'), (203490, 'Otto Porter Jr.'), (201577, 'Robin Lopez')]
# 4
# [203507, 203503, 1627763, 1626192, 201588]
# [1627885, 1627789, 203490, 1627782, 1627853]
# [(203507, 'Giannis Antetokounmpo'), (203503, 'Tony Snell'), (1627763, 'Malcolm Brogdon'), (1626192, 'Pat Connaughton'), (201588, 'George Hill')]
# [(1627885, 'Shaquille Harrison'), (1627789, 'Timothe Luwawu-Cabarrot'), (203490, 'Otto Porter Jr.'), (1627782, 'Wayne Selden'), (1627853, 'Ryan Arcidiacono')]
# 21800844
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800844&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800844_full_pbp.json
# 1
# [1629029, 1628467, 1627827, 1628973, 203501]
# [202702, 201569, 200782, 201935, 101108]
# [(1629029, 'Luka Doncic'), (1628467, 'Maxi Kleber'), (1627827, 'Dorian Finney-Smith'), (1628973, 'Jalen Brunson'), (203501, 'Tim Hardaway Jr.')]
# [(202702, 'Kenneth Faried'), (201569, 'Eric Gordon'), (200782, 'PJ Tucker'), (201935, 'James Harden'), (101108, 'Chris Paul')]
# 2
# [1629029, 203504]
# [201569, 101123, 202697, 101108, 202702]
# [(203939, 'Dwight Powell'), (1629029, 'Luka Doncic'), (2734, 'Devin Harris'), (203504, 'Trey Burke'), (1717, 'Dirk Nowitzki')]
# [(201569, 'Eric Gordon'), (101123, 'Gerald Green'), (202697, 'Iman Shumpert'), (101108, 'Chris Paul'), (202702, 'Kenneth Faried')]
# 3
# [1628467, 1627827, 1628973, 1629029, 203501]
# [201569, 202702, 200782, 201935, 101108]
# [(1628467, 'Maxi Kleber'), (1627827, 'Dorian Finney-Smith'), (1628973, 'Jalen Brunson'), (1629029, 'Luka Doncic'), (203501, 'Tim Hardaway Jr.')]
# [(201569, 'Eric Gordon'), (202702, 'Kenneth Faried'), (200782, 'PJ Tucker'), (201935, 'James Harden'), (101108, 'Chris Paul')]
# 4
# [203504, 1628382, 2734]
# [101123, 200782, 202702, 202697]
# [(203939, 'Dwight Powell'), (2734, 'Devin Harris'), (203504, 'Trey Burke'), (201584, 'Courtney Lee'), (1628382, 'Justin Jackson')]
# [(101123, 'Gerald Green'), (202697, 'Iman Shumpert'), (200782, 'PJ Tucker'), (202702, 'Kenneth Faried'), (101108, 'Chris Paul')]
# 21800845
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800845&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800845_full_pbp.json
# 1
# [201568, 202066, 1628983, 201976]
# [1626157, 203967]
# [(201568, 'Danilo Gallinari'), (202066, 'Garrett Temple'), (1627826, 'Ivica Zubac'), (1628983, 'Shai Gilgeous-Alexander'), (201976, 'Patrick Beverley')]
# [(201952, 'Jeff Teague'), (1626157, 'Karl-Anthony Towns'), (1629006, 'Josh Okogie'), (2736, 'Luol Deng'), (203967, 'Dario Saric')]
# 2
# [101150, 1626149, 203210, 1629010]
# [201952, 201573, 203476, 203967, 1629006]
# [(1626149, 'Montrezl Harrell'), (203210, 'JaMychal Green'), (1629010, 'Jerome Robinson'), (1629013, 'Landry Shamet'), (101150, 'Lou Williams')]
# [(201952, 'Jeff Teague'), (201573, 'Jerryd Bayless'), (203476, 'Gorgui Dieng'), (203967, 'Dario Saric'), (1629006, 'Josh Okogie')]
# 3
# [201568, 202066, 1627826, 1628983, 201976]
# [203967, 201952, 1626157, 1629006, 2736]
# [(201568, 'Danilo Gallinari'), (202066, 'Garrett Temple'), (1627826, 'Ivica Zubac'), (1628983, 'Shai Gilgeous-Alexander'), (201976, 'Patrick Beverley')]
# [(203967, 'Dario Saric'), (201952, 'Jeff Teague'), (1626157, 'Karl-Anthony Towns'), (1629006, 'Josh Okogie'), (2736, 'Luol Deng')]
# 4
# [101150, 1628983, 1629013, 1626149]
# [203476, 201952, 1629006]
# [(1626149, 'Montrezl Harrell'), (203210, 'JaMychal Green'), (1629013, 'Landry Shamet'), (1628983, 'Shai Gilgeous-Alexander'), (101150, 'Lou Williams')]
# [(201952, 'Jeff Teague'), (1629006, 'Josh Okogie'), (2736, 'Luol Deng'), (203476, 'Gorgui Dieng'), (203967, 'Dario Saric')]
# 21800846
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800846&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800846_full_pbp.json
# 1
# [203994, 203468, 203090, 203081, 202329]
# [203500, 202331, 202335, 1628390, 201566]
# [(203994, 'Jusuf Nurkic'), (203468, 'CJ McCollum'), (203090, 'Maurice Harkless'), (203081, 'Damian Lillard'), (202329, 'Al-Farouq Aminu')]
# [(203500, 'Steven Adams'), (202331, 'Paul George'), (202335, 'Patrick Patterson'), (1628390, 'Terrance Ferguson'), (201566, 'Russell Westbrook')]
# 2
# [1628380, 203918, 203468, 1627774, 202323]
# [202331, 101109, 203457, 1627846]
# [(1628380, 'Zach Collins'), (203918, 'Rodney Hood'), (203468, 'CJ McCollum'), (1627774, 'Jake Layman'), (202323, 'Evan Turner')]
# [(203457, 'Nerlens Noel'), (1629126, 'Deonte Burton'), (1627846, 'Abdel Nader'), (101109, 'Raymond Felton'), (202331, 'Paul George')]
# 3
# [202329, 203081, 203994, 203090, 203468]
# [203500, 201566, 202331, 202335, 1628390]
# [(202329, 'Al-Farouq Aminu'), (203081, 'Damian Lillard'), (203994, 'Jusuf Nurkic'), (203090, 'Maurice Harkless'), (203468, 'CJ McCollum')]
# [(203500, 'Steven Adams'), (201566, 'Russell Westbrook'), (202331, 'Paul George'), (202335, 'Patrick Patterson'), (1628390, 'Terrance Ferguson')]
# 4
# [203552, 202329, 203918]
# [202331, 1629126, 1628390]
# [(203552, 'Seth Curry'), (203918, 'Rodney Hood'), (202329, 'Al-Farouq Aminu'), (1628380, 'Zach Collins'), (1627774, 'Jake Layman')]
# [(203457, 'Nerlens Noel'), (1628390, 'Terrance Ferguson'), (1629126, 'Deonte Burton'), (101109, 'Raymond Felton'), (202331, 'Paul George')]
# 21800847
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800847&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800847_full_pbp.json
# 1
# [202355, 203482, 1626196, 203079, 1626159]
# [203486, 203999, 203115, 1627736, 1627750]
# [(202355, 'Hassan Whiteside'), (203482, 'Kelly Olynyk'), (1626196, 'Josh Richardson'), (203079, 'Dion Waiters'), (1626159, 'Justise Winslow')]
# [(203486, 'Mason Plumlee'), (203999, 'Nikola Jokic'), (203115, 'Will Barton'), (1627736, 'Malik Beasley'), (1627750, 'Jamal Murray')]
# 2
# [1628389, 203585, 2548, 201949, 1626196]
# [203115, 1626168, 200794, 1628420]
# [(1628389, 'Bam Adebayo'), (203585, 'Rodney McGruder'), (2548, 'Dwyane Wade'), (201949, 'James Johnson'), (1626196, 'Josh Richardson')]
# [(1628420, 'Monte Morris'), (203115, 'Will Barton'), (1628470, 'Torrey Craig'), (1626168, 'Trey Lyles'), (200794, 'Paul Millsap')]
# 3
# [202355, 1626159, 1626196, 203482, 203079]
# [203115, 203999, 203486, 1627736, 1627750]
# [(202355, 'Hassan Whiteside'), (1626159, 'Justise Winslow'), (1626196, 'Josh Richardson'), (203482, 'Kelly Olynyk'), (203079, 'Dion Waiters')]
# [(203115, 'Will Barton'), (203999, 'Nikola Jokic'), (203486, 'Mason Plumlee'), (1627736, 'Malik Beasley'), (1627750, 'Jamal Murray')]
# 4
# [2548, 203585, 201949, 1628389]
# [1627736, 200794, 203999, 1628470, 1628420]
# [(203585, 'Rodney McGruder'), (1628389, 'Bam Adebayo'), (2548, 'Dwyane Wade'), (1626196, 'Josh Richardson'), (201949, 'James Johnson')]
# [(1627736, 'Malik Beasley'), (200794, 'Paul Millsap'), (203999, 'Nikola Jokic'), (1628470, 'Torrey Craig'), (1628420, 'Monte Morris')]
# 21800848
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800848&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800848_full_pbp.json
# 1
# [1628398, 201580, 1627742, 203493, 2544]
# [203473, 1629027, 1628381, 1627752, 1628989]
# [(1628398, 'Kyle Kuzma'), (201580, 'JaVale McGee'), (1627742, 'Brandon Ingram'), (203493, 'Reggie Bullock'), (2544, 'LeBron James')]
# [(203473, 'Dewayne Dedmon'), (1629027, 'Trae Young'), (1628381, 'John Collins'), (1627752, 'Taurean Prince'), (1628989, 'Kevin Huerter')]
# 2
# [1629021, 200765, 203484, 202362]
# [203473, 1713, 203145, 1629016, 1627761]
# [(1629021, 'Moritz Wagner'), (202362, 'Lance Stephenson'), (203484, 'Kentavious Caldwell-Pope'), (200765, 'Rajon Rondo'), (1627742, 'Brandon Ingram')]
# [(203473, 'Dewayne Dedmon'), (1713, 'Vince Carter'), (203145, 'Kent Bazemore'), (1629016, 'Omari Spellman'), (1627761, "DeAndre' Bembry")]
# 3
# [203493, 201580, 1628398, 2544]
# [1627752, 1628381, 203473, 1628989, 1629027]
# [(203493, 'Reggie Bullock'), (201580, 'JaVale McGee'), (1628398, 'Kyle Kuzma'), (2544, 'LeBron James'), (1627742, 'Brandon Ingram')]
# [(1627752, 'Taurean Prince'), (1628381, 'John Collins'), (203473, 'Dewayne Dedmon'), (1628989, 'Kevin Huerter'), (1629027, 'Trae Young')]
# 4
# [1628398, 2544, 203484, 1627742, 200765]
# [1629027, 203473, 1627752, 1628989, 1628381]
# [(1628398, 'Kyle Kuzma'), (2544, 'LeBron James'), (203484, 'Kentavious Caldwell-Pope'), (1627742, 'Brandon Ingram'), (200765, 'Rajon Rondo')]
# [(1629027, 'Trae Young'), (203473, 'Dewayne Dedmon'), (1627752, 'Taurean Prince'), (1628989, 'Kevin Huerter'), (1628381, 'John Collins')]
# 21800849
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800849&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800849_full_pbp.json
# 1
# [201143, 203935, 202694, 1628369, 1626179]
# [203954, 202710, 202699, 1627732, 200755]
# [(201143, 'Al Horford'), (203935, 'Marcus Smart'), (202694, 'Marcus Morris'), (1628369, 'Jayson Tatum'), (1626179, 'Terry Rozier')]
# [(203954, 'Joel Embiid'), (202710, 'Jimmy Butler'), (202699, 'Tobias Harris'), (1627732, 'Ben Simmons'), (200755, 'JJ Redick')]
# 2
# [201143, 202330, 203935, 1627759]
# [202710, 200755]
# [(202954, 'Brad Wanamaker'), (1627759, 'Jaylen Brown'), (201143, 'Al Horford'), (202330, 'Gordon Hayward'), (203935, 'Marcus Smart')]
# [(204456, 'T.J. McConnell'), (203118, 'Mike Scott'), (203954, 'Joel Embiid'), (200755, 'JJ Redick'), (202710, 'Jimmy Butler')]
# 3
# [1628369, 202694, 1626179, 203935, 201143]
# [202710, 203954, 202699, 200755, 1627732]
# [(1628369, 'Jayson Tatum'), (202694, 'Marcus Morris'), (1626179, 'Terry Rozier'), (203935, 'Marcus Smart'), (201143, 'Al Horford')]
# [(202710, 'Jimmy Butler'), (203954, 'Joel Embiid'), (202699, 'Tobias Harris'), (200755, 'JJ Redick'), (1627732, 'Ben Simmons')]
# 4
# [202330, 201143, 1627759, 202694, 1626179]
# [200755]
# [(202330, 'Gordon Hayward'), (201143, 'Al Horford'), (1627759, 'Jaylen Brown'), (202694, 'Marcus Morris'), (1626179, 'Terry Rozier')]
# [(204456, 'T.J. McConnell'), (203118, 'Mike Scott'), (203954, 'Joel Embiid'), (200755, 'JJ Redick'), (202710, 'Jimmy Butler')]
# 21800850
# https://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021800850&RangeType=2&Season=2018-19&SeasonType=Regular+Season&StartPeriod=1&StartRange=0kk
# https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2018/scores/pbp/0021800850_full_pbp.json
# 1
# [202722, 201942, 200752, 200746, 1627854]
# [1628991, 203200, 202340, 1626153, 1628397]
# [(202722, 'Davis Bertans'), (201942, 'DeMar DeRozan'), (200752, 'Rudy Gay'), (200746, 'LaMarcus Aldridge'), (1627854, 'Bryn Forbes')]
# [(1628991, 'Jaren Jackson Jr.'), (203200, 'Justin Holiday'), (202340, 'Avery Bradley'), (1626153, 'Delon Wright'), (1628397, 'Ivan Rabb')]
# 2

# %%
test.game_date.unique()
# Out:
# array(['2019-02-02T00:00:00.000000000'], dtype='datetime64[ns]')
